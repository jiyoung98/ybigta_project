# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#각 지역 리뷰 파일 불러오기
gangnam_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/강남 cafe_review.csv')
sinchon_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/testdata.csv')
hongdae_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/홍대 cafe_review.csv')
geondae_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/건대 cafe_review.csv')
garosu_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/가로수길 cafe_review.csv')
jongro_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/종로 cafe_review.csv')
daehakro_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/대학로 cafe_review.csv')

gwanghwamun_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/광화문 cafe_review.csv')
seouluniv_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/서울대입구 cafe_review.csv')
seongsu_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/성수 cafe_review.csv')
yeonnamdong_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/연남동 cafe_review.csv')
yeongdeungpo_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/영등포 cafe_review.csv')
wangsimni_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/왕십리 cafe_review.csv')
ikseondong_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/익선동 cafe_review.csv')
hannamdong_set = pd.read_csv('/content/drive/MyDrive/신입프로젝트/한남동 cafe_review.csv')

# %%
num_garosu = len(garosu_set)
garosu_loc = []
for i in range(num_garosu):
  garosu_loc.append('가로수길')
garosu_set['location'] = garosu_loc
garosu_set = garosu_set[['Unnamed: 0','location','0','1','2']]
garosu_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_gangnam = len(gangnam_set)
gangnam_loc = []
for i in range(num_gangnam):
  gangnam_loc.append('강남역')
gangnam_set['location'] = gangnam_loc
gangnam_set = gangnam_set[['Unnamed: 0','location','0','1','2']]
gangnam_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_geondae = len(geondae_set)
geondae_loc = []
for i in range(num_geondae):
  geondae_loc.append('건대')
geondae_set['location'] = geondae_loc
geondae_set = geondae_set[['Unnamed: 0','location','0','1','2']]
geondae_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_daehakro = len(daehakro_set)
daehakro_loc = []
for i in range(num_daehakro):
  daehakro_loc.append('대학로')
daehakro_set['location'] = daehakro_loc
daehakro_set = daehakro_set[['Unnamed: 0','location','0','1','2']]
daehakro_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_jongro = len(jongro_set)
jongro_loc = []
for i in range(num_jongro):
  jongro_loc.append('종로')
jongro_set['location'] = jongro_loc
jongro_set = jongro_set[['Unnamed: 0','location','0','1','2']]
jongro_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_hongdae = len(hongdae_set)
hongdae_loc = []
for i in range(num_hongdae):
  hongdae_loc.append('홍대')
hongdae_set['location'] = hongdae_loc
hongdae_set = hongdae_set[['Unnamed: 0','location','0','1','2']]
hongdae_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_sinchon = len(sinchon_set)
sinchon_loc = []
for i in range(num_sinchon):
  sinchon_loc.append('신촌')
sinchon_set['location'] = sinchon_loc
sinchon_set = sinchon_set[['Unnamed: 0','location','0','1','2']]
sinchon_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

# %%
num_gwanghwamun = len(gwanghwamun_set)
gwanghwamun_loc = []
for i in range(num_gwanghwamun):
  gwanghwamun_loc.append('광화문')
gwanghwamun_set['location'] = gwanghwamun_loc
gwanghwamun_set = gwanghwamun_set[['Unnamed: 0','location','0','1','2']]
gwanghwamun_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_seouluniv = len(seouluniv_set)
seouluniv_loc = []
for i in range(num_seouluniv):
  seouluniv_loc.append('서울대입구')
seouluniv_set['location'] = seouluniv_loc
seouluniv_set = seouluniv_set[['Unnamed: 0','location','0','1','2']]
seouluniv_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_seongsu = len(seongsu_set)
seongsu_loc = []
for i in range(num_seongsu):
  seongsu_loc.append('성수')
seongsu_set['location'] = seongsu_loc
seongsu_set = seongsu_set[['Unnamed: 0','location','0','1','2']]
seongsu_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_yeonnamdong = len(yeonnamdong_set)
yeonnamdong_loc = []
for i in range(num_yeonnamdong):
  yeonnamdong_loc.append('연남동')
yeonnamdong_set['location'] = yeonnamdong_loc
yeonnamdong_set = yeonnamdong_set[['Unnamed: 0','location','0','1','2']]
yeonnamdong_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_yeongdeungpo = len(yeongdeungpo_set)
yeongdeungpo_loc = []
for i in range(num_yeongdeungpo):
  yeongdeungpo_loc.append('영등포')
yeongdeungpo_set['location'] = yeongdeungpo_loc
yeongdeungpo_set = yeongdeungpo_set[['Unnamed: 0','location','0','1','2']]
yeongdeungpo_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_wangsimni = len(wangsimni_set)
wangsimni_loc = []
for i in range(num_wangsimni):
  wangsimni_loc.append('왕십리')
wangsimni_set['location'] = wangsimni_loc
wangsimni_set = wangsimni_set[['Unnamed: 0','location','0','1','2']]
wangsimni_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_ikseondong = len(ikseondong_set)
ikseondong_loc = []
for i in range(num_ikseondong):
  ikseondong_loc.append('익선동')
ikseondong_set['location'] = ikseondong_loc
ikseondong_set = ikseondong_set[['Unnamed: 0','location','0','1','2']]
ikseondong_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

num_hannamdong = len(hannamdong_set)
hannamdong_loc = []
for i in range(num_hannamdong):
  hannamdong_loc.append('한남동')
hannamdong_set['location'] = hannamdong_loc
hannamdong_set = hannamdong_set[['Unnamed: 0','location','0','1','2']]
hannamdong_set.rename(columns = {'Unnamed: 0': 'num', '0': 'cafe_name','1':'review','2':'label'}, inplace = True)

# %%
#모든 지역의 카페리뷰를 하나의 dataFrame으로 병합
cafe_set = pd.concat([gangnam_set,sinchon_set,hongdae_set,geondae_set,garosu_set,jongro_set, daehakro_set,gwanghwamun_set,seouluniv_set,seongsu_set,yeonnamdong_set,yeongdeungpo_set,wangsimni_set,ikseondong_set, hannamdong_set])

cafe_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34759 entries, 0 to 1360
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   num        34759 non-null  int64
#  1   location   34759 non-null  object
#  2   cafe_name  34759 non-null  object
#  3   review     34489 non-null  object
#  4   label      34759 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %%
cafe_set  = cafe_set.dropna()

cafe_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34489 entries, 0 to 1360
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   num        34489 non-null  int64
#  1   location   34489 non-null  object
#  2   cafe_name  34489 non-null  object
#  3   review     34489 non-null  object
#  4   label      34489 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %%
len(cafe_set.cafe_name.unique())
# Out:
# 1483

# %%
# concat된 리뷰 전체를 0부터 끝까지 indexing
row_num = []
for i in range(len(cafe_set)):
  row_num.append(i)
cafe_set['row_num'] = row_num
cafe_set.drop(['num'], axis=1, inplace=True)
cafe_set = cafe_set[['row_num','location','cafe_name','review','label']]

# %%
# label 정수 형태로 변환
for i in range(len(cafe_set)):
  cafe_set['label'].iloc[i] = cafe_set['label'].iloc[i][0]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
cafe_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34489 entries, 0 to 1360
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   row_num    34489 non-null  int64
#  1   location   34489 non-null  object
#  2   cafe_name  34489 non-null  object
#  3   review     34489 non-null  object
#  4   label      34489 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %%
cafe_set.head(10)
# Out:
#    row_num location  ...                                             review label
# 0        0      강남역  ...  그냥 그렇다 생각했는데 다른 곳에서 도넛 먹고나면? ㄷ ㄷ 킹티드 .. 잘되는 이유...     4
# 1        1      강남역  ...                우유크림 개맛있슴 근데 그만큼 혼잡해서 또 가고싶지 않은 곳..     3
# 2        2      강남역  ...  도넛은 맛있는데 종업원들 대응이 너무 느려요. 한남이랑 삼성점도 가봤는데 여기가 유...     2
# 3        3      강남역  ...  도넛이 맛은 있는데 줄이 진짜 너엉어ㅓㅓ어어어어무 길다 예약해서 가져갈거면 가고 가...     4
# 4        4      강남역  ...                                              감사합니다     1
# 5        5      강남역  ...  바닐라맛 맛있어요! 도넛 사는데.. 40분? 기다린거 같네요 . 이왕 간김에 조각 ...     4
# 6        6      강남역  ...  도넛 맛은 맛있음 대신 포장해서 갈거면 인내심 길러가야함 뭔가 포장하는 방식이 바뀌...     3
# 7        7      강남역  ...  계산해주는 직원도 불친절하고 크로플도 두개시켰는데 집에 와서 열어보니 한개만 줬네요...     1
# 8        8      강남역  ...                                                좋아요     4
# 9        9      강남역  ...                                               최고예요     5
#
# [10 rows x 5 columns]

# %%
cafe_set.tail(10)
# Out:
#       row_num location  ...                                             review label
# 1351    34479      한남동  ...                                               최고예요     5
# 1352    34480      한남동  ...  치즈 주문을 잘못받았는데 사과한마디 없어 언짢았지만 쿠키서비스로 사과를 대신해서 바...     4
# 1353    34481      한남동  ...  일하시는 분 핵 불친절 그래도 어쩌다 또 방문하게 됐는데 여전하시더라구여 손님 입장...     1
# 1354    34482      한남동  ...                                               최고예요     5
# 1355    34483      한남동  ...                                     바닐라 라떼 / 모모 라떼     4
# 1356    34484      한남동  ...                                            조금 아쉬워요     2
# 1357    34485      한남동  ...  우리는 결국 모두 어떤 기대 없이 하도록 돼 있는 일을 하게 된다. 그래서 이 곳은...     5
# 1358    34486      한남동  ...                                  가격도 합리적이고 분위기두 굿!     5
# 1359    34487      한남동  ...  조용한 골목에 있어서 일단 너무 좋아요. 분위기도 예쁘고. 여긴 독특하게 시간당으로...     4
# 1360    34488      한남동  ...  - 심플한 사인에 보게 되었다가 실내의 조명 디테일에 반함 .  오래 있고 싶은 카...     4
#
# [10 rows x 5 columns]

# %% [markdown]
# ## 전처리~

# %%
cafe_set.to_csv("/content/drive/MyDrive/신입프로젝트/whole_data_beforepp2.csv")

# %%
import re

punct = "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&' 
punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2",
                 "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 
                 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi'} 

def clean_punc(text, punct, mapping): 
  for p in mapping: 
    text = text.replace(p, mapping[p]) 
  for p in punct: 
    text = text.replace(p, f' {p} ') 
    specials = {'\u200b': ' ', '…': ' ... ', '\ufeff': '', 'करना': '', 'है': ''} 
  for s in specials: 
    text = text.replace(s, specials[s]) 
   
  return text.strip() 



def clean_text(texts): 
  corpus = [] 
  for i in range(0, len(texts)): 
    review = re.sub(r'[@%\\*=()/~#&\+á?\xc3\xa1\-\|\.\:\;\!\-\,\_\~\$\'\"]', '',str(texts[i])) #remove punctuation 
    review = re.sub(r'\d+','', str(texts[i]))# remove number 
    review = review.lower() #lower case 
    review = re.sub(r'\s+', ' ', review) #remove extra space 
    review = re.sub(r'<[^>]+>','',review) #remove Html tags 
    review = re.sub(r'\s+', ' ', review) #remove spaces 
    review = re.sub(r"^\s+", '', review) #remove space from start 
    review = re.sub(r'\s+$', '', review) #remove space from the end 
    review = re.sub(r'♥','',review)
    review = re.sub(r'~','',review)
    review = re.sub(r'&','',review)
    corpus.append(review) 
  return corpus

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
# NLTK Data 다운
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

stop_words = open('/content/drive/MyDrive/신입프로젝트/korean_stopwords.txt').read()


# 위의 불용어는 명사가 아닌 단어 중에서 저자가 임의로 선정한 것으로 실제 의미있는 선정 기준이 아님
stop_words=stop_words.split('\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git

from hanspell import spell_checker
def grammar_check(text):
  spelled_sent = spell_checker.check(text)
  hanspell_sent = spelled_sent.checked
  return hanspell_sent

# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git

from pykospacing import spacing

# !pip install konlpy 
from konlpy.tag import Okt
okt = Okt()

def tokenize_tagged(text):

  temp_X = okt.pos(text, norm=True, stem=True) # 토큰화
  temp_X = [word for word in temp_X if not word in stop_words] # 불용어 제거
  return ['/'.join(t) for t in temp_X]
# Out:
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-5v5wln8c
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-5v5wln8c
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-cp36-none-any.whl size=4854 sha256=0288ed7d07a16059afc44ca9b2a9898ff337f9259a769edbb4f524ac3b557735
#   Stored in directory: /tmp/pip-ephem-wheel-cache-evbxjp7d/wheels/0a/25/d1/e5e96476dbb1c318cc26c992dd493394fe42b0c204b3e65588
# Successfully built py-hanspell
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-n0_hvghp
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-n0_hvghp
# ...
#      |████████████████████████████████| 394.7MB 45kB/s
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.4-cp36-none-any.whl size=2255638 sha256=dcb60c22459213c391eb390830c7ea289364e054a01d07485c76f7140cb61ba8
# ...

# %%
cafe_set['new_review'] = cafe_set['review']
#main()
import regex as re
for i in range(len(cafe_set)):
    text = cafe_set['review'].iloc[i]
    print(str(i) + '###', end = '')
    text1 = clean_punc(text, punct, punct_mapping)
    text2 = ''.join(clean_text(text1))
    text3 = spacing(text2)
    text4 = grammar_check(text3)
    text_ = tokenize_tagged(text4)
    regex = re.compile(r"/+[a-zA-Z]")
    regex1 = re.compile('Josa$')
    regex2 = re.compile('Punctuation$')
    regex3 = re.compile('Suffix$')
    regex4 = re.compile('KoreanParticle$')
    regex5 = re.compile('Alpha$')
    regex6 = re.compile('Foreign$')
    text_nj = []
    for item in text_:
      mo1 = regex1.search(item)
      mo2 = regex2.search(item)
      mo3 = regex3.search(item)
      mo4 = regex4.search(item)
      mo5 = regex5.search(item)
      mo6 = regex6.search(item)
      if mo1 == None and mo2 == None and mo3 == None and mo4 == None and  mo5 == None and mo6 == None:
        text_nj.append(item)
    new_review = ','.join(text_nj)
    cafe_set['new_review'].iloc[i] = new_review
    print(cafe_set['new_review'].iloc[i])
# Out:
# 0###
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 29489###팡/Adverb,도르가/Noun,그렇게/Adverb,맛있다/Adjective,모르다/Verb,던데/Noun,아니다/Adjective,제/Noun,팡/Adverb,도르다/Verb,너무/Adverb,기대하다/Adjective,탓/Noun,이다/Verb,요/Noun,안/Noun,크림/Noun,뭐/Noun,있다/Adjective,줄/Noun,알/Noun,앗다/Verb,네버/Noun,그냥/Noun,슈거/Noun,파우더/Noun,위/Noun,가득/Noun,뿌리다/Verb,하다/Verb,팡/Adverb,도르다/Verb
# 29490###맛/Noun,디저트/Noun,빵/Noun,맛/Noun,커피/Noun,바글바글/Adverb,한/Determiner,사람/Noun
# 29491###보통/Noun
# 29492###예쁘다/Adjective,맛있다/Adjective,날/Noun,좋다/Adjective,날/Noun,가기/Noun,좋다/Adjective
# 29493###진짜/Noun,맛있다/Adjective,인절미/Noun,팡/Adverb,도르다/Verb,칠리/Noun,소세지/Noun,먹다/Verb,다음/Noun,다른/Noun,거/Noun,또/Noun,먹다/Verb
# ...

# %%
cafe_set.to_csv("/content/drive/MyDrive/신입프로젝트/whole_data_finally.csv")
