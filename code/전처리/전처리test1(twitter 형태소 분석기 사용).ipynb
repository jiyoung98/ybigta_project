# %%
import nltk
import numpy as np
import pandas as pd

# NLTK Data 다운
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82108\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\82108\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\82108\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# tokenizer 불러오기
from nltk.tokenize import word_tokenize, WordPunctTokenizer

# %%
#한국어 띄어쓰기 패키지로 띄어쓰기가 되어있지 않은 문장을 띄어쓰기를 한 문장으로 변환해주는 패키지
#PyKoSpacing은 대용량 코퍼스를 학습하여 만들어진 띄어쓰기 딥 러닝 모델로 준수한 성능
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to c:\users\82108\appdata\local\temp\pip-req-build-p0mr4uyg
# ...
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git 'C:\Users\82108\AppData\Local\Temp\pip-req-build-p0mr4uyg'
# ...
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ...

# %%
sent = '김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.'

# %%
new_sent = sent.replace(" ", '') # 띄어쓰기가 없는 문장 임의로 만들기
print(new_sent)
# Out:
# 김철수는극중두인격의사나이이광수역을맡았다.철수는한국유일의태권도전승자를가리는결전의날을앞두고10년간함께훈련한사형인유연재(김광수분)를찾으러속세로내려온인물이다.

# %%
from pykospacing import spacing

kospacing_sent = spacing(new_sent)
print(sent)
print(kospacing_sent)
# Out:
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.

# %%
"""
전체 데이터 -> 띄어 쓰기 제거 -> spacing을 통해 띄어쓰기
-> Py-Hanspell은 네이버 한글 맞춤법 검사기를 바탕으로 만들어진 패키지를 이용하여 맞춤법 보정
-> soynlp는 기본적으로 학습에 기반한 토크나이저이므로 학습에 필요한 한국어 문서를 다운로드
-> 3만 91개의 훈련데이터를 바탕으로 토크나이저 학습
-> SOYNLP의 L tokenizer를 이용하여 분리
-> SOYNLP를 이용한 반복되는 문자 정제
-> Customized Konlpy라는 사용자 사전 추가가 매우 쉬운 패키지 사용하여 사용자 사전 추가
"""
# Out:
# '\n전체 데이터 -> 띄어 쓰기 제거 -> spacing을 통해 띄어쓰기\n-> Py-Hanspell은 네이버 한글 맞춤법 검사기를 바탕으로 만들어진 패키지를 이용하여 맞춤법 보정\n-> soynlp는 기본적으로 학습에 기반한 토크나이저이므로 학습에 필요한 한국어 문서를 다운로드\n-> 3만 91개의 훈련데이터를 바탕으로 토크나이저 학습\n-> SOYNLP의 L tokenizer를 이용하여 분리\n-> SOYNLP를 이용한 반복되는 문자 정제\n-> Customized Konlpy라는 사용자 사전 추가가 매우 쉬운 패키지 사용하여 사용자 사전 추가\n'

# %%
#Py-Hanspell은 네이버 한글 맞춤법 검사기를 바탕으로 만들어진 패키지
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to c:\users\82108\appdata\local\temp\pip-req-build-0fn6avag
# ...
#   Running command git clone -q https://github.com/ssut/py-hanspell.git 'C:\Users\82108\AppData\Local\Temp\pip-req-build-0fn6avag'
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4899 sha256=08cde780536adc0d60d156a91230407463f8de8a6eda279d251fa4c82c665e8b
#   Stored in directory: C:\Users\82108\AppData\Local\Temp\pip-ephem-wheel-cache-bzgvhmcd\wheels\3f\a5\73\e4d2806ae141d274fdddaabf8c0ed79be9357d36bfdc99e4b4
# Successfully built py-hanspell
# ...

# %%
from hanspell import spell_checker

sent = "맞춤법 틀리면 외 않되? 쓰고싶은대로쓰면돼지 "
spelled_sent = spell_checker.check(sent)

hanspell_sent = spelled_sent.checked
print(hanspell_sent)
# Out:
# 맞춤법 틀리면 왜 안돼? 쓰고 싶은 대로 쓰면 되지

# %%
spelled_sent = spell_checker.check(new_sent)

hanspell_sent = spelled_sent.checked
print(hanspell_sent)
print(kospacing_sent) # 앞서 사용한 kospacing 패키지에서 얻은 결과
# Out:
# 김철수는 극 중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연제(김광수 분)를 찾으러 속세로 내려온 인물이다.
# 김철수는 극중 두 인격의 사나이 이광수 역을 맡았다. 철수는 한국 유일의 태권도 전승자를 가리는 결전의 날을 앞두고 10년간 함께 훈련한 사형인 유연재(김광수 분)를 찾으러 속세로 내려온 인물이다.

# %%
"""
soynlp는 품사 태깅, 단어 토큰화 등을 지원하는 단어 토크나이저입니다. 
비지도 학습으로 단어 토큰화를 한다는 특징을 갖고 있으며, 데이터에 자주 등장하는 단어들을 단어로 분석합니다.
soynlp 단어 토크나이저는 내부적으로 단어 점수 표로 동작합니다. 
이 점수는 응집 확률(cohesion probability)과 브랜칭 엔트로피(branching entropy)를 활용
"""
# !pip install soynlp

# %%
import urllib.request
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
#soynlp는 기본적으로 학습에 기반한 토크나이저이므로 학습에 필요한 한국어 문서를 다운로드
urllib.request.urlretrieve("https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt", filename="2016-10-20.txt")
# Out:
# ('2016-10-20.txt', <http.client.HTTPMessage at 0x21426ec3610>)

# %%
# 훈련 데이터를 다수의 문서로 분리
corpus = DoublespaceLineCorpus("2016-10-20.txt")
len(corpus)
# Out:
# 30091

# %%
word_extractor = WordExtractor()
word_extractor.train(corpus)
word_score_table = word_extractor.extract()
# Out:
# training was done. used memory 0.649 Gb
# all cohesion probabilities was computed. # words = 223348
# all branching entropies was computed # words = 361598
# all accessor variety was computed # words = 361598

# %%
"""
soynlp는 학습 기반의 단어 토크나이저이므로 기존의 KoNLPy에서 제공하는 형태소 분석기들과는 달리 학습 과정을 거쳐야 함 
즉, 전체 코퍼스로부터 응집 확률과 브랜칭 엔트로피 단어 점수표를 만드는 과정
WordExtractor.extract()를 통해서 전체 코퍼스에 대해 단어 점수표를 계산
"""

# %%
"""
한국어는 띄어쓰기 단위로 나눈 어절 토큰은 주로 L 토큰 + R 토큰의 형식을 가질 때가 많습니다. 
예를 들어서 '공원에'는 '공원 + 에'로 나눌 수 있겠지요. 또는 '공부하는'은 '공부 + 하는'으로 나눌 수도 있을 것입니다. 
L 토크나이저는 L 토큰 + R 토큰으로 나누되, 분리 기준을 점수가 가장 높은 L 토큰을 찾아내는 원리를 가지고 있습니다.
"""
from soynlp.tokenizer import LTokenizer

scores = {word:score.cohesion_forward for word, score in word_score_table.items()}
l_tokenizer = LTokenizer(scores=scores)
l_tokenizer.tokenize("국제사회와 우리의 노력들로 범죄를 척결하자", flatten=False)
# Out:
# [('국제사회', '와'), ('우리', '의'), ('노력', '들로'), ('범죄', '를'), ('척결', '하자')]

# %%
from soynlp.normalizer import *
print(emoticon_normalize('앜ㅋㅋㅋㅋ이영화존잼쓰ㅠㅠㅠㅠㅠ', num_repeats=2))
print(emoticon_normalize('앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋ이영화존잼쓰ㅠㅠㅠㅠ', num_repeats=2))
print(emoticon_normalize('앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ이영화존잼쓰ㅠㅠㅠㅠㅠㅠ', num_repeats=2))
print(emoticon_normalize('앜ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ이영화존잼쓰ㅠㅠㅠㅠㅠㅠㅠㅠ', num_repeats=2))
# Out:
# 아ㅋㅋ영화존잼쓰ㅠㅠ
# 아ㅋㅋ영화존잼쓰ㅠㅠ
# 아ㅋㅋ영화존잼쓰ㅠㅠ
# 아ㅋㅋ영화존잼쓰ㅠㅠ

# %%
pip install customized_konlpy
# Out:
# ...
#
# ...

# %%
#형태소 분석기 Twitter에 add_dictionary('단어', '품사')와 같은 형식으로 사전 추가
from ckonlpy.tag import Twitter
twitter = Twitter()
twitter.morphs('은경이는 사무실로 갔습니다.')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['은', '경이', '는', '사무실', '로', '갔습니다', '.']

# %%
twitter.add_dictionary('은경이', 'Noun')

# %%
twitter.morphs('은경이는 사무실로 갔습니다.')
# Out:
# ['은경이', '는', '사무실', '로', '갔습니다', '.']

# %%
data = pd.read_csv('C:/Users/82108/Desktop/ybigta_project/ybigta_pj/Train_Data/traindata.csv')
data.head(10)
# Out:
#    Unnamed: 0         0                                                  1   2
# 0           0  카페노티드 청담  도넛 맛은 맛있음 대신 포장해서 갈거면 인내심 길러가야함 뭔가 포장하는 방식이 바뀌...  3점
# 1           1  카페노티드 청담  계산해주는 직원도 불친절하고 크로플도 두개시켰는데 집에 와서 열어보니 한개만 줬네요...  1점
# 2           2  카페노티드 청담                                                좋아요  4점
# 3           3  카페노티드 청담                                               최고예요  5점
# 4           4  카페노티드 청담  빵들 다 맛있고 저렴한데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이...  3점
# 5           5  카페노티드 청담                                               최고예요  5점
# 6           6  카페노티드 청담        먹고싶었는데 많이 안달아서 진짜 더 좋았던거같아요 줄 정리도 빨라서 좋았습니다  5점
# 7           7  카페노티드 청담                                               최고예요  5점
# 8           8  카페노티드 청담                                       노티드 맛있어요 ㅠㅠㅍ  5점
# 9           9  카페노티드 청담  아쉬워요ㅠㅠ처음 노티드 알게 되고 먹었을 때의 설렘과 감동이 어느 순간부터는 안 느...  3점

# %%
#4,000개 데이터로 학습, 네이버 영화분석에서는 총 20만개로 했기때문에, 
#우리도 우선은 시도해보고, 괜찮으면 10만개 정도까지 늘려도될듯?!
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4008 non-null   int64
#  1   0           4008 non-null   object
#  2   1           3978 non-null   object
#  3   2           4008 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 125.4+ KB

# %%
text = data['1'][4]
text
# Out:
# '빵들 다 맛있고 저렴한데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이라 아쉬워요 계산할 때 빵은 어디서 받고 케익은 어디서 받는지 미리 말씀해주셨으면..'

# %%
new_text = text.replace(" ", '') # 띄어쓰기가 없는 문장 임의로 만들기
print(new_text)
# Out:
# 빵들다맛있고저렴한데다매장분위기도좋은데직원들끼리좀소통이안되는느낌이라아쉬워요계산할때빵은어디서받고케익은어디서받는지미리말씀해주셨으면..

# %%
from pykospacing import spacing

kospacing_text = spacing(new_text)
print(text)
print(kospacing_text)
# Out:
# 빵들 다 맛있고 저렴한데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이라 아쉬워요 계산할 때 빵은 어디서 받고 케익은 어디서 받는지 미리 말씀해주셨으면..
# 빵들다 맛있고 저렴한데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안 되는 느낌이라 아쉬워요계산할 때 빵은 어디서 받고 케익은 어디서 받는지 미리 말씀해주셨으면..

# %%
from hanspell import spell_checker

spelled_text = spell_checker.check(text)

hanspell_text = spelled_text.checked
print(hanspell_text)
# Out:
# 빵들 다 맛있고 저렴한 데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이라 아쉬워요 계산할 때 빵은 어디서 받고 케이크는 어디서 받는지 미리 말씀해주셨으면..

# %%
spelled_text = spell_checker.check(new_text)

hanspell_text = spelled_text.checked
print(hanspell_text)
print(kospacing_text) # 앞서 사용한 kospacing 패키지에서 얻은 결과
# Out:
# 빵들 더 맛있고 저렴한 데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이라 아쉬워요 계산할 때 빵은 어디서 받고 케이크는 어디서 받는지 미리 말씀해 주셨으면..
# 빵들다 맛있고 저렴한데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안 되는 느낌이라 아쉬워요계산할 때 빵은 어디서 받고 케익은 어디서 받는지 미리 말씀해주셨으면..

# %%
"""
Hanspell로 전체 스펠체크 후 띄어쓰기 보정하는게 제일 정확한듯..!
"""

# %%
from soynlp.tokenizer import LTokenizer

scores = {word:score.cohesion_forward for word, score in word_score_table.items()}
l_tokenizer = LTokenizer(scores=scores)
l_tokenizer.tokenize(hanspell_text, flatten=False)
# Out:
# [('빵들', ''),
#  ('더', ''),
#  ('맛있', '고'),
#  ('저렴한', ''),
#  ('데다', ''),
#  ('매장', ''),
#  ('분위기', '도'),
#  ('좋은', '데'),
#  ('직원들', '끼리'),
#  ('좀', ''),
#  ('소통이', ''),
#  ('안되는', ''),
#  ('느낌이', '라'),
#  ('아쉬워요', ''),
#  ('계산할', ''),
#  ('때', ''),
#  ('빵은', ''),
#  ('어디서', ''),
#  ('받고', ''),
#  ('케이', '크는'),
#  ('어디서', ''),
#  ('받는', '지'),
#  ('미리', ''),
#  ('말씀해', ''),
#  ('주셨으면', '..')]

# %%
print(emoticon_normalize(hanspell_text, num_repeats=2))
# Out:
# 빵들 더 맛있고 저렴한 데다 매장 분위기도 좋은데 직원들끼리 좀 소통이 안되는 느낌이라 아쉬워요 계산할 때 빵은 어디서 받고 케이크는 어디서 받는지 미리 말씀해 주셨으면..

# %%
from ckonlpy.tag import Twitter
twitter = Twitter()
twitter.morphs(hanspell_text)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# ['빵',
#  '들',
#  '더',
#  '맛있고',
#  '저렴',
#  '한',
#  '데',
#  '다',
#  '매장',
#  '분위기',
#  '도',
#  '좋은데',
#  '직원',
#  '들',
#  '끼리',
#  '좀',
#  '소통',
#  '이',
#  '안되는',
#  '느낌',
#  '이라',
#  '아쉬워요',
#  '계산',
#  '할',
#  '때',
#  '빵',
#  '은',
#  '어디',
#  '서',
#  '받고',
#  '케이크',
#  '는',
#  '어디',
#  '서',
#  '받는지',
#  '미리',
#  '말씀',
#  '해',
#  '주셨으면',
#  '..']

# %%
print(twitter.morphs(hanspell_text))
# Out:
# ['빵', '들', '더', '맛있고', '저렴', '한', '데', '다', '매장', '분위기', '도', '좋은데', '직원', '들', '끼리', '좀', '소통', '이', '안되는', '느낌', '이라', '아쉬워요', '계산', '할', '때', '빵', '은', '어디', '서', '받고', '케이크', '는', '어디', '서', '받는지', '미리', '말씀', '해', '주셨으면', '..']

# %%
#twitter.add_dictionary('겨릭데이', 'Noun') 이런식으로 사전에 추가!

# %%
i = 0
for reviews in data['1']:
  i += 1
  print(str(i) + '번째 리뷰!')
  text = ''. join(clean_text(reviews))
  text = clean_punc(text, punct,punct_mapping)
  text = spacing(text)
  print(word_tokenize(text))

# %%
data.dropna(inplace = True)

# %%
import re 

i = 0
for text in data['1']:
  i += 1
  print(str(i) + '번째 리뷰!')
  text = re.sub('[^가-힣a-z]', ' ', text)  
  spelled_text = spell_checker.check(text)
  hanspell_text = spelled_text.checked
  #twitter.add_dictionary('겨릭데이', 'Noun')
  text_ = twitter.morphs(hanspell_text)

  print(text_)
# Out:
# 1번째 리뷰!
# ['도넛', '맛', '은', '맛있음', '대신', '포장', '해서', '갈', '거', '면', '인내심', '길러', '가야', '함', '뭔가', '포', '장하', '는', '방식', '이', '바뀌어야', '할', '거', '같음']
# 2번째 리뷰!
# ['계산', '해주', '는', '직원', '도', '불친절', '하고', '크로', '프로도', '두', '개', '시', '켰는데', '집', '에', '와서', '열', '어보', '니', '한', '개', '만', '줬네요', '다시', '는', '안', '갈', '예정', '입니다']
# 3번째 리뷰!
# ['좋아요']
# 4번째 리뷰!
# ['최고', '예요']
# 5번째 리뷰!
# ['빵', '들', '다', '맛있고', '저렴', '한', '데', '다', '매장', '분위기', '도', '좋은데', '직원', '들', '끼리', '좀', '소통', '이', '안되는', '느낌', '이라', '아쉬워요', '계산', '할', '때', '빵', '은', '어디', '서', '받고', '케이크', '는', '어디', '서', '받는지', '미리', '말씀', '해주', '셨으', '면']
# 6번째 리뷰!
# ['최고', '예요']
# 7번째 리뷰!
# ['먹고', '싶었는데', '많이', '안', '달아서', '진짜', '더', '좋았던', '거', '같아요', '줄', '정리', '도', '빨', '라서', '좋았습니다']
# 8번째 리뷰!
# ['최고', '예요']
# 9번째 리뷰!
# ['노티', '스', '맛있', '어요']
# 10번째 리뷰!
# ...
