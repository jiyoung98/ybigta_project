# %%
import requests
import os
from time import sleep

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import StaleElementReferenceException
from bs4 import BeautifulSoup
import pandas as pd

options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('lang=ko_KR')
path = 'C:/Users/82108/Desktop/chromedriver.exe'

driver = webdriver.Chrome(path) # chromedriver 열기


def main():
    global driver, load_wb, review_num, searchList,place_name
    
    searchList = []

    driver.implicitly_wait(4)  # 렌더링 될때까지 기다린다 4초
    driver.get('https://map.kakao.com/')  # 주소 가져오기

    # 검색할 목록
    place_infos = ['신촌 카페']

    for i, place in enumerate(place_infos):
        # delay
        if i % 4 == 0 and i != 0:
            sleep(5)
        print("#####", i)
        search(place)
        
    driver.quit()   
    print(searchList)    
    print("finish")
    

def search(place):
    global driver, place_name

    search_area = driver.find_element_by_xpath(
        '//*[@id="search.keyword.query"]')  # 검색 창
    search_area.send_keys(place)  # 검색어 입력
    driver.find_element_by_xpath(
        '//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    sleep(1)

    # 검색된 정보가 있는 경우에만 탐색
    # 1번 페이지 place list 읽기
    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')
    place_lists = soup.select('.placelist > .PlaceItem')  # 검색된 장소 목록

    # 검색된 첫 페이지 장소 목록 크롤링하기
    crawling(place, place_lists)
    print(place_lists)
    search_area.clear()

    # 우선 더보기 클릭해서 2페이지
    try:
        driver.find_element_by_xpath(
            '//*[@id="info.search.place.more"]').send_keys(Keys.ENTER)
        sleep(1)

        while True:
            # 2~ 5페이지 읽기
            for i in range(2, 6):
                # 페이지 넘기기
                xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
                driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
                sleep(1)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                place_lists = soup.select('.placelist > .PlaceItem')  # 장소 목록 list

                print(place_lists)

                crawling(place, place_lists)
            
            xPath = '//*[@id="info.search.page.next"]'
            driver.find_element_by_xpath(xPath).send_keys(Keys.ENTER)
            sleep(1)

    except ElementNotInteractableException:
        print('not found')
    finally:
        search_area.clear()

def crawling(place, place_lists):
    """
    페이지 목록을 받아서 크롤링 하는 함수
    :param place: 리뷰 정보 찾을 장소이름
    """
    while_flag = False
    for i, place in enumerate(place_lists):
        # 광고에 따라서 index 조정해야함
        if i >= 3:
            i += 1

        place_name = place.select('.head_item > .tit_name > .link_name')[0].text  # place name
        place_address = place.select('.info_item > .addr > p')[0].text  # place address

        detail_page_xpath = '//*[@id="info.search.place.list"]/li[' + str(i + 1) + ']/div[5]/div[4]/a[1]'
        driver.find_element_by_xpath(detail_page_xpath).send_keys(Keys.ENTER)
        driver.switch_to.window(driver.window_handles[-1])  # 상세정보 탭으로 변환
        sleep(1)

        print('####', place_name)

        # 첫 페이지
        extract_review(place_name)

        # 2-5 페이지
        idx = 3
        try:
            page_num = len(driver.find_elements_by_class_name('link_page')) # 페이지 수 찾기
            for i in range(page_num-1):
                # css selector를 이용해 페이지 버튼 누르기
                driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                sleep(1)
                extract_review(place_name)
                idx += 1
            driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 5페이지가 넘는 경우 다음 버튼 누르기
            sleep(1)
            extract_review(place_name) # 리뷰 추출
        except (NoSuchElementException, ElementNotInteractableException):
            print("no review in crawling")

        # 그 이후 페이지
        while True:
            idx = 4
            try:
                page_num = len(driver.find_elements_by_class_name('link_page'))
                for i in range(page_num-1):
                    driver.find_element_by_css_selector('#mArticle > div.cont_evaluation > div.evaluation_review > div > a:nth-child(' + str(idx) +')').send_keys(Keys.ENTER)
                    sleep(1)
                    extract_review(place_name)
                    idx += 1
                driver.find_element_by_link_text('다음').send_keys(Keys.ENTER) # 10페이지 이상으로 넘어가기 위한 다음 버튼 클릭
                sleep(1)
                extract_review(place_name) # 리뷰 추출
            except (NoSuchElementException, ElementNotInteractableException):
                print("no review in crawling")
                break

        driver.close()
        driver.switch_to.window(driver.window_handles[0])  # 검색 탭으로 전환


def extract_review(place_name):
    global driver

    ret = True

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 첫 페이지 리뷰 목록 찾기
    review_lists = soup.select('.list_evaluation > li')
    
    
    # 리뷰가 있는 경우
    if len(review_lists) != 0:
        
        for i, review in enumerate(review_lists):
            
            comment = review.select('.txt_comment > span') # 리뷰
            rating = review.select('.grade_star > em') # 별점
            val = ''
            if len(comment) != 0:
                innersearchList = []
                if len(rating) != 0:
                    val = comment[0].text + '/' + rating[0].text.replace('점', '')
                    innersearchList.append(place_name)    
                    innersearchList.append(comment[0].text)
                    innersearchList.append(rating[0].text)
                else:
                    val = comment[0].text + '/0'
                    innersearchList.append(place_name)    
                    innersearchList.append(comment[0].text)
                    innersearchList.append(0)
                print(val)
                
                searchList.append(innersearchList)

    else:
        print('no review in extract')
        ret = False
    return ret
    
    
if __name__ == "__main__":
    main()
# Out:
# ##### 0
# #### 더파이홀
# 보통이에요/3
# 신세계, 그러나 사악한 가격 ㅜㅜ 그리고 화장실 가면 화장실 나방? 맨날 있음....../3
# 분위기도 좋고 맛있었습니다 파이 먹고싶을때 첫본째로 생각나는 것이에요  /5
# 맛있음.친절 피넛초코ㅡ맛있음, 바삭 다음에 딴것도 먹어볼것. 재방문의사ㅡ85퍼/5
# 초코파이.. 찐한 맛 ㅠ/5
# 전 그냥 그랬어요 ...ㅎㅎ/3
# 위생 관리 제발 하세요 코로나가 아니어도 기본적으로 음식 위에 뭘 덮어놔야 하는거 아니에요?/1
# 예전부터 자주 갔어서 오늘도 포장하러 갔었는데, 위생에 정 떨어졌어요ㅠㅠ  로투스 타르트 주문해놓고 스콘도 시킬까 싶어서 봤는데, 스콘 들어있던 진열장? 안에 큰 날파리가 3-4마리 있었어요. 당연히 스콘 위에도 앉았고요.  좀 아닌 거 같아서 말씀드렸는데, 그 스콘들을 따로 빼는 게 아니라 그냥 맨손으로 (스콘에 맨손 닿음) 날파리 쫓으셨어요. 별 신경 .../1
# 일부 메뉴들이 진열장 밖에 있어서 조금 위생적인 부분이 신경쓰이기는 하는데 파이는 맛있당 오레오말차가나슈 최고,,,, 항상 사람들이 붐벼서 요즘은 잘 못가겠지만 파이 존맛/4
# 최고예요/5
# 맛있었어요~ > </4
# 보통이에요/3
# 얼그레이 맛있어서 눈물 한방울/5
# 밀크티가 너무 써요.... 따로 준 시럽 다 넣었는데도 쓴 맛이 나더라구요../4
# 언제나 만족. 사람 밀도가 높은 것은 감내해야./5
# 맛은 4점인데   분위기가 최악.... 정말 최악.... 시장통 + 구린 인테리어/3
# 좋아요/4
# 맛있다 인테리어가 먼지쌓이고 좀 정신사납지만 어차피 파이먹으러 가는 곳이니 괜찮다/5
# 최고예요/5
# 신촌에 친구들 놀러오면 무조건 데려가는 카페! 분위기도 나름 좋고 얼그레이 가나슈 존맛.. 파이 종류 왠만하면 다 맛있어요 음료는 그냥저냥입니당/5
# 이제 화석학번이지만 (또륵) 연대생중에 파이홀 모르는 사람 없을 정도로 유명한 곳.. 신촌에 친구들 놀러오면 호불호 안갈리고 좋아해서 추천하는 카페 중 하나입니당 /4
# 다른 파이는 다 평균치는 데..레몬머랭파이는 제발 절대 드시지마세요....제발...아이셔 10개씩 먹을 수 있는 분 아니면 먹지마세요. 솔직히 이렇게까지 유명할 일인가? 싶긴해요. 세네번 가긴했는데 유달리 맛있는 맛이라 찾아갈 정도는 아닙니다.  /2
# 빵굽는 향이 기분좋다.은근넓다 좀 복작거리지만  파이도 맛있고 음료도 맛있지만 음료는 흠 완벽하진않다. 파이를 직접 다 굽는다 해서 흥미로웠는데 보기도 이쁘고 맛도 좋다 하지만 미치겠어~~~!!!하는 맛은 아닌들.주변에 갈일있으면 들릴만하다/4
# 7월 중순 즈음에 방문했는데, 사람은 좀 많았지만 여깃 유명한데에는 이유가 있더라구요.. 맛이 최곱니다.. 메뉴명은 정확히 기억나지 않지만 레몬맛과 얼그레이 초코맛으로 골랐는데 정말 너어무 맛있었습니다...(*´︶`*) 신촌 가는데 맛있는 디저트를 먹고싶다! 하시면 여깁니다..b/5
# 쿠키랑 커피랑 너무 잘어울려용...  분위기도 좋았어서 다음에 또 올것 같아용/4
# 추가합니다) 파이홀 당신,, 쿠키가 맛있으면 그렇다고 말을 해줘야져,,,, 세상에 스모어 진짜 맛있었어요,,,, 사랑해,,, 원문) 맛 없진 않아요. 그냥 그렇습니다. 커피 파이 둘 다 그냥 그래요. 가격은 꽤 높은 편입니다. 여기도 웨이팅 하면서 먹을 곳은 아니고 가끔 생각나면 파이 한 조각씩 포장해가면 좋을 것 같아요. 신촌에 디저트집이 마땅한데가 없어.../3
# 맛있는 파이집. 공간 대비 항상 사람이 많아 여유로운 분위기를 느끼기는 조금 어려운 것 같지만 맛있으니 갑니다. 얼그레이 가나슈와 말차가 제일 무난하고 깔끔하게 맛있는 메뉴에요./4
# 좋아요/4
# 무난하게 디저트 먹고싶을때 가기 좋음/4
# 맛있는데 사람개많음/4
# 얼그레이 가나슈 너무 맛있음 녹차가나슈인가 그건 진짜 별로 밍밍해요 녹차가 더 진해야함../4
# 얼그레이가나슈가 맛있는. 공간은 별로/4
# 보통이에요/3
# 디저트 알못이라 그런지 잘 모르겠음 메뉴 탓인가 하고 전 메뉴 다 먹어봤는데도... 근데 맛없지는 않아요 말차인가 그건 클로렐라 맛 나서 0점 주고 싶음...../4
# 다 맛있어요 브라우니와 얼그레이파이 강추/5
# 최고예요/5
# 유명하다 해서 왔는데 대기 시간 꽤나 있었고, 케익도 그저 그랬던 기억이./3
# 너무 기대하고 가면 실망할지도/3
# 사람이 많아서 좀 많이 기다렸어요. 하지만, 그만큼 맛이 너무 좋았어요!ㅠㅠ 사과파이 무척 좋아하는데 앞으로 여기만 갈것 같아요~ㅎㅎ/4
# 애플파이에 아이스크림 올려달라했는데 첫번째 사진처럼 아이스크림 다 흘러내린 상태로 나옴 그래서 원래 이렇게 나오는거냐 물었더니 파이 데워서 그렇다고 함 근데 예전에 먹었을땐 두번째 사진처럼 깔끔하게 올려 나왔음 당연히 파이 데웠으니 어느정도 녹는건 이해하지만 첫번째 사진처럼 물처럼 녹은건;; 그럴거면 아이스크림을 왜 올려요.. 빡쳐서 다시 말하니까 파이 안.../2
# 파이 맛있음, 항상 사람 많음. /4
# 좋아요/4
# 가끔 이상하리만치 원재료원재료스러운거 빼면 정말 괜찮아요. 홍차스콘이랑 얼그레이가나슈 딸기크림치즈(?) 존엄스러운 맛/4
# 왜...?/1
# 조금 아쉬워요/2
# 올라가는 크림 양이 복불복이라 좀 별로지만 그래도 맛있다/4
# 마싯어유 ~ 담엔 아이스크림 올려먹고싶어용/5
# 예전만큼 못하다 스콘에 올라가는 크림이 참 맛있었는데 크림 올려주는 양이 줄었고 파이 크기도 줄었고  파이 맛도 스테디셀러 몇개 제외하고는 아쉬울때가 많아서 새로운 메뉴 시도하기 꺼려짐/2
# 기념일날 맞춤파이제작했는데 앞으로 여기서만 할려구요! 맛도있고 예뻐요 /5
# 조금 아쉬워요/2
# 예전에는 다 특별하고 맛있어서 단골이었었는데 요즘은 파이들을 한번에 너무 많이 만드셔서 그런지 얼어서 나올때가 많고.. 금방 색도 변하고..ㅠ 장소가 너무 시끄럽고 별로예요... 지금의 퀄리티에 비해서는 가격도 너무 비싼 것 같아서 안찾게 되네요/2
# 좋아요/4
# 좋아요/4
# 디저트 맛나지만 의자가 등받이 없어서 불편 ㅠ/5
# 최고예요/5
# 얼그레이 머시기 파이 정말 실망... 초콜렛무스?가 정말 별로였음 초콜렛부분 다남겼고 커피도 썩.../3
# 괜찮은데 사람 너무많고 자리좁음 ㅜㅜ/3
# 아늑하고 스콘이랑 디저트가 맛있네요! 직원들도 친절해요/5
# 예전에 조그만 곳에 있을때는 평일에도 식사시간 이후에는 자리 거의못잡았음. 파이홀을 더 큰 곳으로 보내준 건물주께 ㄹㅇ 감사/5
# 밤콩가루랑 호박이 개인적으로 제일 맛있다 오레오말차는 무난했고 얼그레이가나슈는 제일 유명하다는데 내입맛에는 제일 별로였다...크림이 너무 느끼하고 많고 얼그레이향도 딱히..?결국 그냥 크림 거의 걷어내고 먹음/5
# 맛없음. 뭐가맛있다는건지? 그냥애들이먹기에 괜찮은가봄/1
# 파이 맛있다구?? 잘모르겠다. ./2
# 초콜릿 올려진 파이는 맛있었는데. 그 베리 어쩌구 파이는 너무 과했다 너무 달고 시고 너무 많이 올려져있어서 거의 남겼다../3
# 비싸고 사람 많고 음료가 그저 그럼 근 데 파이가 이 모든걸 상쇄시킴... 파이 너무 맛있음...  근데 너무 비쌈... 울면서 먹음/4
# 사람 (평일이었는데도) 오후에 진짜 많아요! ㅎㅎ 좌석 잡는 게 되게 자유로운 분위기인데 타이밍 잘 맞춰서 운 좋게 자리 잡았습니다(사실 2번째 시도) 파이 정말 맛있어요 ;)/5
# 그닥/3
# 실패없는 디저트 맛집/5
# 청키한 애플 잔뜩 있는 애플파이 찾다가 요기와서 라즈베리루바브 삿어요! 크럼이 맛있어보여서ㅎㅎ 이집 파이 잘굽네요! 애플파이 없어서 못샀지만 담에 또 사러 가보려구여!/5
# 음료는 별로지만 타르트가 맛있어요! 특히 핫초코 별로... 음료가 맹맹해서 별 하나 깍아요/4
# 인기많아요!! 파이 종류도 많고 일찍오면 좋을거같아요/4
# 오레오말차파이 맛있어요 ! 흑임자 파이는 무난했고 커피양이 너무 적었어요. 얼음만 많이 주셔서;/3
# 좋아요/4
# 파이가 맛있다!!!! 레몬 파이(대존맛)/ 얼그레이 파이(크림만 먹어도 느끼하지 않아서 좋았다)/ 카페라떼 아이스총 17500원.. 저렴한 가격은 아니지만 맛있었다!! 또 갈거다 월 저녁시간에 방문했는데 사람이 많아서 약간 크게 말해야한다. 시끄러운 분위기였는데 10시 지나니까 좀 사람 빠지고 조용해 졌다./4
# 최고예요/5
# 좋아요/4
# 파이가 맛있게 만들어졌어요!/5
# 좋아요/4
# 최고예요/5
# 좋아요/4
# 최고예요/5
# 맛있다/4
# 여기 말차오레오파이가 최고예요 ㅠㅠㅠ 녹차 덕후 필수 방문!! 카페 아기자기하구 이뻐요 ㅎㅎ/5
# 신촌 파이 명가 자주 가보지 못해서 최애메뉴를 찾진 못했지만 전체적으로 괜찮은 메뉴들이다. 가격이 약!간 비싸긴 하지만 선물용으로도 좋고 새로 가게도 이전해서 분위기도 좋고 한번쯤 들릴만한 곳 + 2차후기 두번들려 세번들러요ㅠ 음료는 복불복이라 맛있는거 시키면 존맛이고 티 종류는 주관적으로 싱거웠다 ㅠ (체리스트로베리티인가..)어쩔수 없지만 아쉽.. 집에 .../3
# 따뜻하고 다정한 느낌/4
# 신촌에 딱히 개인 케익집이 없는데 파이홀이라도 잇어서 다행이에요 이전한 가게 분위기 좋고 들어가면 오븐에서 풍기는 버터향도 좋아요 접근성이 예전보다 좋아져서 그게 가장 좋아요ㅎㅎ 뭔가 예전보다 케이크 크기가 작아진 느낌이 잇는것 같기도 한데.. 딸기 케익 맛잇어요 근데 얼그레이는 얼그레이와 꾸덕한 초코가 따로 노는 느낌이 잇어요 얼그레이는 나중에 안먹을 것.../4
# 오레오말차 얼그레이가나슈/5
# 좋아요/4
# #비엔나커피, 모히또/2
# 보통이에요/3
# 파이 다 맛있어요~~^^ 포장도 해가네요/5
# 얼그레이 가나슈가 정말 맛있어요! 장소이전 하고나서 테이블도 많아졌고 접근성도 좋아졌어요. 1인 1메뉴 필수!/4
# 최고예요/5
# 얼그레이가나슈최고!!!/5
# 최고예요/5
# 분위기는 적당히 활기차고 적당히 조용한 느낌. 가격대는 그런 류의 카페에 알맞는, 납득할 수 있는 수준이었다. 디저트가 신경 써서 만든 느낌이 많이 났는데, 전반적으로 단맛이 강한지라 홍차류의 음료에 곁들이는 것이 좋은 듯./4
# 파이 다 맛있고 가게도 예쁘고 사장님도 예쁘고/5
# 특별한날 미리 주문하는 수제파이가 있어서 좋당/4
# /0
# 케익 파이맛난집/0
# 아몬드코코넛파이와 딸기크림치즈파이 강추!/0
# 사장님의 배려도 커피맛도 케이크도 좋다. 인테리어는 직접하신 거라던데.. 난 정말 좋아하고 편하게 생각하는 곳- 갠적으론 민트초코파이, 레몬치즈타르트, 얼그레이무스, 당근케이크...등등이 좋다ㅋ/0
# 믿고 먹는 파이! 미녀 사장님이 직접 굽는 파이와 쿠키 스무디 커피 다 맛있음! 신거 안 좋아하는데도 여기 레몬파이 먹고 반함!/0
# 짱 거대한 브런치/0
# 좋아요! 언니 친절하시구 가격도괜춘/5
# no review in crawling
# #### 고르드
# 빵에서 아무맛도 안남/1
# 걍 쏘쏘/3
# 크리스마스 케이크 16000원인데 존예예요/4
# 딸기라떼는 절대 먹지마세요. 딸기로 만든 게 아니라 제티맛이에요. 아기들 먹는 감기약 맛 나요./1
# 한번은 가기 좋은곳이에요/3
# 조금 아쉬워요/2
# 모카빵 덕후인데 맛있음. 모카크림도 서비스로 줌. 나머지빵은 쏘쏘/4
# 마카롱만 맛있음 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 가성비 좋음 ㅠㅠㅠㅠㅠㅠㅠㅠㅠ ╥﹏╥  but. 케이크, 스콘, 커피 다 맛없어 마카롱만 맛있음 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ/4
# 스콘 후기가 너무 안 좋길래 괜히 도전의식 자극되어 도전해봤는데 왜 그랬을까요????? 내가 초등학교 5학년 해피쿡으로 만든 초코스콘이 이것보다 맛있는듯???? 평점 잘 안 다는데 진짜 이건 레전드다. 모든 내용물이 따로 놀며 밀가루의 텁텁함이 내 입을 싹 감싼다. 차라리 밀가루 죽을 퍼먹겠습니다!! -케이크와 스콘을 3만원어치 사버린 사람이-/1
# 케이크 먹지마세요 절대루.. 스콘은 시도도 하지마세요 대체 어떤 맛일까 궁금하시더라도 시도하지 마세요 로또 1등 당첨되신거라면 시도해도 안말림/1
# 자칭 스콘감별기임. 눈으로만 봐도 맛있을 지 없을 지 구별할 줄 알아서 딱 봐도 맛없어 보이길래 스콘은 안 사먹음 케익류도 가격에 비해 퀄리티가 흔한 카페 케익 처럼 보이길래 빵류와 손바닥만한 마카롱만 먹어봄. 마카롱 악평이 많은데 내가 먹었을 때는 꼬끄 잘 구워지고 밀도가 괜찮아서 적당히 쫀득하고 맛있었음. 필링은 흔한 버터크림 필링인데 많이 느끼하지 않.../4
# 오페라 진짜 맛없어요 크림이 딱 싸구려라는게 느껴지고 식물성 크림 사용하는 것 같네요 베스트라는 크림빵도 별로예요... 파리바게트나 뚜레쥬르 가서 가성비라도 챙기는게 나을듯/1
# 왈/4
# 좋아요/4
# 앙버터 마카롱 크기는 진짜 큰데...좀 아쉬워요 꼬끄가 너무 딱딱해서/2
# 이렇게 맛없는 스콘은 처음 먹어봤습니다. 마카롱도 같이 싰는데 기대가 안되네요  저만그런가 싶어서 주변 지인들 한입씩 먹였더니 다 별로라고 합니다 빵을 만드는데 계량 제대로 하신거 맞으세요?/1
# 아무 맛도 안나요. 인생 최악의 스콘입니다. 스콘에서 이런 맛니 나는구나 싶어서 놀랍기도 해요. 또 일하시는 분은 포장해달라니까 계산 다하고 그제서야 봉투 50원이니 따로 달라고 하고.. 이게 뭔가 싶네요. 물어보지도 않으셨으면서/1
# 얼그레이 밀크티는 보완 좀 많이 하셔야할 것 같습니다. 밀푀유? 라는 케익을 먹었는데 먹기가 불편했어요. 자를수도 없고 겹겹히 쌓여있는데 그 위에 크림까지 얹어있으니 먹기가 매우 불편했습니다..ㅠㅠ 보기만 좋은 디저트였어요/2
# 제입맛에는 별로..ㅜㅠ/1
# 앙버터 진짜 맛있던데..? 마카롱은 다음에.. 스콘은 쏘쏘. 그래도 신촌 최고 빵집인듯./5
# 아래 후기는 얼마나 맛있는곳에서 드셨는지 모르겠지만 ㅠㅠㅠ 여기 앙버터(미니) 진짜 좋아해요!!! 다른데보다 겉은 바삭 하고 속은 또 앙버터로 차있어서 달달하니!! 다른데는 질겨서 여기가 제일 좋아요! 항상 지인들 데려가는 곳이에요/5
# 앙버터 맛집이라고 유명하지만 대체적으로 딱딱하고 질겼습니다. 빙수랑 오페라가 맛있어요/3
# 앙버터 마카롱 많이 달지 않고 주먹만한 마가롱~ 맛 있어요/4
# 대체 맛있었다는 분들 무얼 드셨는지 알려주세요.. ㅠㅠ 3번의 실패.. 뻑뻑하고 달고 그렇게 맛있지 않은데 가격은 비쌈/1
# 2년 전에 처음에 왔어요. 케이크와 샌드위치가 정말 맛있는데 2년이 지났지만 인터넷은 여전히 좋지 않네요./4
# 보통이에요/3
# 짱맛/4
# 최애빵집/5
# 스콘은 별로. 유명하다는 앙버터도, 커피도 so-so. /2
# 무난한 빵집!/3
# 마카롱 꼬끄 잘못구운 걸 파는 노양심인 곳. 이자국 난 거 보이시나요? 돌덩이인 줄 알았고요? 꼬끄도 못굽는 곳이 무슨 베이커리맛집입니까? /1
# 별 하나도 아깝네요.  빵도 비싼데 맛도 없고 차라리 파리바게트가 가성비도 좋고 맛있을듯.   줄서서 먹길래 옥수수스콘 초코슈 딸기 케익을 먹었는데 돈이 너무 아까웠어요. 스콘은 밀가루랑 계란 냄새 밖에 안나구요 초코슈는 새우를 넣었나 싶을 정도로 구린내가 나고 케이크는 이렇게 만들기도 어려울 정도로 맛없어요. 두번다시 안올 거 같습니다/1
# 별 하나도 주기 싫어요.  케이크 진짜 맛없고 비쌈. 스콘은 밀가루랑 계란맛만 납니다. 어휴...나 같은 돼지가 먹다 남기기 처음./1
# 보통이에요/3
# 좀 비쌈/4
# 좋아요/4
# 아마드 잉글리쉬 브렉퍼스트 크레이프 케이크 베리 버라이어티 타르트  신촌에서 예쁜 조각 케이크가 먹고 싶다면/2
# 빵 맛 괜찮은데 가격이 조금 비싸다 위층의 카페 자리 편안하고 좋다/3
# 보통이에요/3
# 보통이에요/3
# 좋아용/5
# 여기 3층에 식사도 되는데, 샐러드 피자 파스타 다 괜찮았다. 서비스도 센스있고 친절하다. 여럿이 가서 식사하고 차도 마시고 오래 시간보내기 편한 분위기 :)   가격에 걸맞는 맛이 나오는, 신촌에서 갈 만한 곳!!/4
# Town Bakery Also in Myeongdong/3
# 타르트.케잌.  /1
# 빵이 너무 딱딱해서 이빨 부러지는 줄 알았다. 굳이 줄서서 먹을만큼의 베이커리는 아닌 듯!/2
# 앙버터는 최고입니다. 겉은 낙엽처럼 바싹하고, 속은 부드러운바게트와 팥의달콤함과 버터의 부드러움이 조화로운 비율이 왁벽합니다. 커피도 완전 마음에 드네요./4
# 스콘 진짜 짱맛ㅠㅠㅠㅠㅠ 베이커리류가 맛있어요/5
# 좋은 사람들과 함께 하기 좋아요/5
# 최고예요/5
# 1층은 베이커리고 2층은 카페인 듯 했다. 앙버터빵이랑 밤식빵 먹어봤는데 꽤 맛있었다. 특이한 빵들도 있던데 다음엔 다른거 먹어봐야지!/3
# 보통이에요/3
#  분위기  ❤❤❤❤♡ 평일 오후 3시즈음 둘이서 방문하였는데 너무 시끌벅적하지도 않았어오. 시간이 지날수록 2층에 사람이 많어지다보니 시끌시끌하긴했지만 둘이서 대화나누는데 큰 방해가 있거나 하진 않았습니다.   좌석 ❤❤❤❤❤ 좌석은 딱딱한 의자도 있구 쇼파도 있어서 사람이 많지 않을 때 골라앉는 재미가 있어오.  맛 ❤❤❤❤❤ 안에 브라우니가 든 페스츄리.../5
# 조금 아쉬워요/2
# 보통이에요/3
# 앓다가 드디어 먹으러간 청포도타르트/3
# 보통이에요/3
# 좋아요/4
# 1층 베이커리에서 음료와 케익 구매 후 3층 매장 이용 2층에서는 음식 판매 얼그레이티 맛이 좋고 케익 맛도 괜찮음 창이 커서 답답하지 않고 자리가 편함/3
# 최고예요/5
# 좋아요/4
# 학교앞 검증된빵집 ㅎㅎㅎ/5
# 신촌에 새로생긴 베이커리 겸 카페 거의 모든 빵에 시식을 할 수 있어서 좋고 시식양이 꽤 많다 게다가 하나같이 빵이 다 맛있다는거.......... 그냥 들어가봤다가 빵 몇 개 샀다ㅋㅋㅋ 제일 맛있었던건 크림치즈화이트!/3
# 좋아요/4
# 당근케이크♥/4
# 보통이에요/3
# 모양 좋은 케잌이 맛나보여 베스트라는 밀푀유인가를 밥값에 해당하는 6500원 주고 샀는뎅... 크림이 밍밍한 버터 덩어리 먹는 맛이네여^^;;/1
# 맛은있는데 직원들이 미숙하고 무개념.,  포장하는데 빵떨어뜨리지를 않나 그거그냥주던데요..? 알바를 너무많이두는데 하나같이 어리고 미숙한애들뿐임/2
# no review in crawling
# #### 그릭데이 이대점
# 요거트랑 코코넛이랑 사서 집에있는 꿀이랑 같이 섞어 먹었는데 맛있었어요!! 다만 알바생분은 상당히 불친절해요.. 갔다가 좀 어이없긴 했는데 맛있어서 별3개 드릴게요/3
# 요거트가 굉장히 꾸덕해서 진짜 수제요거트 먹는거 같았어요 이런거 좋아하시는분들은 잘맞을거같네요/5
# 좋아요/4
# 토핑/잼 종류가 다양하고, 빨리 만들어주셔서 좋아요! 그런데 요거트 자체는 고스트요거트가 더 맛있어요. 둘이 왔다갔다 거리면서 먹어요 ㅎㅎ/4
# 좋아요/4
# 맛은 별 다섯 개. 친절도는 마이너스 주고 싶음. 위생은 잘 모르겠음./2
# 요거트랑 과일 담는 손으로 돈만지고 카드만지고 영수증만지고... 위생도 별로고 직원분들이 너무 너무너무너무 천천히해요ㅠ 저도 알바생 입장으로 이해는 가지만 줄이 정말 길게 서있는데도 태평하게 하는 모습보고 놀랐어요 다른 지점이랑 너무 비교돼요 다시는 안오려고요/1
# 토핑도 종류가 다양하고, 요거트도 꾸덕꾸덕하고 아주 맛있습니다/5
# 좋아요/4
# 식사대용으로 좋은것 같아요~/4
# 비싸고 양 적은건 사실이지만 너무 맛있어요,, 좁은 공간에 사람이 많아서 불편하긴 했지만 이대쪽으로 가게되면 생각나는 집이에요. 간단한 식사 대용으로까지 괜찮았어요. /5
# 응대가 친절하긴한데 양이 적고 돈 만지신 손으로 이것저것 하셔서 좀 그랬어요 ㅠㅠ /3
# 그릭데이 처음가봤는데 응대가너무 불친절해서 아쉬웠습니다. 친구들한테도 직원이 너무 불친절하다는 소리는 들었는데 이정도인지는 몰랐어요. 좀 더 친절하면 좋겠습니다. 맛은 있어요./1
# 맛있게 잘먹었다아 자꾸생각나는맛 ㅠㅠ/5
# 다른지점가세요 여기는 싸가지없고 창렬입니다./1
# 양이 예전보다 많이 줄었지만 여전히 내 최애/4
# 처음 먹어봤는데 야무지고 참신하다  근데 우리가 생각하는 그런 흐르는 액체 요거트가 아니고 딱딱하다 한번쯤 다시 먹어보고 싶은 그런 맛/4
# 조금 아쉬워요/2
# 요즘 왜이렇게 양을 줄이시는지? 예전에는 듬뿍듬뿍 담아주시더니.. 이젠 돈이 너무 아까워서 안갑니다 ㅠㅠ/2
# 창렬이고 겨털인지 뭔지 나온 적 있어요 ㄹㅇ 겨릭데이/1
# 다른 지점에 비해 너무 창렬함 호구 됨/1
# 처음가봐서 꿀을 뺏는데 꿀은 필수입니다.  목막혀요. /3
# 다른 지점에 비해 양도 적고 위생 별로인적 많음/1
# 굳이? 꼭 먹어야겠다면 다른 지점을 가세요/1
# 완전 맛있어요~~! 매일가는중 ㅋㅋ 알바생?직원분도 친절하고 토핑도많이주시고 먹으면 완전든든해요 ㅎㅎ 꿀 많이 안준대서 걱정했는데 양이 많더라구요!! 오늘도 가는중이요~~ ㅋㅋ/5
# 그리.. 맛있는지 모르겠음 한번쯤 먹어볼 만/3
# 별로예요/1
# 진짜 좋아하는 곳인데 허니 스쿱 꿀 양이 엄 청 나 게 줄은 건지 아무리 시켜도 꿀이 없어서 꿀 더 추가했는데도 거의 없고.. 꿀이 들었는지 안 들었는지 먹고 나서야 알 수 있으니 따질 수도 없고../3
# 좋아요/4
# 최고예요/5
# 존맛탱/5
# 맛있어요/4
# 깔끔한 요거트!/5
# 양은 정량이 있다고 하는데 만드는 사람마다 조금씩 차이가 있다. 한끼정도는 배부르게 먹을 수 있고, 로즈그레이 최고!!!!!!!! 다만 너무너무너무너무 사람이 많아서 예상시간보다 더 오래 걸릴 수 있으니 시간을 두고 가길/5
# 최고예요/5
# 무슨말이 필요하리오.... 인생요거트집ㅠㅠㅠ 극극극극극강추 별다섯개 뿌시고 백개주고싶엉 ㅜㅜ/5
# 그릭데이는 내 종교다/5
# 흑 오래오래 장사해주세요/5
# 최고예요/5
# 다양한 토핑의 요거트를 골라먹을 수 있어 좋아요~~사이즈별로 있어서 간단하게 끼니 떼울수도 있고 요거트가 치즈처럼 쫀득쫀득해요!/5
# 그릭데이 사랑합니다. 이대앞 맛집중 최고! 오이번가의 자랑! 진짜 매일가고있어요...리터러리...1일1그릭데이...대신 줄은 조따길지만..그릭데이를 위해서라면 그정도는 감수할수있습니다^^ 대신 30분이상 기다릴 각오는 해야합니다ㅎㅎ (저는 50분만에 먹은적도 있습니다...ㅎ)/5
# no review in crawling
# #### 에이투지카페
# 매장분위기가 좋아요 ~~ 자주올듯/4
# 화장실 냄새가 카페 전반에 깔려있고, 젊은 남자 알바 불친절. 시종일관 에어팟 꽂고 있고 주문 다 받아놓고 뒤늦게 안된다고 하면서 오히려 자기가 불편하다는 표정과 말투 왜그럼?ㅡㅡ 손님 받는 거나, 음료 만드는 거나 걍 다 귀찮고 싫은 듯한 태도. /1
# 매장이 넘 예뻐요. 투웅엥 티라미수보다 맛있어요. ( 더 비싸니깐,,ㅎ) /4
# 딸기라떼랑 치즈케이크 ㄱㅊ음  그치만 내부 인테리어가 좀더 예뻤으면 자주갔을듯/3
# 딸기라떼가 예쁘게 잘 나오고 매장 분위기가 편안해요/4
# 맛은 있었지만 비싼감이 없지않아 있었구 분위기랑 인테리어는 무슨 컨셉인지 음료랑 같이 나오는 공룡때문에 더 모르겟는 카페예용.. 딸기라떼가 궁금하시면 한 번쯤 가볼만은 해유/3
# 불친절하다 화장실 냄새와 방향제 냄새가 독하다/1
# 신촌 예쁜 카페. 자리도 좋고, 뭔가 또가고싶은 느낌이드는 그런곳/4
# 딸기라떼 시그니처 맛있어요/4
# 고풍스럽고 아늑한 느낌 비싸지만 실패하지 않을 확률이 높다:)/4
# 넘넘 예쁘고 깨알 공룡도 귀엽! 다만 메뉴판은 비친절/4
# 비주얼이 예뻐서 sns에 자주 올라오는 곳인데 sns맛집들이 그렇듯 딱히 대단하진 않음/3
# 디스플레이가 매우 예쁜 카페! 분위기 앤틱하고 좋다! 커피로는 아인슈페너 추천!/5
# 보통이에요/3
# 보통이에요/3
# 교생모임!  제일유명하다는 딸기라떼 예쁘긴예쁘다  다음에 가게되면 요거트를 먹어야겠다/3
# 에이투지 카페에서 제일 잘나가는 딸기 라떼 시켰는데 직원은 저회 잊어 버리셨어용;; 그래서 서비스로 치즈케이크를 받았는데  너무나 맛있었어용 최고의 치즈케이크 드시고 싶으면 에이투지 카페에 가보세요 ~~/4
# 좋아요/4
# 신촌에 진짜 몇없는 개인카페인뎅 이뻐용ㅋㅋㅋ 분위기가 좋고 사진찍을맛 나는곳  /3
# 좋아요/4
# 좋아요/4
# 신촌에서 점심! 리코타치즈샐러드 맛있당/0
# 조용하고 좋다!/0
# 딸기라떼~♥♥♥ 라즈베리치즈케이크~♥ 상큼상큼!!!/0
# 분위기좋고 맛있는음료♥/0
# 로제파스타와 후식류는 갑갑/0
# 음료와 함께 나오는 아기자기 피규어들. 맛있는 홈메이드 음료./0
# 브런치카페/0
# 샹그리아 피쳐   분위기좋은 신촌카페/0
# 분위기 좋아요^^b 친구들이나 연인끼리 오는거 추찬 합니당. 개인적으로 로제 치킨파스타가 참 맛있어요///4
# no review in crawling

# %%
searchList
# Out:
# [['카페노티드 안국', '맛있어요 좀 비싸긴하지만 늦게가면 남은거없음  요즘 코로나라 사람 덜함', '4점'],
#  ['카페노티드 안국', '밀크 존맛♡', '5점'],
#  ['카페노티드 안국', '맛은 있는데 항상 웨이팅이 길고 남은 메뉴가 몇 개 없네요 아쉽', '4점'],
#  ['카페노티드 안국',
#   '맛은..평범해요.. 한사람이 도넛 계산 후 도넛을 받을 때까지 그 뒷 사람 주문을 안받아서.. 사람들이 대기줄이 생길 수밖에없어요 ㅎㅎ',
#   '2점'],
#  ['카페노티드 안국', '존맛탱', '5점'],
#  ['카페노티드 안국', '좋아요', '4점'],
#  ['카페노티드 안국', '그냥 무난무난 .. 직원들이 너무 서로 친한듯^^;;', '3점'],
#  ['카페노티드 안국',
#   '오늘 기준으로 저는 약 20분 정도 줄 섰구요 은근 기대하고 갔는데 저는 정말 맛있게 먹었어요! 리뷰가 왜이렇게 낮은지 모르겠지만 한국에서는 잘 먹을 수 없는 종류의 도넛 같아요ㅎㅎ  무엇보다 크림이 전혀 안달아서 제일 좋아요 다만 단점이 있다면 각격이 조금 비싸다는거?ㅠ 저는 정말 맛있게 먹었고 조만간 또 사먹으러 갈 것 같아요!',
#   '5점'],
#  ['카페노티드 안국',
#   '너무 극찬하길래 직접 가서 포장해와서 먹어봤습니다.... 패키지랑 컨셉은 진짜 잘하신듯합니다만, (단연 돋보여요. 이거 하신 작가님 작품들도 다 귀염뽀짝하고 예쁘네요☺)  맛은 기대 이하였습니다 ㅠㅠ 가격대비도 별로구요... 그냥 던킨먹을게요 ㅠㅠ 사람마다 입맛은 다 다르니께유...',
#   '2점'],
#  ['카페노티드 안국',
#   '눈 내리는 날에 가지 마세요. 매장 안에 들어오지 말라고 내쫓깁니다. 인성 쓰레기 같은 남자직원인지 사장인지',
#   '1점'],
#  ['카페노티드 안국', '한번쯤 기다려서 먹어볼만 해요 빵이 부드러워요 ', '3점'],
#  ['카페노티드 안국', '컨셉과 디자인의 승리. 맛 자체는 특별하진 않음.', '3점'],
#  ['카페노티드 안국', '앙버터 젤좋아함 우유크림 예전같지않음 내입맛이 변한건지ㅠㅠㅠ뭔지ㅠㅠㅠㅠ', '3점'],
#  ['카페노티드 안국', '매장 예쁘고, 친절하나 30분 기다려 먹을만큼 특별한 맛은 아님. ', '3점'],
#  ['카페노티드 안국',
#   '하도 인기가 많아서 먹어봤어요  근데 솔직히 딱히 그렇게 큰 맛의 차이는 모르겠습니당 그리고 도넛치곤 너무 비싼 느낌...? 그리고 진짜 달아요 단거 좋아하시는 분들은 좋아할듯 .. 저는 그렇게 생각 나는 맛은 아니었습니다! ! ',
#   '3점'],
#  ['카페노티드 안국',
#   '튀겨서 크림 넣은 종류의 도넛 중엔 가장 맛있는듯해요 잦은 품절이나 긴 웨이팅으로 사기 힘든게 단점 패키지는 매우 귀여움',
#   '5점'],
#  ['카페노티드 안국',
#   '인테리어랑 제품디자인은 귀엽고 이뻐요◡̈♡̴ 도넛 맛은 기대가 커서 실망도 크네요.. 시장에서 파는 기름에 튀긴 도넛에 필링만 넣은 느낌인데 가격이 많이 비싼듯해요.. 필링은 맛있어서 한번쯤 먹어봐도 좋지만 줄서서 기다려서 먹을 정도는 아닌 것 같아요..',
#   '2점'],
#  ['카페노티드 안국', '맛있고 귀여워요', '5점'],
#  ['카페노티드 안국', '맛은 있는데 너무 비싸요', '3점'],
#  ['카페노티드 안국', '예뻐용', '5점'],
#  ['카페노티드 안국', '그냥 도넛', '3점'],
#  ['카페노티드 안국', '^_____^ 귀여워요', '1점'],
#  ['카페노티드 안국', '얼그레이 필링 조금만 더 많으면 넘넘 맛있을 것 같아요! 우유 생크림은 크림 듬뿍이라 존맛', '4점'],
#  ['카페노티드 안국', '고소한 빵+깔끔하고 적당히 단 필링. 도넛 생각날 때 1개씩 사먹을만 합니다.', '4점'],
#  ['카페노티드 안국',
#   '맛 매우 평범. 가성비 생각하면 매우 아쉬움. 근처 프릿츠 커피 커스터드 도넛이 세배는 더 맛있음. 예쁘기 때문에 선물로 좋음.',
#   '2점'],
#  ['카페노티드 안국', '바닐라 크림도넛 먹었는데 너무 평범함. 가성비 창렬', '2점'],
#  ['카페노티드 안국', '우유생크림 도넛이 제일 맛있더군요. 얼그레이도 맛있습니다', '5점'],
#  ['카페노티드 안국', '시장 도넛이랑 큰 차이를 모르겠어요 필링을 넣었다 안넣었다 뿐', '3점'],
#  ['카페노티드 안국',
#   '당일 먹은 도넛은 맛있었어요ㅋㅋ 근데 진짜 아래 후기대로 너무 불친절해요. 말하기 싫은데 억지로 말하시는것처럼...ㅋㅋ 갑질을 하시는건지 뭔지 모르겠지만 불친절해서 다시 방문하기 싫어요~',
#   '2점'],
#  ['카페노티드 안국',
#   '크로와상 너무 달아요 딱봐도 달아 보이는데 가게에서는 미처 판단이 제대로 서지 않았나봐요...  냉장고 넣어놨다 하루 지나서 먹으니까 확실히 도넛이 딱딱해졌더라구요 당일 산 도넛은 당일에 드시는 걸 추천드립니다',
#   '3점'],
#  ['카페노티드 안국', '최고예요', '5점'],
#  ['카페노티드 안국',
#   '남자 직원 진짜 불친절하고 기분 나빠서 안국점은 다신 안감. 도넛 언제 나오는지만 물어봤는데 아 저희도 몰라요~ 안내 제대로 해주지도 않고 사람 무안하게 만들고 여기 리뷰만 봐도 서비스로 말 많은 것 같은데 왠지 알겠음 ',
#   '1점'],
#  ['카페노티드 안국', '도넛이 많이 달지 않고 적당함~!', '5점'],
#  ['카페노티드 안국',
#   '너무 불친절함!! 장사 잘된다고 손님 이런식으로 응대하면 안됨 테이크아웃 줄서라고 하고 안내도 제대로 안하고 몇시부터 영업하냐고 물어보니까 알바생인지 직원인지 신경질적인 어조로 “도넛 11시 부터 하구요 지금부터 할거에요!!” 물어보는것도 잘못인가? 기분더러워서 안사먹음 이딴식으로 하면 맛있어도 망하는건 금방임 명심하셈 알바생 직원 교육부터 다시시키길',
#   '1점'],
#  ['카페노티드 안국',
#   '기본이 안된 점포. 11시 오픈인데 20분 넘도록 안내도 없고 뭘 물어봐도 무조건 줄서세요 라고만 앵무새처럼 응대함. 오전부터 얼마나 피곤하길래 손님들한테 신경질을 내는지... 본인들이 게시해놓은 오픈 시간을 지키거나 오픈이 늦어지니 기다려달라고 안내를 잘 하는게 기본인데, 그런 기본이 안된 점포같음.',
#   '1점'],
#  ['카페노티드 안국', '11시 오픈인데 매장 오픈시간에 준비된것도 없이 줄만 세워두고', '2점'],
#  ['카페노티드 안국',
#   'There were no signs saying what your covid rules are. We tried to go inside to write down our temperature and provide our QR code but we were pushed out the way by people delivering donuts in plastic ...',
#   '1점'],
#  ['카페노티드 안국', '두번갔었는데 두번 다 얼그레이는 솔드아웃이네요. 다음에 갔을 땐 있겠죠..?', '3점'],
#  ['카페노티드 안국', '크림도넛 진짜 맛있음 ㅋㅋ 옛날빵 느낌도 나고', '4점'],
#  ['카페노티드 안국', '좋아요', '4점'],
#  ['카페노티드 안국',
#   '클래식 바닐라 도넛 먹었는데 부드럽고 반죽도 촉촉하고 좋았어요. 근데 다른 바닐라 도넛이랑 다른 점은 없어서 특색있는 도넛(레몬슈가나 얼그레이등)을 다음에 시도 해보려고요. 알바분은 나갈때도 인사해주시고 친절했습니다.',
#   '5점'],
#  ['카페노티드 안국', '알바가 정말 정말 불친절합니다', '1점'],
#  ['카페노티드 안국', '맛이 막 특별한 것도 아닌데 너무 비싸요. ', '2점'],
#  ['카페노티드 안국', '맛있어요!!! 딸기 들어간 거를 꼭 드셔보세용ꈍ◡ꈍ ', '4점'],
#  ['카페노티드 안국', '도넛은 진짜 별로 차라리 스콘이 나아요', '1점'],
#  ['카페노티드 안국', '맛있지만 너무 비싼.,,,,,', '2점'],
#  ['카페노티드 안국', '도넛은 최고', '5점'],
#  ['카페노티드 안국',
#   '기대했는데 실망이네요. 정말 스페셜한 맛 하나 없어요. 차라리 시장 도넛이나 던킨 도너츠 바바리안 도넛이 훨씬 맛있는듯..  가성비 창렬입니다',
#   '1점'],
#  ['카페노티드 안국', '카운터앞에 서서 주문한다고 해도 뒤돌아서 지들 할거만 하네여. 안보이는 공간이아닌데 어이없네요', '1점'],
#  ['카페노티드 안국', '가성비 노굿. 마케팅의 승리', '1점'],
#  ['카페노티드 안국', '최고예요', '5점'],
#  ['카페노티드 안국',
#   '크로와상도 맛있고 도넛은 마니안조아해서 그냥 보통 부드럽고 덜달긴해요 바로먹는게 낫고 가게는 너무 좁아요 커피 맛있었어요 ',
#   '4점'],
#  ['카페노티드 안국',
#   '제 최애 도너츠집입니다. 단점은 집에서 멀다는거. 제발 강서구 쪽에 하나 더 내주세요....역시 도너츠는 받자마자 먹는게 최고더라고요. 아껴먹는다고 다음날 아침에 먹었는데 감동이 쬐끔 덜하더라고요!! 그래도 건수만 있으면 가서 사먹는 노티드 도넛임다!!',
#   '5점'],
#  ['카페노티드 안국', '왜 유명한지 모르겠어요..속에 들어있는 크림은 먹을만하고 빵은 촉촉하지않고 퍽퍽해요', '3점'],
#  ['카페노티드 안국', '도넛 존맛 근데 매장이 작아서 앉아서 먹기는 힘듬 그냥 편하게 테이크아웃하는게..', '5점'],
#  ['카페노티드 안국', '최고예요', '5점'],
#  ['카페노티드 안국', '그 예전에 미스터도넛이라는 곳 있었는데 거기랑 도넛 식감이 비슷. 알바가 불친절해서 별 뺌', '3점'],
#  ['카페노티드 안국', '그냥그래요. 도넛도 너무 작고 ,,,', '2점'],
#  ['블루보틀 삼청한옥',
#   '친절함  눌라플로트, 싱글오리진 라떼가 제일 괜찮음. non- coffee 메뉴는 맛없어서 깜짝 놀랐다 ',
#   '4점'],
#  ['블루보틀 삼청한옥', '커피맛 보통 자리부족', '3점'],
#  ['블루보틀 삼청한옥', '기대 만큼 맛있지 않습니다 스타일 차이일 수 있지만 저 같으면 근처 폴바셋이나 포비 갑니다', '3점'],
#  ['블루보틀 삼청한옥', '솔직히 여기 라떼 찐이잖아,,,', '5점'],
#  ['블루보틀 삼청한옥', '3층 뷰 너무 이쁘고 직원분들도 엄청 친절하세요 덕분에 엄마랑 좋은시간 보내구 갑니당 ㅎㅎ ', '5점'],
#  ['블루보틀 삼청한옥', '커피 한 모금에 다채로운 풍미를 명료하게 경험할 수 있는 가성비 맛집. 단연코 탁월합니다. ', '5점'],
#  ['블루보틀 삼청한옥', '최고예요', '5점'],
#  ['블루보틀 삼청한옥',
#   '장점: 유명한 곳 치고 주문도 음료제조도 여러 사람이 달려들어 해치우기 때문에 웨이팅이 길지 않음. 통유리창으로 보이는 기와지붕 같은 요소들 때문에 왠지 모르게 여행 가서 관광지 둘러보는 기분이 듦. 단점: 편히 앉아 먹기는 그름. 사람 많음. 아메리카노 상대적으로 바디감 있고 구수하다는 원두로 골랐는데 산미 있는 걸로 고른 것처럼 산뜻한 맛임.',
#   '3점'],
#  ['블루보틀 삼청한옥', '맛있게 잘 마셨습니다. 상주하고 있던 고양이가 매우 귀여워서 한참을 예뻐해 주던 곳. ', '5점'],
#  ['블루보틀 삼청한옥', '춥고 커피 맛도 별루에요..', '2점'],
#  ['블루보틀 삼청한옥',
#   '아.. 삼청동에 도착한 나는 거리가 이뻐 기분이 매우 좋았다. 하지만 이곳에 오고난 후 나의 심경은 급속도로 변하기 시작했다.  한약맛이 콜드브루에서 날줄은...  아이스라떼에서는 김칫국물 몇방울을 떨궈서 만든듯한 혼종의 맛이 났다.. 사람들은 겁나 북적거리는데  이걸 맛잇다고 먹는 사람들은 평소에 뭘먹길래 그러지?',
#   '1점'],
#  ['블루보틀 삼청한옥', '보통이에요', '3점'],
#  ['블루보틀 삼청한옥', '좋아요', '4점'],
#  ['블루보틀 삼청한옥', '친절해욥', '5점'],
#  ['블루보틀 삼청한옥', '라테 괜찮아요. ', '4점'],
#  ['블루보틀 삼청한옥', '조금 아쉬워요', '2점'],
#  ['블루보틀 삼청한옥', '다른 지점에 비해 자리가 불편함', '4점'],
#  ['블루보틀 삼청한옥', '신랑이랑 커피 한 잔 하면서.. 폭풍수다 떨고 왔네요~', '4점'],
#  ['블루보틀 삼청한옥',
#   '인테리어 맛 다 조금씩 아쉬워요 따뜻한 라테도 마셨는데 폼이 별로였어서 사진은 없어요 직원분들은 다 정말 친절하세요!!',
#   '3점'],
#  ['블루보틀 삼청한옥', '조금 아쉬워요', '2점'],
#  ['블루보틀 삼청한옥', '보통이에요', '3점'],
#  ['블루보틀 삼청한옥', '한번 가볼만 함', '3점'],
#  ['블루보틀 삼청한옥', '좋아요', '5점'],
#  ['블루보틀 삼청한옥', '편안함은 1도 없는  카페라고 할 수 없는 카페', '1점'],
#  ['블루보틀 삼청한옥',
#   '맛있는데 테이크아웃 해가는 입장에서는 가격이 너무 비싸 놀람 테이크아웃 할인이 있는 것도 아니고.. 휘낭시에도 메종엠오 본점보다 비싸더라 3층 올라가보니 뷰가 좋아서 앉아있다 갈거면 갈 메리트 있지만 글쎄,, 다신 안 갈듯 외국에서 갔을 때 좋게 남았던 기억까지 망치는 것 같았다',
#   '3점'],
#  ['블루보틀 삼청한옥', '자리도없고 맛도 보통.', '3점'],
#  ['블루보틀 삼청한옥', '좋아요', '4점'],
#  ['블루보틀 삼청한옥',
#   '커피 페어링 서비스 예약하면 블루보틀 건물 뒷편에 작고 아담한 한옥으로 안내해주신다. 복작스럽지않고 소담한 한옥에서 티&커피와 어울리는 다과(?)를 먹으며 담소 나누는 재미 꿀. 다만 가격 사악 ',
#   '5점'],
#  ['블루보틀 삼청한옥',
#   '최악입니다. 별점 1점도 아까운... 자리는 없는데 사람은 바글바글... 넓은 의자 하나에 다른 팀이랑 같이 앉아서 너무 블편했구요. 내가 마신 건 지브라타는 그럭저럭 먹을만 했는데 여친이 먹은 뉴올리언스는 드럽게 맛없었어요. 쟁반도 안줘서 들고 다니기 힘들었구요. 대충 원샷하고 나왔네요. 다른 동네에서 까페 다시 왔네요.',
#   '1점'],
#  ['블루보틀 삼청한옥', '사진 찍으러 온 감성 카페 음료가 맛이 없어서 먹다 버림', '2점'],
#  ['블루보틀 삼청한옥', '커피맛이 별로에요', '2점'],
#  ['블루보틀 삼청한옥', '보통이에요', '3점'],
#  ['블루보틀 삼청한옥',
#   '양은 적고 비싸고 앉을데도 없지만 커피만큼을 깔수가 없어요. 맛있죠. 다음엔 아이스크림 얹은거 먹어야지~',
#   '5점'],
#  ['블루보틀 삼청한옥', '최고예요', '5점'],
#  ['블루보틀 삼청한옥', '최고예요', '5점'],
#  ['블루보틀 삼청한옥', '저는 괜찮았고 맛있었어요', '5점'],
#  ['블루보틀 삼청한옥', '분위기가 좋다. 근데 커피는 딱 한입만 먹고 버렸다. 빵 맛없다 돈이 아까워서 억지로 먹고 나옴.', '2점'],
#  ['블루보틀 삼청한옥', '할 말 없음.. 위치 좋고 뷰는 이쁘다.. ', '2점'],
#  ['블루보틀 삼청한옥', '좋아요 2층 뷰가 커피는 중간 평범합니다', '3점'],
#  ['블루보틀 삼청한옥', '아아 맛있어여 뷰 이쁨', '4점'],
#  ['블루보틀 삼청한옥', '음... 일본 시나가와에서 먹었던건 이런 맛이 아니었는데? 공간은 그럭저럭 조망은 나쁘지 않다.', '2점'],
#  ['블루보틀 삼청한옥', '이건 커피가 아님..  인테리어나 가구나 음악선곡 모두 최악. ', '1점'],
#  ['블루보틀 삼청한옥', '커피는 별로. 전망은 최고.', '2점'],
#  ['블루보틀 삼청한옥', '앉을자리없고 모카는 아쉬운 맛', '2점'],
#  ['블루보틀 삼청한옥', '보통이에요', '3점'],
#  ['블루보틀 삼청한옥', '드디어 카카오 맵에 장소 등록됐네요.. 삼청 한옥점이랑은 다릅니다.', '3점'],
#  ['블루보틀 삼청한옥', '최고예요', '5점'],
#  ['블루보틀 삼청한옥',
#   '후기보고 걱정했는데...직원분들 엄청 친절하시던데요.?ㅎㅎ 커피맛은 괜찮았는데 가성비가 없긴하네요 ㅎㅎㅎ ',
#   '5점'],
#  ['블루보틀 삼청한옥', '내 입맛은 뉴요커가 아닌가봐요', '2점'],
#  ['블루보틀 삼청한옥',
#   '모두 맛있었다고 할 순 없지만, 몇가지는 기억에 남았다.  맛을 떠나 공간에서 느껴지는 여유로움이 즐거웠다.  종종 서울 시내 호텔에서 애프터눈을 즐기지만, 여긴 여기 나름의 감성이 있어서 좋았던 경험으로 남은 듯.  여자친구들끼리 속닥거리기 좋을 듯 하고, 연인들이 한번쯤 방문하기도 괜찮.  난 인스타는 하지 않으므로 인스타충만을 위한 공간이라고 보기는 ...',
#   '4점'],
#  ['블루보틀 삼청한옥', '커피에서 간장맛남 ㅠ;; 콜드브루 너무 맛없어서 충격받음,,,! 인스타충에게는 뭐 추천...', '1점'],
#  ['블루보틀 삼청한옥',
#   '비싼 가격에 비해서 형편없음. 원두를 너무 태웠다. 너무 추출을 과하게 해서 원두의 영혼까지 뽑은 맛. 원두의 쓴 맛이 너무 과하다. 실망스러웠다.',
#   '1점'],
#  ['블루보틀 삼청한옥', '생각보다 아쉽네여', '2점'],
#  ['블루보틀 삼청한옥', '엄마 모시고 갔는데 좋아하셨어요', '5점'],
#  ['블루보틀 삼청한옥', '커피 레알 맛없어서 충격받은 적 처음임', '1점'],
#  ['블루보틀 삼청한옥', '조금 아쉬워요', '2점'],
#  ['블루보틀 삼청한옥', '명불허전 라떼 .. 맛있어요 ! ·ᴗ·', '4점'],
#  ['블루보틀 삼청한옥', '네슬레 인수후 맛이 조잡하고 바라스타들이 일반인보다 못함', '1점'],
#  ['블루보틀 삼청한옥', '분위기가 너무 좋습니다', '4점'],
#  ['블루보틀 삼청한옥', '개인카페 라떼가 더 맛있음..가격 오바..', '1점'],
#  ['블루보틀 삼청한옥',
#   '가격에 비해서는 대단히 실망. 스탠드방식과 2인테이블 형태가 아직 한국인들 한테는 맞는 인테리어는 아닌 것 같지만 심플한 외관과 일하시는 분들의 친절 마인드는 너무 좋네요!',
#   '2점'],
#  ['블루보틀 삼청한옥', '전 라떼 별로였어요 부드럽긴한데 우유맛이 더 많이 나는 느낌이었음', '2점'],
#  ['블루보틀 삼청한옥', '진짜 3층 풍경도 좋고, 라떼매니안데 불루보틀 라떼 개맛잇음', '5점'],
#  ['블루보틀 삼청한옥',
#   '장소도 괜찮고 직원들도 진짜 너무 친절해요. 맛은 나쁘지 않은데 일본에서 먹었던 맛 생각하고 먹으면 별로일꺼에요. :)',
#   '4점'],
#  ['블루보틀 삼청한옥',
#   '좌석 불편하고 그나마 앉을 자리도 부족. 2층은 스탠딩석이라 서서 마셔야 함. 후딱 마시고 나가라는 느낌. 요즘 커피 괜찮은데가 많아서 상대적으로 블루보틀이 엄청 맛있진 않았음. 굳이 두번 찾아갈 정도는 아님. ',
#   '3점'],
#  ['블루보틀 삼청한옥', '맛을 떠나서 앉을 공간이 너무 부족합니다.', '2점'],
#  ['블루보틀 삼청한옥', '조금 아쉬워요', '2점'],
#  ['블루보틀 삼청한옥', '그냥 기본매장보다는 확실히 나아요 디저트류도 괜찮고 차분하니 좋습니당 재방문의사 확실하게 있어욥', '4점'],
#  ['블루보틀 삼청한옥', 'All about the hype', '1점'],
#  ['블루보틀 삼청한옥',
#   'Drip Coffee and Iced Mocha.  They say the hype is real, so we arrived before 10am. ',
#   '3점'],
#  ['블루보틀 삼청한옥', '맛은 있었는데 가격대비 양이ㅠ', '3점'],
#  ['블루보틀 삼청한옥', '워낙 유명해서 기대한 그 정도', '4점'],
#  ['블루보틀 삼청한옥',
#   '여기 오랫동안 앉을 수 있는 카페 아니지만 라떼는 역시 평범한 카페보가 훨씬 맛있음. 특히 싱글 오리진 너무 좋았어요. 한번만 갈 만해요. 머핀 그냥 보통. ',
#   '5점'],
#  ['블루보틀 삼청한옥', '예약이 힘들지만 서비스도 좋고 음료의 페어링이 좋아서 다시 가고 싶은 마음이 드네요', '5점'],
#  ['블루보틀 삼청한옥',
#   '커피 맛은 특별할 것 없었어요. 라떼를 먹었어야 했는데 아메리카노를 먹어서 그런가봐요. 사람이 너어무 많아서 테잌아웃만 했을뿐인데 지쳐서 돌아나왔어요 ,, 흑흑 ㅠㅡㅠ',
#   '3점'],
#  ['블루보틀 삼청한옥',
#   '창가에 햇빛은 너무 세고 자리는 카페에 앉아서 편안하게 커피를 즐기기엔 넘 적고 불편하다. 그렇다고 테이크아웃하기엔 커피가 너무 비싸다. 세련된 이미지가 주는 마케팅?에 비해 서비스가 별로임.',
#   '2점'],
#  ['블루보틀 삼청한옥', '왜 핫한지 의문입니다 라떼는 역시 아띠제입니다', '1점'],
#  ['블루보틀 삼청한옥', '기본적인 서비스등은 좋은데 굳이 다시 가고싶지는 않음.', '2점'],
#  ['블루보틀 삼청한옥', '납득이 안감 정말 맛없음', '1점'],
#  ['블루보틀 삼청한옥', '별로예요', '1점'],
#  ['블루보틀 삼청한옥', '맛없음. 탄맛이 심함. 원래 블루보틀 맛이 아님', '1점'],
#  ['블루보틀 삼청한옥', '최악의 서비스를 경험하였습니다 직원분들 교육좀 더 해야 할듯합니다', '1점'],
#  ['블루보틀 삼청한옥',
#   '커피맛이 쓰레기임..스벅 탄맛의 열배정도 됨.. 근데 연하고 묽어.. 인스타열풍에 힘입어 사진찍기용이지..커피 마시러는 절대 안감',
#   '1점'],
#  ['블루보틀 삼청한옥',
#   '이 돈을 주고 굳이 이걸 먹어야 하나 싶은 라떼 맛 싱글오리진으로 변경하면 1100원 추가하고 더 후회함 불편한 좌석 별다를 것 없는 인테리어 남녀공용화장실 대체 좋은게 뭔지 알 수 없는 최악의 커피샵  가격이 2000원대면 알맞음',
#   '1점'],
#  ['블루보틀 삼청한옥', '자리 협소함. 보통맛. 지나가다면 모를까 굳이?', '3점'],
#  ['블루보틀 삼청한옥', '보통이에요', '3점'],
#  ['블루보틀 삼청한옥',
#   '긴줄 더운날에도 친절응대하시는 직원분들 땜에 별줌.뉴올리언즈는 평범  원두를 사와 집머쉰서 내려먹었는데 원두 퀄은 좋음!이원두로  그래서 애플이라는',
#   '4점'],
#  ['블루보틀 삼청한옥',
#   '직원분들의 자연스러운 미소와 서비스가 인상적인 곳  3층의 뷰도 엄청납니다  다만, 커피의 맛은 엄청난지 잘 모르겠네요..  ',
#   '3점'],
#  ['블루보틀 삼청한옥',
#   "불친절해도 너무 불친절하네요.. 대기번호 22번이었고, 기다리다가 40분 넘게 커피 안 나오길래 갔더니 '다른 분들이 가져갔나봐요~금방 만들어드릴게요' 가 끝. 사과 한 마디라도 해주시지 그러셨어요. 커피도 그렇게 특별한지 전혀 모르겠네요. 다신 안 갈듯 합니다. ",
#   '1점'],
#  ['블루보틀 삼청한옥', '엉터리..여요', '2점'],
#  ['블루보틀 삼청한옥', '쾌적한 느낌을 주는 공간 ', '4점'],
#  ['블루보틀 삼청한옥', '한국 현지화 되었다', '1점'],
#  ['블루보틀 삼청한옥',
#   '맛이 궁금해서 가봤는데 건물은 좋네요 2층 한옥뷰도 좋지만 특히 3층 인왕산 뷰요  아이스라떼 마셨는데 원두맛이 부드럽고 제 미각으로 개성은 못느꼈어요 개취로 이 가격이면 폴바셋이나 테라로사를 갈 듯 합니다',
#   '3점'],
#  ['블루보틀 삼청한옥', '일본 불매중에 잘들 가네. 대체가 안되는 품목도 아니고.', '1점'],
#  ['블루보틀 삼청한옥',
#   '맛있어요. ㅋㅋ 수요일 6시 좀 넘어서 대기없이 주문했지만 커피 받는데는 20분 걸림. 집근처면 또 먹겠지만 일부러 찾아갈 정돈 아니에요. 그리고 너무 비싸요....ㅋㅋ ',
#   '4점'],
#  ['블루보틀 삼청한옥',
#   '개인적으로는 성수 인테리어랑 상반되서 좋았습니다!  지점마다 인테리어가 같으면 별로인것 같아서 ! 직원들은 친절해서 좋았고 역시나 음료는 가격이 사악하네여 사실 친구 한테 부탁해서 원두도 구매해봤는데  같은 가격대의 호주 로스터리 원두 구매해서 핸드드립해 마실 것 같네요...(쓰리아프리카스 산미가 기분 좋은 산미는 아니었습니다;;)',
#   '3점'],
#  ['블루보틀 삼청한옥',
#   '성수보다는 낫다는 평가가 많은데 그래서 별3개입니다 사람이 너무많아서.. 커피를 즐길공간이 매우 협소합니다',
#   '3점'],
#  ['블루보틀 삼청한옥', '뉴올리언스 마셨는데. 뭐 맹맛. 뭐지 한번 구경해보고 메리티 없음', '1점'],
#  ['블루보틀 삼청한옥', 'great interior, great vibes. great coffee', '5점'],
#  ['블루보틀 삼청한옥', '파란병이던데요.... 빨대도..', '3점'],
#  ['블루보틀 삼청한옥', '간판찍고옴', '2점'],
#  ['블루보틀 삼청한옥',
#   '한 여름 대낮에 줄을 서서 커피를 마신다는 것이 얼마나 열정이 있어야 하는 일인지... 오후 5시쯤 되니 오히려 줄이 줄었다.   층마다 바리스타가 있고, 굉장히 기능에 집중 한 공간.  그리고, 점점 높아져가는 커피가격. ',
#   '4점'],
#  ['블루보틀 삼청한옥', '인테리어가 멋졌어요', '5점'],
#  ['블루보틀 삼청한옥', '성수점보다 훌륭한 건축과 인테리어 마감. 아이덴티티. 한옥과의 조화.. 개방감.. ', '5점'],
#  ['블루보틀 삼청한옥', '최고예요', '5점'],
#  ['어니언 안국점', '커피는 아직 안먹어봤지만 샌드위치 넘 좋아요 추천 ', '5점'],
#  ['어니언 안국점', '음료와 디저트가 공간을 못따라갑니다.  "한옥카페" 가고싶다 하면 추천', '3점'],
#  ['어니언 안국점', '공간을 방문하는 햇살 버금가는 맛 정겨운 소리 발걸음 도심 속 휴식', '5점'],
#  ['어니언 안국점',
#   '앙버터는 팥이 씹혀서 개인적으로 맛있게 먹었는데... 아메리카노는 진짜 심하게 맛없음. 물 잔뜩 탄 맛... 차라리 플랫화이트가 나았음. 입구에서 사진만 찍기 좋은 곳. ',
#   '1점'],
#  ['어니언 안국점',
#   '서울사람 다 여기 모인거같음 진짜 졸라붐빔 갈때마다 ㅡㅡ 시끄럽구로  빵은 매우 맛있음 아보카도명란바게트랑 까만크림치즈소보로 ? 굿 ',
#   '4점'],
#  ['어니언 안국점', '공간 디자인 하나만으로도 가봐야 하는 곳. 조금 덜 붐비는 시간에 가면 좋아요!', '5점'],
#  ['어니언 안국점', '분위기는 좋으나 가격대가 있는편', '4점'],
#  ['어니언 안국점',
#   '커피는 4점 주고싶음 인테리어는 5점 주고싶음 그치만 관리가 안돼서 안타까움  화장실도 내부도 급속도로 낡고 지저분해져서 안타까움;; 이렇게까지 관리가 안될 수가 있나 싶을 정도? ',
#   '2점'],
#  ['어니언 안국점', '그냥 그래요. 여기 갈 바엔 다른 곳을 가겠어요. ', '2점'],
#  ['어니언 안국점',
#   '빵이...사람들 줄서는길 진열대 맨 아래에 두다니요..진열빵 위에서 수다떠는 사람들도 이해안가지만 진열대기중인 빵을 사람들 걷는 길바닥 아래에 셋팅하다니..그냥 제빵실안에 두면 안되는거였나요..그거 가지러 왔다갔다 하는게 그렇게 귀찮으시면 빵을 팔지 마셔야죠..',
#   '2점'],
#  ['어니언 안국점', '최고예요', '5점'],
#  ['어니언 안국점',
#   '빵이 정말 평-범 그 자체!!ㅎㅎ 음료도 아주아주 평범 그자체ㅎㅎ 서비스는 아주아주 친절함  대신 한옥이 예쁘고 이게 다 하는 곳 날씨 좋을때 오픈된 마루에 앉아서  커피홀짝 빵냠하기에 최적의 인테리어를 갖췄음ㅎㅎ  빵커피맛집은 아니고 분위기맛집  언제가도 사람 너무 많지만 지리적으로나 규모로나 그럴 수 밖에 없음ㅠ',
#   '4점'],
#  ['어니언 안국점',
#   '객관적으로 너무 맛이 없습니다. 가게 직원 친절하고, 인테리어 예쁘고, 넓습니다. 단지 단점은 하나-빵 맛이 없어요.  나쁜가게는 절대 아닙니다. 그냥 맛이 없어요.',
#   '1점'],
#  ['어니언 안국점',
#   'ㅠㅜㅜ팡도르가 그렇게 맛있나요ㅠㅠ? 모르겠ㄱ던데ㅠㅜㅜ아님 제가 팡도르를 너무 기대한 탓일까요ㅠㅠ? 안에 크림이나 뭐가 잇을 줄 알앗는데ㅠㅜㅜ 네버ㅠㅠㅠ 그냥 슈가파우더만 위에 가득 뿌려지기만 한 팡도르ㅠㅠㅠ',
#   '3점'],
#  ['어니언 안국점', '맛난 디저트빵 맛난 커피, 바글바글한 사람들', '3점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점', '예쁘고 맛있고 날 좋은날 가기에 좋아요ㅜㅜ...!!!~', '5점'],
#  ['어니언 안국점', '진짜 맛있다 ㅠㅠㅠ 인절미팡도르랑 칠리소세지? 먹었는데 다음엔 다른 거 또 먹어야지~', '4점'],
#  ['어니언 안국점', '너무 이쁜데 사람이 엄청 많아서 자리가 없어요 ㅠㅠ', '4점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점', '아메리카노 2000원 행사하고 있었어요 완전 저렴', '5점'],
#  ['어니언 안국점',
#   '감성을 위해서 너무 많은 걸 포기해야 함 근데 그럴 가치가 있긴 해요 카페가 정말 예쁘긴 합니다...만.... 음 사람 많이 안몰릴 시간에 가세요 ',
#   '3점'],
#  ['어니언 안국점',
#   '인테리어는 너무 예쁨 그러나 1. 테이블이 더러워 물티슈로 닦았는데 정말 더러움.  2. 이 시국에 베이커리류를 쇼케이스 없이 진열함.   성수점은 어떤지 몰라도 안국점은 매장 관리가 안되어 있음. ',
#   '1점'],
#  ['어니언 안국점', '알바 느려터짐', '1점'],
#  ['어니언 안국점', '여기유명하던데.. 빵이 엄청 일찍 나가서.. 여기 굴뚝빵 먹어보기가 힘들어요 ㅜ', '3점'],
#  ['어니언 안국점', '할많하않', '1점'],
#  ['어니언 안국점',
#   '카페모카에서 커피와 초콜릿 맛 이외의 신맛이 났어요... 카페모카도 이렇게 맛없을 수 있구나를 배우고 갑니다^^',
#   '1점'],
#  ['어니언 안국점', '장소는 이쁘나..빵과 음료는 그냥 그럼. 빵조각이 있다면 참새를 가까이서 볼 수 있다.', '4점'],
#  ['어니언 안국점', '빵 맛있다.', '5점'],
#  ['어니언 안국점',
#   '개인적으로 내 취향인 어니언 빵과 커피를 같이 먹으면 부담 없이 많이 먹을 수 있음 시그니처 메뉴 보다 다른 것들이 더 맛있을 수 있으니 도전해보세요-!',
#   '5점'],
#  ['어니언 안국점', '어니언 한장요약 ㅋ', '1점'],
#  ['어니언 안국점', '한번 와봤으니 되었오.', '3점'],
#  ['어니언 안국점', '트러플맘모스 빵 맛있음 음료는 양이 종이컵수준 비쌈 공간만 이쁘고좋음', '3점'],
#  ['어니언 안국점', '이렇게 큰 가게를 뭘 믿고 차렸는지 모르겠다. ', '2점'],
#  ['어니언 안국점', '커피 맛있고 공간도 예쁜데 베이커리 최악 ㅠㅠ 3개천원하는 빵보다 맛없음 뻑뻑하고', '3점'],
#  ['어니언 안국점',
#   '분위기는 좋은데 바리스타들도 멋지던데 왜 불친절하지? 커피맛이 좀 아쉽네 빵은 종류만 많지 별로 먹고 싶은것이 없네 아쉽다',
#   '2점'],
#  ['어니언 안국점',
#   '다들 이게 얼마로 보이시나여 바로 17000원 입니다 인스타 감성 찾는다해도 가지마세요  @ 인테리어— 들어가자마자 이거 버리는건가?; 싶은 녹 슨 의자와 테이블이 즐비해 있습니다 ( 잠깐 앉았는데 엉덩이 시리고 불편함 이게 뭔가싶은 ,,,)  그러면 안으로 들어가면 되지않냐? _ 자리가 없습니다 진짜 사람들 빽빽해여 ,, 인생샷 찍기에는 채광이 안좋아서 ...',
#   '1점'],
#  ['어니언 안국점',
#   '인테리어는 좋음 불친절, 맛 없음 바라보는 사람이 그렇게 많은데  필터커피 내리는 중간중간 핸드폰하는 바리스타..',
#   '1점'],
#  ['어니언 안국점', '가격이 사악함  조금 씨끄러움', '4점'],
#  ['어니언 안국점', '분위기 말곤 내세울 게 없다.', '3점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점', '평이 안좋아서 걱정했는데 생각보다 맛도 괜찮고 분위기도 굳.', '5점'],
#  ['어니언 안국점', '조금 아쉬워요', '2점'],
#  ['어니언 안국점',
#   '진짜 분위기말고 내세울게없다. 저번에도 커피 드럽게 맛없더니 이번엔 커피는 믿고 거르고 쑥차 셨는데  저런식으로해서 비싸게팔고 오래장사하고 싶으면 커피원두를 바꾸던지 제대로 교육을 시키던지 해야할듯..',
#   '1점'],
#  ['어니언 안국점', '이젠 굳이 찾아갈 필욘 없는', '2점'],
#  ['어니언 안국점',
#   '생각했던것보다 아인슈페너가 맛있었고, 자리도 잘 치워주셨다.. 번호표나 진동벨이 있었음 좋겠다 이름 부를때 너무 안들려서ㅠㅠ',
#   '3점'],
#  ['어니언 안국점', '난 성수보다 여기가 더 좋더라 사람많아서 항상 밖에 앉음....', '3점'],
#  ['어니언 안국점', '빵은 퍽퍽하고 커피는 평범, 사람도 넘 많음', '2점'],
#  ['어니언 안국점', '최고예요', '5점'],
#  ['어니언 안국점', '최고예요', '5점'],
#  ['어니언 안국점', '사진 찍기 위한 사람들이 아주 많이 모인 곳.', '2점'],
#  ['어니언 안국점', '다신 가고싶지않음', '1점'],
#  ['어니언 안국점',
#   '인절미 팡도르도 맛있고 커피도 맛있고 인테리어도 이쁘지만 사람이 너무 많아서 매장 관리가 제대로 안 되어서 아쉽다ㅠㅠ 테이블이 너무 더러워,, 카페가 너무 유명하고 좌석 간 거리가 좁다보니 대화 나누기에는 적당하지 않은 듯,, 사진 찍는 사람들이 너무 많아 내 얼굴도 거기에 같이 나올 듯...ㅎ̌̈',
#   '3점'],
#  ['어니언 안국점', '자리 청소 좀 해 주지. 앞 사람 먹은 빵 부스러기들이 그대로.. 아, 드러..', '2점'],
#  ['어니언 안국점', '최고예요', '5점'],
#  ['어니언 안국점', '사람 쏘 매니', '3점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점', '이정도 하는 빵집은 동네에도 있는듯...', '1점'],
#  ['어니언 안국점', '힙힙힙', '5점'],
#  ['어니언 안국점',
#   '스콘, 빵은 평범 하나 안에 들어가는 팥 덕분에 먹을만 했고, 앙버터 스콘보다 그냥 앙버터 빵이 더 맛있어요. 유명세 만큼 맛집은 아닌것 같고 분위기가 진짜 좋은 곳 같아요!',
#   '4점'],
#  ['어니언 안국점', '분위기가 참 좋음.. 밤엔 멋있음.  다만.. 춥고.. 커피나 빵은 보통이예요.', '3점'],
#  ['어니언 안국점', '너무 추워요', '1점'],
#  ['어니언 안국점', '주말엔 사람이 많다 평일도 사람이 많다', '1점'],
#  ['어니언 안국점',
#   '커피 괜찮고 외관 괜찮은데 내부는 다닥다닥 붙어있는 밥집만 못해요. 전면이 유리인데 유리창 틈새로 한기가 엄청 들어와서 냉골... 히터도 소용없는 냉골..',
#   '1점'],
#  ['어니언 안국점',
#   '분위기는 참 좋았으나 의자 엄청 딱딱하고 불편합니다 방도 다과상은 낮고 더불편할듯!! 커피와 빵가격 맛 다른곳에 밀리진 않습니다 계산대와 커피 회전율이 너무 좋지 않아 곳곳의 직원들이 한가한데도  손님들은 대기중~~~안내도 부족~~~ 물티슈도 빵샀는데 기본 제공 안하면서 가져가려니 시킨 음료 나올때 준다며 도끼눈!!!  결국 시킨 트레이에 없었음 가장 문제...',
#   '1점'],
#  ['어니언 안국점', 'Einspanner, 초코라 and 팡도르. 9시처럼 일찍와.', '3점'],
#  ['어니언 안국점',
#   '카푸치노가 미지근하네요.  옆건물이 바로 주방이있는 건지 왼쪽 홀에는 생선비린내가 좀 나네요.  빵맛은 괜찮은데 사람들이 분주하게 오가는중에 청결이 아쉬웠어요.  한국방문하는 관광객이 많은 건 좋지만 그래서인지 아침 9시에도 자리 잡기가 힘드네요. ',
#   '2점'],
#  ['어니언 안국점',
#   '워낙 많이 들어서 왔는데 빵진열도 사람들 다니는곳에 오픈한채로 두고 고르게 되어있네요. 사람들 이야기 하면서 고르고 먼지.침 다 떨어지고 빵 고르고 나서도 음료주문하느라 20분 넘게 기다림. 최악은 메뉴판이 다 영어로 되어있음. 한옥에 영어간판 단것까지는 그렇다쳐도 왠 영어일색 메뉴판인가요? 한국에서 한글메뉴판 쓰면 뭐 격이 떨어지나요? 한국적인테리어에 그...',
#   '1점'],
#  ['어니언 안국점',
#   '이쁘고 다 좋은데 주문이 너무너무너무너무 오래걸림. 사람이 그리 많은데 주문 받는사람이 한명이며 그 사람이 느릿느릿 빵 포장까지하며 주문 받느라 주문만 몇십분 . 게다가 좌석은 멀리 있는데 진동벨을 주지 않아 주문한 것 받는것도 힘듦. 외국인도 많던데 주문 받는 알바 좀 늘렸으면. 성수 어니언도 주문이 완전 느렸는데 느린 주문이 정책인건지 ㅡㅡ',
#   '1점'],
#  ['어니언 안국점', '자리잡는데 10분, 줄서서 주문하는데 20분. 주말에 가니 사람이 많네요. 팡도르 맛있었어요', '4점'],
#  ['어니언 안국점', '장소는 걍 대충 만들고, 사람은 많은데 응대준비 부족하고 빵 비싸고.정신없고.. 뭐하러 가냐여기', '1점'],
#  ['어니언 안국점', '비싸기만 함', '1점'],
#  ['어니언 안국점', '태어나서 이렇게 맛없는 라떼 첨먹어봐요 ', '1점'],
#  ['어니언 안국점',
#   '커피: 맛있음 빵 : 맛있는편.  분위기: 한옥 인테리어. 넓은 하늘. 좋음  단점: 역시 위생. 테이블 아래 놓여진 바닥 가까이 빵들.                      자리없음. ',
#   '3점'],
#  ['어니언 안국점', '인간적으로 빵값 너무 비싸다. 커피는 드럽게 맛이 없으면서..', '1점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점', '건물과 인테리어가 전부', '1점'],
#  ['어니언 안국점', '분워기만 조금 좋음 마루는 조금 아니 조금 많이 지져ㅂ', '1점'],
#  ['어니언 안국점', '분위기만 좋은걸로... 커피가 진짜 맛없... ', '1점'],
#  ['어니언 안국점', '조금 아쉬워요', '2점'],
#  ['어니언 안국점', '별로예요', '1점'],
#  ['어니언 안국점',
#   '블로그만 보고 잔뜩 기대하고 방문했는데 커피맛이나 빵맛에 실망했다기보다 내부가 지저분해서 실망하고 왔어요 평일에 자리가 거의 만석이었는데 좌석정리하는 직원은 한 명도 보이지 않았구요 방석에 앉긴 했지만 사방에 머리카락이 널려있고 반납하지 않은 음식물 쟁반 계속 방치되어 있고 화장실엔 화장지가 칸칸마다 없어요 음식도 중요하지만 카페시설관리도 신경써 주시면 좋...',
#   '1점'],
#  ['어니언 안국점',
#   '한옥에 하얀 자갈밭! 인테리어는 멋있음 베이커리는 전반적으로 별로 대표빵인 팡도르를 포함하여 스콘, 앙버터도 그냥 그랬음 그리고 주문 너무오래 걸림 주문받는사람을 늘리던지 해야 할 듯ㅠ',
#   '2점'],
#  ['어니언 안국점',
#   '오래된 한옥집 대청마루에 앉아서 하늘구경 사람구경 잘했음.  커피 주문하는데 메뉴판을 크게 비치해서 멀리서도 볼 수 있게 해붰으면 함.  주문하는데 너무 오래걸림.  분위기랑 인테리어는 굿. 빵이랑 음료는 보통.  주문 및 계산은 낙제점.',
#   '3점'],
#  ['어니언 안국점',
#   '한옥느낌만좋음//직원서비스최악+손님은넘쳐나는데 직원들손느림(커피제조속도심각함 교육을안하는듯?)//커피맛없음//앙스콘먹었는데 간이안맞음.. //여기가왜인기있는베이커리카페인지모르겠네요..단지한옥느낌보려고가시는건상관없는데맛이중요하신분이라면비추합니다*^^',
#   '1점'],
#  ['어니언 안국점',
#   '잔짜 커피나 빵맛을 위해 찾는거라면 개인적으로 비추. 사람구경 하고싶으면 추천 ^^ 근데 카페는 참 멋지긴 하다..',
#   '3점'],
#  ['어니언 안국점', '커피 빵 맛있는데 손님에 대한 배려가 전혀없음 심각 ', '2점'],
#  ['어니언 안국점',
#   '사람이 정말 너무 많아요 그래서 직원분들의 서비스가 많이 떨어지는데 아쉽네요. 빵 포장 막해줘서 되게 별로였어요.',
#   '2점'],
#  ['어니언 안국점', '보통이에요', '3점'],
#  ['어니언 안국점',
#   '오픈한지 얼마 되지 않았지만 평일 낮에도 사람들은 너무 꽉찼고, 빵가격은 비싼게 흠이지만 도심속 이런 풍경속에서 차 한잔 할수 있다는 것이 감사하다. ',
#   '4점'],
#  ['어니언 안국점',
#   '사대문 안의 옛 포도청이었던 한옥 안에서 마시는 커피. 오픈한 지 얼마 안되었는데도 외국인들 바글바글. 어니언 커피도 옛날에 비해 엄청 맛있어졌다.',
#   '5점'],
#  ['산모퉁이', '뷰가좋아요', '4점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '뷰는 좋지만 기대보다 별로였어요 조각상 수천개가 날 바라보는 너낌,,', '3점'],
#  ['산모퉁이',
#   '뷰말곤 이젠 없어요.. 사장님 이젠 마이 벌어 무그따 아이가~ 고마해드소~ 편의점커피보다 맛없는 커피가 8처넌... 커피프린스 후광으로 많이 벌었으니 다른 사람한테 넘기시던지.. 자리가 넘 아까워서리..',
#   '1점'],
#  ['산모퉁이', '뷰만 좋아요', '3점'],
#  ['산모퉁이',
#   '관리가 너무 안됐다는 느낌이 강하고 여름이라 슬슬 벌레도 창궐할 기미가 있음 굳이 차끌고 오지는 않을 것 같음',
#   '1점'],
#  ['산모퉁이',
#   '부암동의 아이콘 같던 곳이었는데 너무 방치되는걸 보니 좀 아깝단 생각이 든다. 사장님, 차라리 잘 관리할만한 임자에게 장기로 맡기는게 어떠세여? ',
#   '2점'],
#  ['산모퉁이',
#   '뷰 말고는 0점 드리고 싶은 카페입니다.  1. 커피 맛없고 비싸고 (7천원부터..) 2. 직원 불친절 하고  3. 주차할 곳 없고 4. 와이파이 안 되고...........  다시는 안 갈 듯... 경치 잘 봤습니다.',
#   '1점'],
#  ['산모퉁이', '커피는 평타 뷰는 우수 다만 주차 힘들어서 별하나 감점~', '4점'],
#  ['산모퉁이', '와이파이 없음. 직원들은 무서움. 절대 다시 네버 안 옴. ', '1점'],
#  ['산모퉁이',
#   '구석구석 너무 낡았고 드러워요 소품도 지저분 ㅠ 맛도 별로  뷰하나로 버티기엔 자리가 아깝네요  리모델링좀 plz',
#   '1점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '조금 아쉬워요', '2점'],
#  ['산모퉁이', '커피는 비싸지만 오전 11시쯤 간 뷰는 끝장남', '4점'],
#  ['산모퉁이', '분위기는 좋아요 ', '2점'],
#  ['산모퉁이', '직원들 불친절', '1점'],
#  ['산모퉁이',
#   '예전엔 정말 커피가 맛이없었는데 요새는 맛이 많이 나아졌네요. 그래도 가격은 완전 사악하죠 레모네이드 만원....ㅋㅋㅋ 여름이나 날좋을때는 풍경이 너무 좋죠. 근데 한겨울에 갓더니 좀 별로였어요. 미세먼지도 많으니 더 별로...인테리어는 기대하시면 안됩니다. 좀 조악해요.  결론. 날좋은날 가면 좋은 카페지만 그렇지 않을경우엔 조악한 인테리어와 사악한 가격...',
#   '4점'],
#  ['산모퉁이', '직원들 매우 불친절함 ', '1점'],
#  ['산모퉁이',
#   '경치를 생각하면 갈만은 합니다. 하지만 주차는 헬입니다. 길 한켠에 대야하는데 정말 여의치않아요. 운전 잘 못하시면 개고생합니다. 음료는 따뜻 8천원 아이스는 9천원이란 가격을 생각한다면 절대 돈값을 못하지만 카페에서 보이는 뷰를 생각하면 면피는 됩니다. 한 번 가봤으니 더는 안 갈 것 같네요. ',
#   '3점'],
#  ['산모퉁이', '인테리어랑 주변경관만 좋고 종업원 너무 불친절해요 손님들한테 대하는 매너좀 바꾸셔야할듯', '1점'],
#  ['산모퉁이',
#   '커피맛은 십년 전에 비해 많이 개선됐다 ㅋ ㅋ 여긴 뷰...  이정도 관광지면 고개가 끄덕여 지는 커피값-_-  ',
#   '4점'],
#  ['산모퉁이',
#   '맘 비우고 경치만 보고 오세요 평일에 가셔야 그나마 ,,,, 휴일에는 정말 비추 사람 바글바글 전 평일 늦은 오후에 다녀왔어요 직원의 친절은 기대하지 마시고요',
#   '2점'],
#  ['산모퉁이',
#   '이렇게 생각하세요. 경치 입장료, 경치 관람권을 사시면 음료를 한잔 드립니다! 그러면 조금 마음이 편해집니다. 커피보단 자몽에이드 추천할께요. 생자몽이라 맛이 없을 수 없어요!',
#   '3점'],
#  ['산모퉁이',
#   '풍경 때문에 별 하나 더 줬습니다. 땅값 플러스인지.맛없는 아이스 아메리카노가 8000원. 더맛없는 마들랜도 8000원. 주차는 그 동네 언덕에 했으니. 주차편의 점수도 줄수없고.. 오히려 그 동네 산책로가 더 좋네요',
#   '2점'],
#  ['산모퉁이', 'only 뷰..나머진 감수해야. 비싸고 맛없는 커피와 마들렌ㅋ', '3점'],
#  ['산모퉁이', '별로예요', '1점'],
#  ['산모퉁이', '사람 없을 때 가야함', '5점'],
#  ['산모퉁이', '별로예요', '1점'],
#  ['산모퉁이', '사람만 많고 그냥 사진 한 장 찍으러 오는 곳 두번 오는 사람 없다에 내 오른손 겁니다.', '1점'],
#  ['산모퉁이', '여기는 뷰 빼고는 뭐 없지만 뷰는 정말좋다', '2점'],
#  ['산모퉁이',
#   "'커피프린스 1호점' 촬영지. 인왕산과 북악산으로 둘러 쌓인 경관이 상당히 수려하다. 주인장이 수집한 소품이 카페 여기저기에  잡다하게 배치된 게 불만스럽지만 그 정성에는 경의를 표하고 싶다. 하지만 아무리 경관빨로 유명한 카페라고는 하지만 커피가 너무 맛이 없다. ",
#   '4점'],
#  ['산모퉁이', '커피프린스 명소. 경관이 좋아요. 주차공간 없어 도로에 불법주차하는데 시간마다 딱지 붙이고 감', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '사람 바글바글 답답답답 커피프린스의 추억은 내 마음속에만 간직하는것으로.', '2점'],
#  ['산모퉁이', '짱', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '경치를 내려다보며 공부 하고 싶은 욕망이 생기는 장소!', '4점'],
#  ['산모퉁이',
#   '경치는 좋지만. 내부시설이 오래된느낌. 커피가 질에 비해 가격이 비싸고, 맛도 보통 테이크아웃전문점 수준.  아이들이 있다면 지하층에 꼭 가보길 추천합니다. 재미있는장난감이 많아요',
#   '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '커피값 7천원, 맛은 없음', '1점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '가는길이 고불고불하나 아이와 가지 좋다', '4점'],
#  ['산모퉁이',
#   '절대 차가지고 가지 마세요 주차장이 없고 가파르고 좁은 길에 마주 오는 차로 식은 땀 펄펄 나는 상황에 처하는 분 봤어요  전망 나쁘지 않습니다만 도떼기 시장 저리 갈 정도로 많은 사람이 붐벼요 주말엔 절대 안가는게 정신 건강에 좋을 듯 합니다  아메리카노 한 잔 가격 8000원... 이게 최저가 메뉴에요  주말에 땀 뻘뻘 흘리며 올라간 고갯길에서 바가지 ...',
#   '1점'],
#  ['산모퉁이', '프로포즈', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '최고의 전망을 자랑하는 카페임.', '5점'],
#  ['산모퉁이', '풍경이 너무 좋다~ 사람 없을때 가야 좋은 곳', '4점'],
#  ['산모퉁이', '풍경 좋지만 사람이 너무 북적거림...ㅠ 커피맛은 쏘쏘', '4점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', 'View > Coffee', '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이',
#   ' ㅡ음료 6,000원이상, 맥주8,000원 기타 ㅡ뷰 아주좋음. 언제가도 좋은 곳    단 휴일은 손님 많고 주차 불편',
#   '4점'],
#  ['산모퉁이', '뷰가 좋은', '4점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이',
#   '유명 커피숍이다보니 가격이 비쌈. 연인들 데이트 코스로 괜찮아 보이지만, 차량이 없으면 엄두도 못낼 것 같음...',
#   '3점'],
#  ['산모퉁이',
#   '왜 아니 좋을쏘냐 커피프린스 추억이 담겨있고 서울에서 산속의 한적함을 느낄수 있는 풍경 가격대는 좀 있지만 그만큼 가치있음 ',
#   '5점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '주위 풍경과 아름다운 카페의 조화', '5점'],
#  ['산모퉁이', '우앙 여기 넘 예쁘당 뷰가 환상 커피프린스에 나온 한성이네 집', '4점'],
#  ['산모퉁이',
#   '음료값이 너무 터무니없이 비싸요  바깥풍경 사진 찍는데 7000-8000원이라니.  커피맛은 이디야가 더 맛있는 정도..?   커피맛이 아닌 풍경 보러 가는거 인정. ',
#   '2점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고명당이아닌가싶다 소품이며 아기자기한것이 커피값만 천원만좀내려주라', '4점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '후~:) viwe 짱', '5점'],
#  ['산모퉁이',
#   '서울에서 이런 뷰를 감상할 수 있는 카페가 또 있을까? 서울인듯 서울 아닌듯한 곳 왼쪽으로는 북악산. 우측으로는 인왕산 그리고 그곳을 관통하는 북한산성과 서울 도심 뷰 지하1층. 1층 2층 컨셉별. 테라스 자리도 많다. 가격대비 음료맛 빼고 완벽한 곳.',
#   '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이',
#   '좁고 가격도 비싸다. 이층으로 된 건물이 이쁘고 분위기좋다. 서울한복판 경치가 볼거리. 야경도 이쁠것 같다.',
#   '4점'],
#  ['산모퉁이', '경치가 좋으네요. 근데 모기 공격을 한번에 너무 많이 받았어요ㅠㅠ', '5점'],
#  ['산모퉁이', '분위기 최고예요~~', '5점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이',
#   '솔직히... 뷰는 서울치고 좋지만... 토요일 12시인데도 조용하지만... 가격대비 오는시간과 정성대비는 굳이 일부러 찾아올만하진 않다... 가다오다 지나다 들리면 모를까...',
#   '2점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '부암동 산 모퉁이 카페', '5점'],
#  ['산모퉁이', '커피가 8천원 ㄷㄷㄷ 야경은 괜찮은데 여름에가서 모기뜯겼다 ㅜ', '3점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '경치좋은 카페', '4점'],
#  ['산모퉁이',
#   '대체로 좋았음, 그러나 주차 시설 부족했고 너무기대를 하고 가서인지 생각보다 그냥 쏘쏘했으나 직원들은 대체로 친절함',
#   '3점'],
#  ['산모퉁이', '카페', '5점'],
#  ['산모퉁이', '커피가 비싼만큼 뷰가 좋음ㅋ', '4점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '비오는 산속 넘넘 멋집니다… ', '4점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '분위기 지존. 이 날 고백해서 성공했다.', '5점'],
#  ['산모퉁이', '드라이브 코스 북악스카이 ', '3점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이',
#   '야경과 풍경은 넘좋은데.. 곳곳에 숨은그림찾기하듯 테이블이 있고 커피맛은 그닥~~~ 단속가끔 뜨는데 주차전쟁..ㅠㅜ',
#   '4점'],
#  ['산모퉁이', '음료값이 도가 지나치게 비싸고 맛도 없었던 곳 경치만 좋음 그리고 카페 바닥 청소안하는지 쓰레기 나뒹굼', '1점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '오랜만에 방문한 산모퉁이 비오고 자리없어서 우린 방공호로;', '4점'],
#  ['산모퉁이', '이정도 뷰면 음식은 상관없어진다. 그러나 당케가 맛있고 가격도 미친듯비싸지않음. 자리도많고', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '접근성이 부족하나 최고의 경치를 자랑하는 곳', '4점'],
#  ['산모퉁이', '분위기 괜찮은데 가격이 .. 다른카페에 두배에욥', '5점'],
#  ['산모퉁이', '커피프린스 촬영했던 곳. 분위기 짱 좋음', '4점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이',
#   '부암동. 카페  드라마 커피프린스 1호점에 나온, 북한산 뷰가 좋은 카페.  시내에서 점심식사 후, 좋은 경치를 보면서 커피와 케익을 먹으면서 얘기하기 좋은 카페.  평일 오후 늦게에도, 아줌마 손님이 많은 것이 함정',
#   '5점'],
#  ['산모퉁이', '경치 짱 커피값은 조금 비쌈 아메리카노 7,000원', '5점'],
#  ['산모퉁이',
#   '어른들 모시고 갔는데 좋아들하세요~~ 벚꽃피고 경치너무 좋아요  주차는 너무힘들고 사장님인지 주차아저씨는 불친절하지만 ',
#   '5점'],
#  ['산모퉁이', '풍경이 좋아요~!!', '4점'],
#  ['산모퉁이', '주차전쟁에 노맛임에도 어른들 모시고 부암동가면 여길 가게 되는 내가 미워...', '1점'],
#  ['산모퉁이', '최고예요', '5점'],
#  ['산모퉁이', '좋아요', '4점'],
#  ['산모퉁이',
#   '산기슭에 있는 분위기 좋은 카페. "커피프린스 1호점" 드라마 촬영장소이면서 주변에 "인간의 조건" 촬영했던 게스트하우스 있네요. 특히 뷰가 좋아 데이트하기 좋은 곳입니다.',
#   '4점'],
#  ['산모퉁이', '뷰가 너무 이쁜 곳 근데 가격이 너무 비싸고 외국인들이 많다ㅠㅠ', '4점'],
#  ['산모퉁이', '보통이에요', '3점'],
#  ['산모퉁이', '여기 커피 정말 맛이없습니다 풍경보는건 괜찮지만 뜨듯미지근하면서 맹한 맛에 다시 가고싶지는 않아요', '1점'],
#  ['산모퉁이', '야경이 멋진 카페 사람 진짜 많음', '4점'],
#  ['산모퉁이',
#   '부암동의 주택들이 한눈에 보이는  분위기 좋은 카페.   밤에 와봤는데 낮에와도 좋을듯.  선선할때 자주 가야지~',
#   '5점'],
#  ['산모퉁이',
#   '커피프린스 촬영지로 사람이 항상 많다. 음료는 맛이 없음. 병음료 시켜야함 그런데 경치는 정말 죽인다. 야경보기도 좋고, 하늘 파란날 야외 자리에 앉아도 좋다',
#   '3점'],
#  ['산모퉁이', '전망 좋은 곳~^^', 0],
#  ['산모퉁이', '유자차ᆞ모과차 8천원씩 쿠키5천원 북악 팔각정가기전 카페 분위기도 경치도 괜찮은편', 0],
#  ['산모퉁이', '커피프린스촬영장소', 0],
#  ['산모퉁이', '음료안시키고 잠깐 전망만 봐도 좋을곳', 0],
#  ['산모퉁이', '종로 카페', 0],
#  ['산모퉁이', '우왕ㅋㅋㅋㅋㅋㅋ', 0],
#  ['산모퉁이', '부슬부슬 비가와도 좋은곳~', 0],
#  ['산모퉁이', '정말 사람 많아요', 0],
#  ['산모퉁이', '⭐️⭐️⭐️⭐️ 드라마 커피프린스 1호점 촬영지. 야외테라스에서 바라본 부암동의전경이 최고', 0],
#  ['산모퉁이', '★★★★★', 0],
#  ['산모퉁이', '뷰가 너무 좋은 카페.', 0],
#  ['산모퉁이', '분위기짱!', 0],
#  ['산모퉁이', '분위기 좋은 카페', 0],
#  ['산모퉁이', '종로 게하', 0],
#  ['산모퉁이', '장소는좁은데 사람이 너무많아서ㅡ 화장실에서공유를본듯ㅡ사진이있었던듯', 0],
#  ['산모퉁이', '탁트이는 숨~  바람 좋은 곳', 0],
#  ['산모퉁이', '굿', 0],
#  ['산모퉁이', '카페', 0],
#  ['산모퉁이',
#   '서울 성곽이 내려다보이는 야경이 끝내준다 드라마 커피 프린스에서 이선균씨 집으로 나온 이곳은 북악스카이웨이에서 드라이브를 계획하고 있다면 들를 만한 곳',
#   0],
#  ['산모퉁이', '커피 프린스 1호점.... 산책코스 카페1', 0],
#  ['산모퉁이', '커피프린스1호점~촬영지!!', 0],
#  ['산모퉁이', '북악.팔각정 가기전 카페, 오픈 테라스  커피프린스 촬영장소', 0],
#  ['산모퉁이', '카페.  아름다운 산 풍경과 여유.', 0],
#  ['산모퉁이', '', 0],
#  ['산모퉁이', '부암동', 0],
#  ['산모퉁이', '풍경쵝오!!', 0],
#  ['산모퉁이', '카페', 0],
#  ['산모퉁이', '뷰, 뷰, 뷰', 0],
#  ['산모퉁이', '자연의 카페', 0],
#  ['산모퉁이', '커피프린스 촬영장소', 0],
#  ['산모퉁이', '부암동 까페 경치좋은곳.', 0],
#  ['산모퉁이', '커피프린스촬영장소', 0],
#  ['산모퉁이', '테라스에서 보는 경치가 너무 좋아요~ 주말은 사람이 너무 많으니 패스!!', 0],
#  ['산모퉁이', '우왕 가슴이 탁 트이는듯한 기분! *.* 커피프린스 1호점 !!', 0],
#  ['산모퉁이', '커피프린스 촬영장소 경치도 좋구나 ㅋㅋ', 0],
#  ['산모퉁이', '산모퉁이', 0],
#  ['산모퉁이', '커피프린스 촬영장소로 유명!!', 0],
#  ['산모퉁이', '최근 유명세 때문에 사람이 넘 많다~ 주중 오전 또는 오후에 가서 차한잔 강추!!!', 0],
#  ['산모퉁이', '모기조심, 전망좋음', 0],
#  ['산모퉁이', '커피 프린스', 0],
#  ['산모퉁이', '전망좋은커피점', 0],
#  ['산모퉁이', '밤 야경 분위기는 굿!', 0],
#  ['산모퉁이', '말이필요없음', 0],
#  ['산모퉁이', '커피 멋진 곳', 0],
#  ['산모퉁이', '멋짐', 0],
#  ['산모퉁이', '공룡주의', 0],
#  ['산모퉁이', '이선균의 노랫소리가 들리는 듯하다.', 0],
#  ['산모퉁이', '언제나 좋은 곳', 0],
#  ['산모퉁이', '요기 좋은데..', 0],
#  ['산모퉁이', '커피프린스 촬영장소로 유명해진 카페. 북악스카이웨이 드라이브하고 여기서 커피한잔!', 0],
#  ['산모퉁이',
#   "부암동 '환기미술관' 위로 쭉 올라가면 나오는 산모퉁이 카페. ☕️커피 마시기 참~좋은 날씨구나! 이 계절을 붙잡고싶다.",
#   0],
#  ['산모퉁이', '북악스카이웨이 전망좋은카페', 0],
#  ['산모퉁이', '야경이 정말 이쁜곳! 카페모카 커피곰도 귀엽다.', 0],
#  ['산모퉁이', '산모퉁이 넘 이쁘고 쿠키 맛나요~!!+_+', 0],
#  ['산모퉁이', '이젠 좀 식상해진 느낌', 0],
#  ['산모퉁이', '산모퉁이', 0],
#  ['산모퉁이', '경치가 좋아요. 산책하고 커피. 음료 및 음식보다는 분위기와 경치가 좋은곳', 0],
#  ['산모퉁이', '부암동 산모퉁이 ;)   첨가본 곳인데 야경이 너무 예뻤다~ 💓 까페도 넓고 내부도 예쁘고 또 가고픈 곳 ^.^', 0],
#  ['산모퉁이', '커프', 0],
#  ['산모퉁이', '여기 최고임 ㅋㅋㅋ  가는 길은 힘들지만  도착하고나면 보람 느껴요 ㅋㅋ', 0],
#  ['산모퉁이', '추억의장소', 0],
#  ['산모퉁이', '커피프린스1호점', 0],
#  ['산모퉁이', '경치가 끝내줌! 백사길 계곡트래킹 후 들리면 최고!!^^', 0],
#  ['산모퉁이', '백사실에서 쉬다가 차한잔 ok?', 0],
#  ['산모퉁이', '경치좋다', 0],
#  ['산모퉁이', '음 주말에 한번 가면 좋은곳일듯.', 0],
#  ['산모퉁이', '인간의조건 생각하며 차없이 걷기. 힘듬 ㅋ', 0],
#  ['산모퉁이', '레이는 올라가다 뒤집어 질지도 몰라...', 0],
#  ['산모퉁이', '모닝 아메리카노.', 0],
#  ['산모퉁이', '산모퉁이의 테라스에서 바라보는 북악산과 인왕산의 풍경을 느끼고 싶다면!', 0],
#  ['산모퉁이', '조금 일찍 닫는거랑 주차 빼고는 굿', 0],
#  ['산모퉁이',
#   '경치나 분위기로는 더 이상 말이 필요없는 집. 부암동 데이트 코스로는 화룡점정! 드라마 커피프린스의 이선균 집으로 더 유명해진 집!  해질녘 석양빛으로 물들어가는 경치를 보며 시원한 아이스 아메리카노 한잔!',
#   0],
#  ['산모퉁이', '한번은 가볼만. 테이블 간격 넘 좁고 사람 넘 많음 ㅠ', 0],
#  ['산모퉁이', '역시 경치짱인곳 하지만 가격이ㅎㄷㄷ', 0],
#  ['산모퉁이', '북악산 산모퉁이 사계절내내 매력터지는 나만의 힐링플레이스', 0],
#  ['산모퉁이', '커피프린스1호점 촬영지~!', 0],
#  ['산모퉁이', '쿠폰있지롱', 0],
#  ['산모퉁이', '커휘프린스 이선균네집이었는뎅 히히 실제로는 엄청 조그마한ㅋ', 0],
#  ['산모퉁이', '여기 그... 커피프린스인가? 뭔가 암튼 드라마 나온곳일텐데..  삭속에 숨어있다으...', 0],
#  ['산모퉁이', '산모퉁이카페~  커피프린스 촬영지 사람많아서 아무것도 못먹고 ㅠ', 0],
#  ['산모퉁이', '커피숍 / 커피프린스 찰영지', 0],
#  ['산모퉁이', '주차가 불편.', 0],
#  ['산모퉁이', '커피프린스와 멋진전망으로 사람이바글바글', 0],
#  ['산모퉁이', '부암동 전망좋은 찻집', 0],
#  ['산모퉁이', '커피프린스', 0],
#  ['산모퉁이', '언덕서 차한잔', 0],
#  ['산모퉁이', '산모퉁이 커피프린스 이선균 집으로 유명해진 곳ㅋ 부암동 최고 산꼭대기 3층짜리 카페ㅋ 사진찍기 좋은 곳^^', 0],
#  ['산모퉁이', '커피프린스1호점 촬영지! 또 가고싶당..', 0],
#  ['산모퉁이', '사람 많은 드라마 촬영지', 0],
#  ['산모퉁이', '커피프린스ㅡ한성이네 집', 0],
#  ['산모퉁이', '커피프린스.북악스카이웨이갔다가 아메', 0],
#  ['산모퉁이', '드라마 촬영지 카페', 0],
#  ['산모퉁이', '오빠랑^^', 0],
#  ['산모퉁이', '인천에서 바로쏴~ㅋ 커피프린스 1호점 촬영장인데..기억이 잘..ㅋㅋ', 0],
#  ['산모퉁이', '커피프린스 이선균네집! 여기 놀러갔을때 너무좋았어... 너랑가서', 0],
#  ['산모퉁이', '산모퉁이', 0],
#  ['산모퉁이', '생각보다 볼게많은 울동네', 0],
#  ['산모퉁이', '부암동 산모퉁이 커피프린스', 0],
#  ['산모퉁이', '장소는 좋다. 하지만 커피와 케잌은 맛이 없다. 주말에 차가지고 오지 말 것.', 0],
#  ['산모퉁이', '야경이 끝내죠요,  야밤엔 황금용도 볼수있다요! ＼(^◇^)/＼(^◇^)/', 0],
#  ['산모퉁이', '', 0],
#  ['산모퉁이', '북악스카이웨이 산모퉁이~커피값의 압박ㅋㅋ', 0],
#  ['산모퉁이', '드라마 커피프린스에서 나온 이선균집^^ 첨에갔을땐 한적했는데 이젠 많이알려져서^^', 0],
#  ['산모퉁이', '주차 어려웠던 이 곳. 커피맛은 소소. 대신 분위기와 멋진 야경 최고.', 0],
#  ['산모퉁이', '경치짱~~~', 0],
#  ['산모퉁이', '커피프린스찰영한곳', 0],
#  ['산모퉁이', '경치좋은카페', 0],
#  ['산모퉁이', '', 0],
#  ['산모퉁이', '커피 프린스란... 드라마 촬영지 경치는 좋지만... 커피맛은 고만고만...  나의 평가 : ++', 0],
#  ['산모퉁이', '서울이 한 눈에 경치좋은곳', 0],
#  ['산모퉁이', '이쁜곳', 0],
#  ['산모퉁이', '서울이 한 눈에.. 경치 굿..', 0],
#  ['산모퉁이', '커피 프린스', 0],
#  ['산모퉁이', '커피 그리고...', 0],
#  ['산모퉁이', '커피 마시러~~', 0],
#  ['산모퉁이', '오늘가본  커피 프린스', 0],
#  ['산모퉁이', '커피는 비싸지만 경치는 짱!!', 0],
#  ['산모퉁이', '커피는 별로지만 풍경이 캬~~', 0],
#  ['산모퉁이', '자주가는곳! 경관굿!', 0],
#  ['산모퉁이', '시끌법석한 카페는 좋지만 너무 많은 사람이 오간서 정신 사납네. 경치는 참 장관이다.', 0],
#  ['산모퉁이', '훈사모 모인곳', 0],
#  ['산모퉁이',
#   '부암동 꼭대기에 위치한 카페~~  탁트인 자연의 전망을 볼수 있다...! 독특한 소품들도 많았구, 커피프린스 촬영지인가 그렇다~',
#   0],
#  ['산모퉁이', '좋군.', 0],
#  ['산모퉁이',
#   '여기 차 맛은 없다.. 카라멜 마끼아또 시켰더니 탄맛이 낳더라.. 가격도 비싸고.. 다시는 가고 싶지 않다..ㅋㅋ',
#   0],
#  ['산모퉁이', '여기두 좋을 것 같다..', 0],
#  ['산모퉁이', '부암동 산모퉁이- 커피프린스1호점 공유의집.', 0],
#  ['산모퉁이', '야경이 좋은 곳~ 커피프린스 한성의 집', 0],
#  ['산모퉁이', '4월7일. 강촌쌈밥먹구 산모퉁이...', 0],
#  ['산모퉁이', '뷰가 아름다운 커피숍. 커피프린스 촬영지. B+', 0],
#  ['산모퉁이', '커피 프린스 촬영지', 0],
#  ['산모퉁이',
#   "오랜만에주말데이트~~ 비오는날분위기있게커퓌한잔..  여긴부암동'산모퉁이' 커피프린스 이선균이살았던 집이란다..  우리와이프앞머리가 솰아있네 솰아있네 솨솨솨!",
#   0],
#  ['산모퉁이', '커피프린스 촬영지 경치는 좋으나 음료는 별루 그냥 그런..', 0],
#  ['산모퉁이', '차, 디저트류는 별룬데 경치때메~ 고고~', 0],
#  ['산모퉁이', "커피프린스의 '쓸자'네 집으로 유명한 카페! 지하에 멋진 촬영소가 있어요©", 0],
#  ['산모퉁이', '^^~~♥', 0],
#  ['산모퉁이', '서울성곽과 서울야경', 0],
#  ['산모퉁이', '공기좋은 산모퉁이의 카페', 0],
#  ['산모퉁이', '산모퉁이카페 커피프린스 촬영지', 0],
#  ['산모퉁이', '쪼아쪼아', 0],
#  ['산모퉁이', '날씨 좋은날~', 0],
#  ['산모퉁이', '산모퉁이카페', 0],
#  ['산모퉁이', '커피프린스', 0],
#  ['산모퉁이', '가족과 가본 부암동 산모퉁이!  오늘은 정말 가고 싶은 날이다!', 0],
#  ['산모퉁이', '커피프린스로 유명해진 카페여서 외국 관광객들이 많이 옴', 0],
#  ['산모퉁이', '커피프린스 촬영장소로 유명해진 카페. 북악스카이웨이 드라이브하고 여기서 커피한잔!', 0],
#  ['산모퉁이',
#   "드라마 '커피프린스'에서 이선균의 집으로 나왔던.. 카페이다. 지하1층에는 각종 파티용품이 있고 지상 3층까지 되어있어 부암동의 야경또한 즐길수 있다.  Tip.주차불가(가는 오르막길에 주차해야됨)",
#   0],
#  ['산모퉁이', '하나도 아깝', '1점'],
#  ['산모퉁이',
#   '오늘 오후 지인들과 카페에 도착하여 입구에서 주차도우미의 안내로 길가에 차를 주차하고 카페에서 커피를 마시고 있는데  주차단속이 나왔다는 안내방송이 나와서 밖으로 나가보니  이미 저와 지인차, 주변차들에 과태료 부과 딱지가 붙어 있었습니다. 직원은 카페주차장에 세우지 않아서라고 말합니다. 황당했습니다. 너무 불친절한 태도에 맘이 불편하고 속상했습니다.',
#   '1점'],
#  ['산모퉁이',
#   '여긴 정말 커피값도 말도 안되게 비싸지만 직원들 태도가 최악입니다.  물론 멋진뷰를 보기 위해, 명소에 찾아가기도 하지만 정말 사람대 사람으로서 찾아오는 사람들을  그렇게 무시하고 불친절한지 기억하고 싶지도 않네요.  이곳 만큼 멋진 뷰를 가진곳 많으니 다른 곳을 가는 것이 맞다고 생각합니다.',
#   '1점'],
#  ['산모퉁이',
#   '예전에 커피프린스 보고 근처 들렸는데, 왜그렇게 직원들이며, 계산해주시는분이며 불친절하신거죠?  아니 갑질하는 분들때문에도 문제지만, 비싼돈 주고 사먹는데 최소한의 서로에대한 예의는 지켜줘야하는거 아닌가요? 아 정말 기분이 너무 나빠서 이렇게 남기네요. 정말 직원교육(예절교육,도덕교육) 좀 하세요. 이제 커피프린스좀 그만 팔구요.아 정말 화가납니다.',
#   '1점'],
#  ['산모퉁이',
#   '좁은 공간에 작은 테이블이 따닥따닥에 석상과 피규어 또 오징어와 생선은 무슨 인테리어인지..직원들은 어쩜그리 다들 불친절한지 메뉴 물어보니 한숨쉬면서 노려보질 않나..가격은 스타벅스보다 비싼데 맛도 없음',
#   '1점'],
#  ['산모퉁이', '왜 마이너스는 없는거야!', '1점'],
#  ['산모퉁이', '커피값이 8000원이라 좀 부담되긴하지만 경치하난 진짜 끝장이에요 ', '3점'],
#  ['산모퉁이',
#   '사장님이란 분 참 불친절해요 ...아이를 툭툭 치면서 구석구석 진열된 것들 만지지 말라고 하더군요...본인의 강아지는 안고 다니면서 말이죠. 사장님께 귀한 개가 있듯이 나도 내새끼 귀합니다. 친절하면 당연 커피맛도 좋게 느껴질텐데...안좋은 기분으로 돌아왔네요.',
#   '1점'],
#  ['산모퉁이', '커피프린스에나왔다는이유하나로뜬집. 경치는최고지만커피맛은별로에요', '2점'],
#  ['산모퉁이', '소문에 비해 실속은 없는 곳 언덕 주차 좀 난코스', '2점'],
#  ['산모퉁이', '솔직히 커피맛은 보통이나 분위기와 경치는 정말 좋아요. 서울같지않은 정취가 느껴짐', '3점'],
#  ['산모퉁이', '전망과 유명세에 가지만 커피맛은 그닥 ㅎㅎ', '2점'],
#  ['산모퉁이', '찾아가는 길이 쉽지 않고 차 없으면 힘든 것 맞지만 그래도 꽤나 전망이 좋아서 그걸로 ok~', '4점'],
#  ['산모퉁이',
#   '찾아 가는길이 쉽진 않고, 주차해주는 사람이운전못해 소리만 지름. 경치는 좋은데 차값이 비쌈. 암튼 커피프린스에 나온 집이라 몇번갔는데 엄청 아담함',
#   '1점'],
#  ['산모퉁이', '앞에 세워진 자동차 땜에 시선이 확 가지만 실속은 없어요', '3점'],
#  ['산모퉁이',
#   '커피 프린스에서 이선균의 집으로 사용되어 유명해졌죠. 여기 차 없으면 못 가긴 하는데, 정말 풍경 끝내줍니다. ',
#   '5점'],
#  ['산모퉁이', '기분전환삼아 드라이브 다녀오기에도 아주 좋더라구요!!', '4점'],
#  ['산모퉁이', '분위기는 굿굿굿.', '4점'],
#  ['스태픽스',
#   '커피 산미 있어유~  실내 음악소리 큰편이에유~  실내 그닥 안넓어유~  상주 댕댕이는 없음 ㅜㅜ  만족스러운 카페입니다 :) ',
#   '4점'],
#  ['스태픽스', '풍경이 좋아요~~', '5점'],
#  ['스태픽스', '오디오 사운드, 은행나무, 그리고 선곡이 일 다 함 ㅎ 스콘 같은 델리 류를 더 바리 해주시면 어떨지 ㅎ', '4점'],
#  ['스태픽스',
#   '음료는 그냥 그래요 맛있지는 않음. 그냥 뷰 맛집이네요. 한번정도는 와볼만한데 두번이상 굳이? 여기까지 오지는 않을듯',
#   '3점'],
#  ['스태픽스', '커피맛은 잘 모르겠지만,, 큰 은행나무가 있는 마당에서 햇빛쬐면서 먹는 커피는 최고였어요!  ', '5점'],
#  ['스태픽스',
#   '커피 연하고 맛없어요 돈아까비 커피 맛은 별 한개도 아까워요 직원도 불친절하고 특히 매니져라는 여자분 진짜 말투며 전화받는거 ♪♩♬♩ 없드라고요',
#   '1점'],
#  ['스태픽스',
#   '커피 맛은 그냥 그렇고 티를 시켰는데 티백우려 주는 건데 가격은 너무 비쌌어요. 팔천원... 넓은 정원에 있는 가격인 것 같네요.. 뷰가 좋은 건 아닌데 테라스가 큰 곳이 많지 않아 사람들이 많이 오는 것 같아요. 뷰는 그냥 앞에 건물이에요.. 실내는 음악이 너무 시끄러워서 있을 수가 없었어요..  그리고 음료에 빨대를 꽂아주시는데 입 닿는 부분을 손으로 ...',
#   '2점'],
#  ['스태픽스', '서울에 이런곳이 있다는것만으로도 만족 커피가 조금 비싸고 뷰가맛있어요 (아이스아메 5.5)', '5점'],
#  ['스태픽스', '공간이 매력적이예요오 또 갈만한곳', '5점'],
#  ['스태픽스', '최고예요', '5점'],
#  ['스태픽스', '좋아요', '4점'],
#  ['스태픽스', '마당이 매력적이지만 커피는 맛이 갔어요.', '2점'],
#  ['스태픽스', '주차관리인 핵 불친절', '1점'],
#  ['스태픽스', '뷰도 좋고 주차가 돼서 좋아요. 커피는 그닥 ㅜㅜ', '3점'],
#  ['스태픽스',
#   '올라가는 길이 꽤 힘들고.. 사람 넘 많고.. 인스타용 사진 건지려는 사람들 틈에서 민망해서 고개를 들 수가 없던 곳..... ',
#   '2점'],
#  ['스태픽스',
#   '노래가 너무 시끄러워서 이어플러그를 꼈는데도 스트레스가 너무 치솟아요.. 카페를 나오고 나서 얼마동안은 이명이 들리는 정도입니다. ',
#   '1점'],
#  ['스태픽스',
#   '요즘 시국에 야외 테라스가 넓은 카페라 좋았지만 커피가 너무 너무 연해요....맛이 없는건 아니지만 조금 아쉬웠네요 햇살 좋은날 한번쯤 들릴만한 곳',
#   '3점'],
#  ['스태픽스', '좋아요', '4점'],
#  ['스태픽스', '별로예요', '1점'],
#  ['스태픽스', '넓은 마당외에는 장점이 없음', '2점'],
#  ['스태픽스', '주차안돼요. ', '2점'],
#  ['스태픽스', '분위기가 아주 좋아요', '5점'],
#  ['스태픽스', '엄청 넓은데 그거말고는 딱히 특이점없움', '3점'],
#  ['스태픽스',
#   '실내에 앉았는데 음악 소리가 고막 찢어질듯해서 카운터 가서 요청. 직원 5명이 내가 다섯 번 불러도 아무도 못 들음. 카페 컨셉이라 참으라는 답변. 커피 밍밍~',
#   '1점'],
#  ['스태픽스', '그냥 자리값~~~~~~', '1점'],
#  ['스태픽스',
#   '사장님이 이글을 꼭 보시길 바랍니다.. 좀 더 안전한 파라솔로 교체해주세요 파라솔 밑에가 원형이 아닌 반형이네요..  바람 때문에 파라솔이 위태로워 보이긴 했습니다. 결국 바람 때문에 파라솔 위쪽이 다 뒤집어지고 넘어져 탁자 컵이 다 깨졌네요 다행히 사람은 안 다쳤지만 만약 사람이 있었다면 큰일이였겠죠. 직원분들이 괜찮냐는 말 없이 그냥 치우고 이런적 처음...',
#   '1점'],
#  ['스태픽스', '최고예요', '5점'],
#  ['스태픽스', '커피가 맛있지는 않은데 인테리어가 정말 이뻐요  하지만 사람이 진짜 많아서 작업하기는 좋지 않네요', '4점'],
#  ['스태픽스', '차가 없으면 오기까지 힘들긴 한데,   야외자리 있어서 좋았어요', '5점'],
#  ['스태픽스', '조금 더 따뜻해지고 평일에 오면 좋을 듯.  주말엔 조금 소란스럽. ', '3점'],
#  ['스태픽스', '커피 맛은 다른가게랑 별차이 없지만 야외 테이블에서 본 경치가 좋습니다', '4점'],
#  ['스태픽스', '임대료가 비싼가... 빵 가격치고 양이 정말 적어서 놀랐네용..', '3점'],
#  ['스태픽스', '너무최고', '5점'],
#  ['스태픽스', '보통이에요', '3점'],
#  ['스태픽스', '다 좋고 커피도 맛있는데 음악소리가 너무 커서 머리아파서 금방 나와버림ㅠㅠ', '4점'],
#  ['스태픽스',
#   '여름에 가야 이 장소의 참맛을 알게되는듯. 노래 선곡은 좋은데 실내에 있다보면 볼륨이 큼. 그래도 워낙 장소가 좋아서 주말에 자주 가게됨',
#   '4점'],
#  ['스태픽스',
#   '생각보다 별로네요. 꽤 크고 넓을줄 알았는데 자리도 많지 않고 여유롭기보다 정신없고 좀 어수선한 분위기. 우선 날이 좀 따듯한 때 다시가서 바깥에 있어봐야겠어요',
#   '3점'],
#  ['스태픽스', '뷰가 너무 좋고 음료도 맛있네요!', '5점'],
#  ['스태픽스', '최고예요', '5점'],
#  ['스태픽스',
#   '봄가을에 다시 가봐야할듯 후기는 좋다고 해서 갔는데 겨울이라 허허벌판임 푸릇할때 다시 가보면 맘이 달라질려나',
#   '3점'],
#  ['스태픽스',
#   '주차가능이라고 되어있는데 아니라서 별로에요. 건물 앞 주차 자리에 댔더니 옆 유료주차장 아저씨가 나와서 들어올 차 있다고 빼라고 다짜고짜 소리 지르네요. 바로 옆에 주차장에 대라고 해서 들어갔는데 무작정 퉁명스럽게 주차하라는 말만 하더라고요. 카페랑 연관되어 있는 곳이냐고 물었더니 아니래요. 유료주차장 주차비 따로 내야한대요. 미리 말을 해주면 모르겠는데 ...',
#   '1점'],
#  ['스태픽스', '뷰가 다했다ㅠㅠ', '5점'],
#  ['스태픽스', '나만 알거야ㅠ', '5점'],
#  ['스태픽스', '최고예요', '5점'],
#  ['스태픽스', '숨겨진 곳  아무도 몰라라.. 나만 가게...', '5점'],
#  ['포비 광화문점', '베이글 맛있었어요', '4점'],
#  ['포비 광화문점',
#   '향도 그렇고 베이글이 많이 단단하지 않아서 약간 식빵같은 느낌이 있었어요 무화과 스프레드 발라 먹으니 달달해서 맛있었습니다! 아메리카노는 고소한 원두로 마셨는데 진하지 않고 약간 숭늉 같은 맛... 나쁘지 않았어요   화장실은 가게에서 나와서 오른쪽으로 돌아 다시 건물 내로 들어가면 있습니다',
#   '4점'],
#  ['포비 광화문점',
#   '단골이에요. 근데 포장할때마다 느끼지만 ㅠ 굽자포 얘기 미리 안하면 손님 탓하는 느낌을 매번 받아요 (구워서 잘라서 포장) 주문받을때 직원분이 확인하거나 디폴트로 해주는게 더 상식적이지 않나요? ㅠ',
#   '3점'],
#  ['포비 광화문점', '커피랑 베이글하면 가장 먼저 떠올라요', '5점'],
#  ['포비 광화문점', '분위기도좋고  커피맛있어요', '4점'],
#  ['포비 광화문점', '허니밀크+무화과 조합에 플랫화이트 한잔! 크아~', '5점'],
#  ['포비 광화문점',
#   '여기 스프레드 맛있는지는 모르겠네요. 제 입엔 그냥 달달한 요구르트 맛이에요. 크림치즈 향 전혀 나지 않아요^^; 베이글 자체는 두툼하지만 그만큼 가격도 비싸요. 특색 있는 맛은 아니니 찾아가지 마시고 컬리에서 주문해서 드세요.',
#   '2점'],
#  ['포비 광화문점', '베이글은 쫀쫀하고 크림치즈는 적지만 맛있어요. 여긴 커피도 좋아요. ', '5점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점', '맛나요', '5점'],
#  ['포비 광화문점', '별로예요', '1점'],
#  ['포비 광화문점',
#   '초코라떼가 두유색에 맛도 연해서 조금만 진하게 요청 드렸더니  원래 베이스로 타놓고 따라 주는거라 맛조정이 안된다 하네요^^; 그냥 레시피 자체가 맛이없는걸로..ㅠㅠ  그래도 커피는 맛있었네요ㅎㅎ',
#   '2점'],
#  ['포비 광화문점', '예전보다 달아진 것 같아요. ', '3점'],
#  ['포비 광화문점', '그렇저렇 괜찮아요', '3점'],
#  ['포비 광화문점', '보통이에요', '3점'],
#  ['포비 광화문점', '베이글도 맛있는데 무화과 크림치즈가 찐.... 자리 불편한게 흠 ㅠㅠ', '5점'],
#  ['포비 광화문점', '먹고 맛없다고 하는 사람 있을까 싶은 촉촉한 베이글. 담에 가면 시나몬으로 먹어봐야지', '4점'],
#  ['포비 광화문점',
#   '진짜 위생이 최악입니다. 커피시켰는데 커피 내릴때 가루를 기계에서 뽑는데 이때 가루가 그 동그란통안에 볼록하게 쌓이면 그걸 손으로 쓰윽해서 평평하게합니다. 제가 용어를 잘 몰라서 이렇게 설명합니다만 이해되시길 바랄께요..  코로나 인데 이렇게 비위생적인게 이해가 안가네요.. 이럴꺼면 왜 오픈키친로 한건지 모르겠어요. 더군다나 알바생들 손에 위생장갑도 안끼고...',
#   '1점'],
#  ['포비 광화문점', '베이글 진짜진짜 맛있는 집 ♡', '5점'],
#  ['포비 광화문점', '최애카페. 공간이 협소하고 의자가 불편하긴 하지만 그 마저도 매력있는 곳. ', '5점'],
#  ['포비 광화문점',
#   'not a new york bagel but still pretty good—super soft and pillowy even after toasting and didn’t harden (important for me since i’m a slow eater). it did remind me more of bread than a bagel necessari...',
#   '4점'],
#  ['포비 광화문점', '최악', '1점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점',
#   '쑥 베이글... 이렇게 맛있을 것이라는 생각 못했는데... 그냥 건강한 맛일 듯해서 선택했는데 쫀득한  베이글 식감에 쑥향과 특유의 쑥 단맛... 크림치즈를 일부러 안시켜보았는데 잘 한 듯하다. 쑥맛 좋네~ 에스프레소도 좋구~ 좋네. 포비 디엠지와 다른 분위기지만 둘 다 맘에 든다.',
#   '5점'],
#  ['포비 광화문점', '어우 존맛탱', '4점'],
#  ['포비 광화문점',
#   '가성비 좋음. 어디하나 모난 것은 없음. 맛도 좋음. 재방문 의사 높음. 사람이 많아 소란스러움. 합정 지점 보다 사람은 쾌적함',
#   '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '점심 먹고 자주 들립니다. 맛있고 친절한 곳.', '5점'],
#  ['포비 광화문점', '보통이에요', '3점'],
#  ['포비 광화문점',
#   '시나몬 베이글에 크랜베리 크림치즈 발라먹으니 정말 맛있어요. 베이글 무슨 맛으로 먹나싶었는데 간만에 맛있는거 먹었네요. 매장에서 먹어서 그런지 따뜻하고 바삭하고 핵맛ㅠㅠ 커피는 산미가 많이 느껴져서 제 입맛엔 별로였어요.',
#   '4점'],
#  ['포비 광화문점', '사람이 많긴한데 베이글은 맛있어요.', '4점'],
#  ['포비 광화문점', '커피는 평범. 베이글맛있습니다', '4점'],
#  ['포비 광화문점', '피꼴로+볼케이노+무화과. 사람이 너무 많긴 함. 직원들 친절함.', '5점'],
#  ['포비 광화문점', '베이글 따뜻하게 먹음 맛 좋음. 커피는 그럭저럭', '4점'],
#  ['포비 광화문점', '베이글맛집 최애입니다!!', '5점'],
#  ['포비 광화문점', '평이 좋길래 갔는데 평범한디용? 대학가에서 파는 베이글이랑 비슷하고 특별한 건 없어용', '3점'],
#  ['포비 광화문점',
#   "Coffee's not bad and I love that they have piccolo which is hard to find in Korea. But when you order a takeout they double cup the coffee. I mean, it's 2020 - we're switching to paper straws these da...",
#   '2점'],
#  ['포비 광화문점', '조화롭다', '4점'],
#  ['포비 광화문점', '갈때마다 원하는게 없어서 아쉬워여', '3점'],
#  ['포비 광화문점', '베이글 맛있어요! 음료는 평범하고 의자는 좀 불편하네요ㅠ', '3점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점', '자리는 불편했지만, 베이글은 역시 ^^', '5점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점',
#   '아침일찍 왔는데 다른곳은 다 비어있는게 여기만 바글바글 사람 많은곳엔 이유가 있다.  맛 서비스 둘 다 만족스럽다. 친절하고 싹싹하게 잘하신다.  불만 딱 한가지는 회전율을 높이기 위해서 인지  좌석이 불편하다 정도?   장기간 앉아 계실분은 다른 카페를 찾는게 좋겠다 ',
#   '5점'],
#  ['포비 광화문점', '사람 진짜 많았어요 ㅠㅠ 근데 베이글도 맛있구 커피도 괜찮았어용!! ', '4점'],
#  ['포비 광화문점', '주차도 편하고 좋아요', '5점'],
#  ['포비 광화문점', '예전 그 아메리카노 맛이 아니다', '2점'],
#  ['포비 광화문점', '행복은 멀리 있지 않다 (의자와 테이블이 죠굼 불편. 회전속도를 높이기 위함인 걸까.)', '4점'],
#  ['포비 광화문점',
#   'Freshly baked bagels on a daily basis!  Great place to fix your bagel cravings along with a coffee   Love the different kind of cream cheese available in the store too  ♥️',
#   '4점'],
#  ['포비 광화문점',
#   '마이 스팟 중 하나에요 생각하기 딱 좋고 친구들과 담소 나누기에도 좋아요 아마 적절한 테이블 배치와 음악 덕분인 것 같아요 베이글도 참 맛좋지만 저는 티도 참 좋더라구요 :)',
#   '5점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '틀어주는 재즈 음악이 너무 좋다', '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '보통이에요', '3점'],
#  ['포비 광화문점', '의자가 불편한 것 제외하고는 다 좋았어요~ 베이글이 맛있어요.', '4점'],
#  ['포비 광화문점',
#   '너무 큰 기대를 하고 가지 않으면 괜찮다. 보통보단 낫지만 굳이 찾아갈 정도는... 베이글은 평범하고 크림치즈는 꽤 괜찮았다.',
#   '3점'],
#  ['포비 광화문점', '깔끔하고 친절해요', '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '정말 좋아하는 곳인데 사람이 항상 많아서 자리 얻기 조금 힘든 곳', '5점'],
#  ['포비 광화문점', '모던한 분위기에 맛있는 커피와 베이글. 가격도 괜춘~ 다만 의자가 높고 불편해서 아이들은 불편할거예요', '4점'],
#  ['포비 광화문점',
#   '솔직히 베이글만 맛있을줄 알았는데... 커피도 맛있어서 놀랐어요! 토마토스프레드가 먹고싶었는데 없어서 파인애플,무화과,크렌베리 세가지 먹었는데 다 맛있어요ㅠㅠ 특히 파인애플 최고...',
#   '5점'],
#  ['포비 광화문점', '모든 커피가 맛있습니다 모든 베이글이 맛있습니다', '5점'],
#  ['포비 광화문점',
#   '가야는이유 : 베이글 스프레드 뿐만 아니라 커피도 맛있음 안가는이유 : 의자가 굉장히 불편  베이글과 스프레드를 선택 할 수 있음 어느걸 선택해도 괜찮음 원두도 괜찮음, 빵은 가져다주고, 음료는 이름 부름 아메리카노 없고 롱블랙만, 라떼 없고 플랫화이트인데 양 조절 선택 가능',
#   '4점'],
#  ['포비 광화문점', 'Good experience overall ', '5점'],
#  ['포비 광화문점', '깔끔하고 친절하고 커피맛도 훌륭함!!!', '5점'],
#  ['포비 광화문점', '커피도 베이글도 맛있어요, 요즘 사람이 많아진 것 같은데.. 가격이나 퀄리티는 유지 되길', '4점'],
#  ['포비 광화문점',
#   '포비 너무나 좋아하는곳인데... 커피주문하고 직원이 이름부르는데... 자리가 안쪽에 있었더니... 하나도 안들려서 몇번을 왔다갔다 했는지.. 정작 저 부를때는 저 아닌줄 알고 가만있었네요.. 넘나 짜증... 시스템좀 바꾸세요. 돈 많이 벌지않았어요?? 직원한테 마이크를 채우든지... 목소리를 크게 부르든지... 커피맛 떨어지더라구요.',
#   '3점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점',
#   '베이글 그냥 맨입에 뜯어 먹어도 맛있고 커피도 진짜 맛있다  점심 시간에 사람 너무 많아서 자리 없는게 최대 단점 ',
#   '5점'],
#  ['포비 광화문점',
#   '광화문 D타워 1층에 있는 베이글 전문점. 베이글 종류는 5가지 정도 되고, 함께 먹을 수 있는 크림스프레드를 파는데 무화과랑 크렌베리가 개존맛! 특히 무화과가 베스트라 빨리 빠짐. 다만 입소문이 나서 카페가 자리가 꽉 차 줄서서 기다려야 함.  (주의!) 베이글 테이크아웃 할 경우 반으로 커팅이 안되어있으니 참고하시길  + 오… 아무도 눈길 주지 않는 파...',
#   '5점'],
#  ['포비 광화문점', '커피도 커피지만, 브랜드답다고 생각하는 몇 안되는 브랜드, 포비.', '5점'],
#  ['포비 광화문점', '2018.8.11 오후 5시 카운터 남자 직원 너무 불친절 하네요', '1점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '베이글이랑 스프레드에 중독됨 ㅎㅎㅎ', '5점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점', '무화과 스프레드 존맛 ㅠㅠ', '5점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '정말 특별한 베이글...커피도 맛있다', '4점'],
#  ['포비 광화문점', '최고예요', '5점'],
#  ['포비 광화문점', '모노클 가이드북이 있어서 깜놀. 역시 의자가...', '4점'],
#  ['포비 광화문점', '커피맛있답, 이쁘답,', '4점'],
#  ['포비 광화문점', '교보문고에 왔다가 그냥 들렀는데.. 괜찮아요~ 커피 베이글 모두 굿', '4점'],
#  ['포비 광화문점',
#   '광화문카페중 베이글과 커피가 맛있기로 유명! 카페안에서 만드는 탱글탱글한 수제베이글, 전문 바리스타들이 내려준 커피. 플랫화이트보다 더 진한맛을 느낄 수 있는 이곳의 인기메뉴 피콜로',
#   '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '베이글과 커피가 괜찮음', '4점'],
#  ['포비 광화문점', '좋아요', '4점'],
#  ['포비 광화문점', '베이글 실합니다, 커피는 너무 씁니다', '4점'],
#  ['포비 광화문점', '베이글이 진짜 맛남. 커피의 맛와 양도 만족! 자리가 좀 불편한게 약간의 흠ㅋㅋ', '4점'],
#  ['포비 광화문점',
#   '광화문 디타워에 있는 가격대 괜찮은 맛있는 커피. 분위기도 심플하니 좋다. 아직 베이글은 못먹어봄 흑흑.  + 베이글 먹어봄. 베이글이 진정 진리임. 텍아하지 않고 매장에서 따땃하게 먹어야함. 토마토 크림치즈 먹었는데, 피자맛. 다른거도 도전할 예정.',
#   0],
#  ['포비 광화문점', '베이글과 스프레드의 조합 짱맛 인정.', '5점'],
#  ['프릳츠 원서점', '커피 너무 맛있어요오 근데 여기서 나오는 노래들 너무 기괴해요... ', '4점'],
#  ['프릳츠 원서점',
#   '안국에서 생각보다 제일 편히 들를 수 있는 곳이에요. 날이 추울 때도 밖에 앉아야하는 때가 있다는 게 조금 아쉽지만요. ',
#   '4점'],
#  ['프릳츠 원서점',
#   '빵과 커피 모두 그냥 그저 그랬다. 빵 식감이 약간 눅눅했다. 갓 지은 빵을 생각했지만 아니었다. 취식 공간이 따로 있는데 잘 정리가 되어 있지 않고 어수선했다. 오래 머무르지 못하고 거의 바로 일어났다.',
#   '2점'],
#  ['프릳츠 원서점', '최고예요', '5점'],
#  ['프릳츠 원서점', '커피 ㄱㅊㄱㅊ빵너무비싸지만 맛은 ㄱㅊㄱㅊ  주문하는 곳 너무 좁아서 뭐가 줄인지 몰라서 눈치게임 잼 ', '4점'],
#  ['프릳츠 원서점',
#   '여기 자리 잡는거 참 어려운데 또 잡으면 은은한 정취를 느낄 수 있죠. 커피 정말 괜찮고 빵도 좋아요. ',
#   '4점'],
#  ['프릳츠 원서점',
#   '좌석 간 간격이 너~~~무 좁아요. 좁은 공간에 테이블 수가 지나치게 많아요.  이 점 개선되었으면 좋겠어요.',
#   '1점'],
#  ['프릳츠 원서점',
#   '베이커리 커피 매장 취식시 평균은 됨. 공간은 머물기에 좋음. 그러나 드립백 샀다가 대존망ㅠ 뜯자마자 안좋은 냄새나 설마설마 했는데 망함.',
#   '3점'],
#  ['프릳츠 원서점', '최고예요', '5점'],
#  ['프릳츠 원서점',
#   '아라리오 뮤지엄 1층. 실내보다 야외 좌석이 예쁘고 분위기 좋음. 음료와 빵도 맛있지만 의자가 불편하기 때문에 오래 있을 곳은 아님.',
#   '4점'],
#  ['프릳츠 원서점',
#   '바닐라 라떼 + 커스터드?도넛 이렇게가 맛있어용 플랫화이트는 쫌 썼음 자리 간격이 좁아서 좀 복닥복닥 붙어야 돼요ㅠㅠ  다음엔 프릳츠 다른 지점에 가고싶어여',
#   '4점'],
#  ['프릳츠 원서점',
#   '맛있음. 그렇지만 제발 BGM좀 바꿔주길 ㅜ 메탈리카st 음악 나오는데 카페랑 1도 안어울림...제발......',
#   '3점'],
#  ['프릳츠 원서점', '안국 갔으면 당연히 가야함', '5점'],
#  ['프릳츠 원서점', '빵이 정말 맛있었음! 커피가 살짝 아쉽다!', '4점'],
#  ['프릳츠 원서점', '복작복작... 휘낭시에 비추', '2점'],
#  ['프릳츠 원서점',
#   '카운터 머리 짧은 남직원의 불친절한 태도가 손님을 불쾌하게 합니다.  그 직원 덕분에 다시는 방문하지 않으려고 합니다. ',
#   '1점'],
#  ['프릳츠 원서점',
#   '프릳츠의 명성에 비하자면 많이 아쉽습니다.  숍인숍 느낌이라서 그런건지, 프릳츠 양재점에 비해 커피 밸런스도 아쉬웠습니다',
#   '3점'],
#  ['프릳츠 원서점',
#   '좌석 간격 너무 가까워서 야외테이블인데도 걱정스러움 참새가 너무 많아서 비둘기급으러 무서움 물뜨러간 사이에 내빵 훔쳐먹음 커피맛은 갠적으로 별로임 ㅜ',
#   '2점'],
#  ['프릳츠 원서점',
#   '커피 별로 의자 옛날 오락실 의자인데 쿠션없이 그냥 나무만 옆에 차길 소리 다 들림 카페손님 갤러리 손님 다 많아서 번잡 정신없음 음... 증오하는 사람 생기면 추천해줄게요',
#   '1점'],
#  ['프릳츠 원서점',
#   'GOOD : 한옥컨셉이라 분위기가 좋음. 저녁에는 조금 조명이 어두운편. 컵에 있는 트레이드마크 물개가 귀여움.   BAD : 자리는 조금 부족한편. 늦게가면 빵이 얼마 없어요.  1. 아메리카노 : 보통의 맛. 산미 약간있고 풍미도 살짝있지만 맛없지도 맛있지도 않음.  2. 베이커리 : 유명한 빵은 다 팔려 없었지만 다른것들도 괜찮았음. 크로아상 눅눅하지...',
#   '3점'],
#  ['프릳츠 원서점',
#   '응대하는 여자 직원이 조금 불친절하다는 인상을 받았습니다. 좌석도 작고, 한옥이라는 점에서 인기가 많은듯한데, Overrated된것 같네요.   그냥 그렇습니다 왜 유명한건지 조금 의문이네요 ',
#   '1점'],
#  ['프릳츠 원서점', '좋아요', '4점'],
#  ['프릳츠 원서점',
#   '커피맛은 무난했음.주문받는 여성직원분 말투가 수산시장 경매아저씨 같음. 과한 친절도 불편하지만 퉁명스러운 응대가 카페 이미지가 되었음. 아쉬움. 자리도 좁은데 키오스크 쓰시길바람.',
#   '2점'],
#  ['프릳츠 원서점',
#   '주문하는 곳과 테이블 매장이 따로 있습니다.  1층은 프릳츠고 2층은 다른 식당이니 오해하지 마세요.  야외 테이블과 실내 테이블이 있고, 한옥입니다. 분위기도 괜찮고, 커피맛도 일품인지라 이 동네 오면 거의 항상 들릅니다.  특히 외국인 친구들이 놀러와서 데려가면 정말 좋아했습니다.  다만, 매장이 넓지는 않고, 찾아오는 사람이 꽤 있어서 자리가 없을 수...',
#   '5점'],
#  ['프릳츠 원서점', '불 편 하 지 만 빵 과 커 피 그 리 고 미 술 관 덕 에 넘 좋 은 추 억 쌓 았 네 요', '4점'],
#  ['프릳츠 원서점', '참새와 빵을 먹다.', '2점'],
#  ['프릳츠 원서점', '좋아요', '4점'],
#  ['프릳츠 원서점',
#   "늘 맛있는 커피를 마실 수 있어서 좋음 윗층에 약과랑 빙수 파는 곳 있는데 거기도 추천  이름은 아마 '합'이었나",
#   '5점'],
#  ['프릳츠 원서점', '왜 유명하지?', '2점'],
#  ['프릳츠 원서점',
#   '기대를 넘 많이 하고 가서 그런지 너무 정신이 없었던 곳이에요 자리도 충분하지 않은것 같아요 날씨 좋은날 일찍 가면 여유롭게 즐기다 올수 있는데 주말은 피하시길',
#   '3점'],
#  ['프릳츠 원서점', '최고예요', '5점'],
#  ['프릳츠 원서점',
#   '너무 좋아하는 프릳츠인데 세지점중에 유난히 안국점 퀄리티가 들쑥 날쑥 한 것 같아요 ㅠㅠ 함께 좋아했던 친구들도 그렇게 느끼더라구여...',
#   '3점'],
#  ['프릳츠 원서점', '불편하고 정신없음', '1점'],
#  ['프릳츠 원서점', '커피는 진짜 시큼. 크루아상과 쿠키는 좋았다. ', '3점'],
#  ['프릳츠 원서점', '커피도 빵도 괜찮네요~', '4점'],
#  ['프릳츠 원서점', '커피는 그냥 그랬고 베이커리랑 분위기가 좋았어요.', '4점'],
#  ['프릳츠 원서점', '건축물, 분위기, 음악, 커피, 빵 모두 맘에 듦', '5점'],
#  ['프릳츠 원서점',
#   '맛있어요. 아라, 크로아상 모두 만족요. 야외테이블은 좀 불편하지만 그런대로 좋네요  직원분들도 적당히 친절하시네요 ',
#   '5점'],
#  ['프릳츠 원서점',
#   '사람많은거에비해 너무 앉을곳이없고 복잡한데 좀 의자랑 테이블을 야외에 공간 많던데 설치좀 했으면 싶습니다 음료 맛은 보통 이고 빵은 맛있네요',
#   '3점'],
#  ['프릳츠 원서점', '제대로 앉을 공간이 별로 없음 ;; ㅠㅠ 불편해요', '1점'],
#  ['프릳츠 원서점',
#   '코스타리카 에스프레소 최고에요! 너~무 맛있어요. 산미도 부드럽게 있으면서 맛과 향이 풍부하고 질감도 너무 좋네요! ^_^ 잘 마셨어요~ 감사합니다! ',
#   '5점'],
#  ['프릳츠 원서점', '산미 좋아하는 저로썬 좋았어요 ', '5점'],
#  ['프릳츠 원서점', '바닐라라떼 굳 카페라떼 셔요..', '4점'],
#  ['프릳츠 원서점', '공간은 너무 좋은데 커피가 너무 맛이 없네요..! ', '3점'],
#  ['프릳츠 원서점', '빵은 괜찮은데 커피가 별루에요 ㅡ.ㅡ', '3점'],
#  ['프릳츠 원서점',
#   '의자랑 테이블이 편하지 않고 크루아상이랑 페이스트리 종류가 바삭함이 많이 떨어져서 아쉬웠어요 카페모카는 너무 꾸덕하고 산미도 많은 편이라....호불호가 있을 것 같아요',
#   '2점'],
#  ['프릳츠 원서점', 'Love the coffee N croissant', '4점'],
#  ['프릳츠 원서점', '보통이에요', '3점'],
#  ['프릳츠 원서점',
#   '의자가 많이 불편하고 테이블이 온통 삐걱대고 흔들려서 절대 오래 앉아있기는 힘들어요. 오더하는 곳하고 좌석 공간이 완전 분리되어있어서 지저분한 테이블을 손님들이 닦아서 앉아야해요.. 음료는 종이컵에 주시는데 유독 원서점이 전체적인 직원분들 서비스나 음료 퀄리티가 떨어지는 것 같아요. 커피 맛에서도 그렇고요. 외관에 비해 그 안의 모습이 많이 아쉬운 곳입니다...',
#   '2점'],
#  ['프릳츠 원서점', '직원분이 친절하셨고 음료도 맛있었다 한옥의 분위기가 특히 좋았던 카페', '4점'],
#  ['프릳츠 원서점', '빵은 안 먹어봤지만 커피는 정말 맛 없다. 그냥 맛 없다.', '1점'],
#  ['프릳츠 원서점', '최고예요', '5점'],
#  ['프릳츠 원서점',
#   '점심시간 쯤에 갔는데 주변 직장인 손님들이 많아서 그런지 응대가 약간 잘 안되는 느낌. 주문하는 곳이 분리되어 있는 특이한 구조인데 주문하는 공간이 상당히 좁아서 불편함. 아메리카노를 주문했는데 원두도 한 종류였고 그나마 맛이 정말 없었음.',
#   '1점'],
#  ['프릳츠 원서점',
# ...
#   '분위기 깡패죠 ㅎ 메뉴가격은 높고 맛은 부실합니다만.. 다들 그렇게 알고 방문하는 것 같네요 ㅎ전망도 좋고 야외 넓은 공간에서 느끼는 만족감은 서울 시내에서 누리기 힘들정도 입니다.',
#   '4점'],
#  ['더피아노(2021년4월까지 휴업)', '노키즈존임', '1점'],
#  ['더피아노(2021년4월까지 휴업)', '커피 맛이 좋으면 더 좋겠지만 뷰가 끝내줬다 인생 뷰 카페', '4점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '음료 한잔에 1.7만원 x 2잔 + 케이크 가격은 호텔 로비 커피숍인데 맛은 동네 1700원짜리 음료만도 못함.. 화장실은 남녀공동 1칸, 항상 줄서서 기다리고. 1년전보다 가격만 잔뜩 올려서는..',
#   '1점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '주차 안내를 해줬는데, 거기서 주차 딱지가 끊겼는데 자기네 책임이 아니라고 함ㅋㅋㅋㅋ ',
#   '1점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '북한산 전경에 차를 마실수 있다는 것은 큰장점입니다. 뷰하나는 정말 좋습니다. 그러나 음료나 디저트의 가격대비 퀄리티가 많이 떨어지고 야외 시설물 관리가 잘 되지 않는 느낌입니다.',
#   '3점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '사악한 커피 가격은 야박하지만 한번은 가볼만한 이곳. 고소공포증 있으신 분들, 연로한 어르신 등이 올라가기엔 다소 심장 떨릴듯한 경사가 있으니 주의하시길. 경사를 오르고 난 후에야 비로소 보이는 평창동 일대의 멋드러진 산세 덕분에 별이 세개',
#   '3점'],
#  ['더피아노(2021년4월까지 휴업)', '최고예요', '5점'],
#  ['더피아노(2021년4월까지 휴업)', '경치는 좋지만, 불친절하고 커피값 비쌈', '4점'],
#  ['더피아노(2021년4월까지 휴업)', '금토일만 영업함 가게정보 수정해야할듯', '1점'],
#  ['더피아노(2021년4월까지 휴업)', '가격이너무쎔. 주차공간협소. 경치는 굿굿', '3점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '풍광이 넘나 좋아요~~파란하늘과 초록자연 그안에 도시를 한눈에 담을수 있어요~~^^ 그래서인지 커피값이 마이 비싸요~~^^;;;; ',
#   '3점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '카페안에 작은 폭포가있고  카페에서 계단을 타고 올라가면 북한산과 평창동일대가 한눈에 보이는  탁트인 시야와 잔디밭이 있다 뷰와 평온한 분위기가 너무 좋았던 곳',
#   '4점'],
#  ['더피아노(2021년4월까지 휴업)', '+초콜릿라떼 음료는 평범하지만 풍경은 평범하지 않음.', '4점'],
#  ['더피아노(2021년4월까지 휴업)', '조금 아쉬워요', '2점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '평창동 뷰 좋은 카페. 주차난이 심각함. 커피값은 많이 비쌈. 데이트코스로 한번은 가볼만함',
#   '3점'],
#  ['더피아노(2021년4월까지 휴업)', '보통이에요', '3점'],
#  ['더피아노(2021년4월까지 휴업)', 'xxx', '1점'],
#  ['더피아노(2021년4월까지 휴업)', '좋아요', '4점'],
#  ['더피아노(2021년4월까지 휴업)', '좋다', '5점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '커피맛은 잘 모르겠어요.  가격은 센~편이지요. 그래도 분위기는 너무 좋았어요.  추운날은 no~~~',
#   '4점'],
#  ['더피아노(2021년4월까지 휴업)', 'Coffee', '3점'],
#  ['더피아노(2021년4월까지 휴업)',
#   '서울에 이런 곳이 있다니  아무도 알려주고 싶지 않은 카페ㅎㅎ 차없이 가기 매우 힘듦',
#   '5점'],
#  ['더피아노(2021년4월까지 휴업)', '토요일오전에 한적하게 즐기기너무좋았어용 서울근교로 나온 느낌', '5점'],
#  ['더피아노(2021년4월까지 휴업)', '최고예요', '5점'],
#  ['더피아노(2021년4월까지 휴업)', '보통이에요', '3점'],
#  ['더피아노(2021년4월까지 휴업)', 'gorgeous modern structure hidden in nature!', '5점'],
#  ['포비브라이트 광화문점', '커피 맛있음', '5점'],
#  ['포비브라이트 광화문점', '좋아요', '4점'],
#  ['포비브라이트 광화문점', '최고예요', '5점'],
#  ['포비브라이트 광화문점', '요즘 왜이렇게 여기 라떼가 생각나는지 ㅎㅎ', '4점'],
#  ['포비브라이트 광화문점', '플랫화이트 존맛탱 ', '4점'],
#  ['포비브라이트 광화문점', '보통이에요', '3점'],
#  ['포비브라이트 광화문점', '커피 괜찮음~ 근데 매장이 너무 좁아서 테이크아웃 했어요ㅠㅠ', '3점'],
#  ['포비브라이트 광화문점', '너무 좁아요', '2점'],
#  ['포비브라이트 광화문점',
#   '디타워점은 포장도 다 데워서 해주시는데 여기는 베이글만 달랑 주더라구요ㅠㅠ 커팅도 안된채로 커팅칼도 없이 줘서 힘들게뜯어서 먹었어요 ㅠ_ㅠ 디타워점이 훨씬 좋아요 ',
#   '2점'],
#  ['포비브라이트 광화문점', '보통이에요', '3점'],
#  ['포비브라이트 광화문점', '베이글 굿 ', '4점'],
#  ['포비브라이트 광화문점', '애정하는 커피집중 하나. ', '5점'],
#  ['포비브라이트 광화문점',
#   '생각보다 엄~~~청좁아요ㅠㅠ 잘찍은사진 보고갔다가 바로나옴 ㅠㅠ 건물 회사사람들이 테이크아웃 할만한곳이네요',
#   '5점'],
#  ['포비브라이트 광화문점',
#   '생각보다 공간이 좁고 드링크 메뉴가 한정적임 그리고 빌딩 내에 있어서인지 엄청 조용함 베이글은 플레인까지 다 맛있었어요 :)',
#   '3점'],
#  ['아키비스트', 'bb', '5점'],
#  ['아키비스트', '사람 많아서 실내에선 못 먹고 테이크아웃해서 근처 벤치에서 먹었어요. 존맛!', '5점'],
#  ['아키비스트',
#   '웨이팅 하라는 응대가 달랑 번호 하나 적으리는 건데    전화 1번 하고선 안받으면 넘어갔다는 식. 제 휴대폰에 안울렸는데요? 받으려니 끊겼는데요? 이러면 어쩌실거에요. 애초에 처음부터 휴대폰 쥐고 있으라고 안내하던가 룰을 정해서 알려주셨어야죠. 전화받고 가는시간 30분 걸려도 되나요? 기준 진짜 우습네요. 요즘 같은 시대에 이딴식으로 운영하는 가게 처음 ...',
#   '1점'],
#  ['아키비스트',
#   '오우 좋아용 레몬파운드가 좀만 더 상큼했으면 좋겠다!! 드립 싱글오리진 원두는 콜롬비아 하나뿐인데  나쁘지않습니다',
#   '4점'],
#  ['아키비스트', '서촌 최애 카페', '5점'],
#  ['아키비스트', '아인슈페너랑 당근케익 맛있어요 ㅠ ', '4점'],
#  ['아키비스트',
#   '아인슈페너: 크림이 헤비해서 다 마시니까 속이 좀 느끼했다 입맛에 안 맞 당근케이크: 시나몬맛 강하지 않고 달달괜찮  웨이팅 있고 위치가 썩 좋지도 않고 아인슈페너도 그냥저냥이어서 다시 올 것 같지 않아 별점2개',
#   '2점'],
#  ['아키비스트', '아인슈페너 너무 맛있었어요 .. ', '5점'],
#  ['아키비스트', '아인슈페너 구웃', '5점'],
#  ['아키비스트', '최고예요', '5점'],
#  ['아키비스트', '아인슈페너 넘나마시씀', '5점'],
#  ['아키비스트', '라떼 맛있음 디저트도', '4점'],
#  ['아키비스트',
#   '그냥 맛있어요 월요일 오후라 웨이팅없고 앉을자리 있었구요 사진찍고 자리옮겨도 뭐라고 안하시네요  아인슈페너는 크림은 상당히 달고 아래 커피는 연한편에 속합니다 크림이랑 커피가 섞여서 입에 들어오진 않아요  커피를 잘 안마시는 편이라 저는 차라리 이게 좋았습니다만 굳이 이걸 마시러 올 것 같진 않고 근처에 있으면 한 번쯤 올 것 같아요',
#   '4점'],
#  ['아키비스트', '아인슈페너 맛있어요 무난하게 ~ 레몬파운드도 맛있음', '4점'],
#  ['아키비스트', '좋아요', '4점'],
#  ['아키비스트', '얼그레이 스콘 맛있고 아인슈페너 맛있고! 화장실 깨끗하고!', '5점'],
#  ['아키비스트',
#   '의자한번옮겼다가 직원분 표정과 말투 진짜... 충분히 좋게 말하셔도 됐을 얘기를  무슨 큰 잘못한것마냥 에휴  이렇게 굳이 리뷰까지 남기게하네요  커피마시러 왔다가 기분만 잡치고 가요ㅋ   ',
#   '1점'],
#  ['아키비스트',
#   '별 한개도 아까워요 기껏 왔는데 자리좀 옮겨서 사진찍으려다가 직원분 표정과 말투 때문에 기분만 잡쳤네요ㅡㅡ 분위기 맛 이런걸 떠나서 좀 친절하셔야겠어요',
#   '1점'],
#  ['아키비스트',
#   '전 아인슈페너 매니아고 인생맛집이라는 말이 많아서 와봤는데 굳이 여까진 올 필요없는 정도인데요... 인생아인슈페너라는분 여기가 인생첫 아인슈페너였나봄...  아래 입맛구단님 의견에 동감합니다.',
#   '2점'],
#  ['아키비스트',
#   '자리 웨이팅 길어서 솔직히 그런것에 불만 있는 손님들 있겠지만 그냥 테이크아웃해서 주변 걷는것도 나쁘지 않음 (테이크아웃하면 할인)',
#   '5점'],
#  ['아키비스트',
#   '흠 저만 맛이 없나요. 아인슈페너 매니아라 눈여겨 보고 잇다 왔는데 비싸기만 합니다. 크림 자체는 맛있는데 밑에 깔린 샷이 엄청 밍밍합니다. 같이 시킨 바닐라라떼도 동일하구요. 이걸 우유베이스라고 보기엔 샷 자체가 맛이 없는듯 합니다. 서울에 좋은 카페들에 비해 접근성도 좋지 않는데 말이죠.',
#   '2점'],
#  ['아키비스트', '좋아요', '4점'],
#  ['아키비스트', '전 바닐라빈라떼가 더 맛있더군요', '3점'],
#  ['아키비스트', '커피가 생각보다 별로고 가게가 좁고 사람이 많아서 북적북적하는 느낌이 강합니다', '2점'],
#  ['아키비스트',
#   '내부는 붐비고 정신없는 편이지만, 아인슈페너가 맛있어요 테이크아웃시 할인되고, 청와대사랑채 근처 걸으며 마시기 딱 좋아요',
#   '4점'],
#  ['아키비스트', '좋아요', '4점'],
#  ['아키비스트', '아인슈페너는 무난 레몬 케이크 존맛 ', '4점'],
#  ['아키비스트', '이집 아인슈페너 인정! 그치만 주차가 안되고 웨이팅이 길어서 별하나 뺏음 ㅠㅠ', '4점'],
#  ['아키비스트',
#   '최근 6개월 내로 아인슈페너 먹으러 3번 찾아갔습니다.. 아인슈페너 정말 좋아하는데 인생 아인슈페너 (참고로 경기도민이고, 쫀득한 크림파입미다)  사람은 항상 많아서 늘 테이크 아웃해서 먹었고, 그냥 애초에 앉을 생각 안하고 테이크 아웃해서 경복궁이나 서촌 돌아다니면서 마시면 매우 매우 행복합니다 제 기준에서 5개 주지 않을 이유가 없어서 5개이지만 아래 ...',
#   '5점'],
#  ['아키비스트', '아인슈페너 정말 맛있어요', '5점'],
#  ['아키비스트',
#   '가야는이유 : 분위기 괜찮, 커피맛 괜찮 안가는이유 : 거리는 한적한데 여기만 만석, 베이커리는 쏘쏘  아인슈페너 : 대표메뉴, 크림의 쫀득거림이 취향에 딱 맞고, 끝까지 커피와 크림을 적당량씩 먹을 수 있었음 라떼 : 커피에서 고소함과 씁쓸함이 기본적으로 있어서 괜찮 앙버터스콘 : 스콘에서 짠맛이 남, 팥은 별맛이 나지 않음, 한입에 먹기엔 불편한 사이즈...',
#   '4점'],
#  ['아키비스트', '좋아요', '4점'],
#  ['아키비스트', '아슈 괜찮음', '3점'],
#  ['아키비스트',
#   '사람많고 음악 볼륨도 큰 편이라 시끄러움. 조용한걸 원하면 비추. 아인슈페너 크림은 특출나진 않지만 부드럽고 달달하니 맛있다. 알고있는 그맛 ㅎㅎ 커피는 산미 거의 없고 적당히 씁쓸하며 진해서 좋음. ',
#   '4점'],
#  ['아키비스트', '조금 아쉬워요', '2점'],
#  ['아키비스트',
#   '처음 열었을 때 즈음부터 갔는데 전체적으로 다 맛있어요  아인슈페너가 시그니처 메뉴라 인기 많고 맛있지만 개인적으로 라떼도 맛있어요  마셨을 때 넘김도 부드럽고 그렇다고 가볍지도 않아서 좋아해요  베이커리류는 다 먹어봤는데 레몬 파운드 케이크가 약간 얇지만 이게 젤 괜찮아요  요즘에는 사람 많아서 평일 낮에도 웨이팅이라 예전처럼 편하게 있기는 힘들지만 그래...',
#   '5점'],
#  ['아키비스트',
#   '아인슈페너와 아몬드 카페라떼가 너무 맛있어요 손가락 안에 듭니다 레몬 파운드 케이크도 대존맛 다만 안쪽에 있어서 좀 걸어야하고 사람이 많습니다 ',
#   '5점'],
#  ['아키비스트', '맛있는 아인슈페너 ', '5점'],
#  ['아키비스트',
#   '아몬드 밀크티 맛있어요.. 직원분들은 친절하지도 불친절하지도 않으세요! 가끔은 손님에게 무관심한게 편하지않나요.? 자리도 편하고 좋아요',
#   '4점'],
#  ['아키비스트', '보통이에요', '3점'],
#  ['아키비스트', '맛있어용 ', '4점'],
#  ['아키비스트', '불친절', '1점'],
#  ['아키비스트',
#   '아인슈페너랑 앙버터스콘 둘 다 맛있어요. 인스타로 유명한 카페들은 불친절한 곳들이 꽤 있었는데 여기는 친절하게 응대해주어 기분좋게 시간을 보낼 수 있었습니다',
#   '5점'],
#  ['아키비스트',
#   '아인슈페너 크림이 쫀득하고 너무 안 달아서 맛나여! 레몬케익 부드럽고 새콤달콤! 근데 짐을 놓을 곳이 마땅히 없어서 너무 불편했어요 ㅜ',
#   '4점'],
#  ['아키비스트', '아인슈패너 미쳤어요. 이제부터 제 인생맛집임. 레몬케익더 짱맛...', '5점'],
#  ['아키비스트',
#   '아인슈페너는 진짜 맛있습니다.  일하시는 분이 머랭 치는데 장인의 손길을 느꼈습니다. 다른건 모르겠고 아인슈페너는 꼭 드세요. ',
#   '5점'],
#  ['아키비스트',
#   '아인슈페너가 맛있는 곳 커피가 대체로 산미는 없는 편이고 고소하다 게다가 맛이 부드러워서 커피 자체로는 만족이었음  베이커리류는.. 사실 소금 단팥버터빵을 먹고 싶었는데 쓸데없이 이름에 일본어로 소금을 뜻하는 시오가 들어간 시오앙버터라고 되어있어 거부감이 느껴졌다 다른 앙버터 스콘도 마찬가지 굳이 좋은 소금이라는 단어를 두고 시오라는 단어를 써야하는 이유가...',
#   '3점'],
#  ['아키비스트',
#   '커피 맛으로 치면 아메리카노, 라떼, 플랫화이트, 아인슈패너 중 플랫화이트가 가장 나앗다.  아인슈패너는 비쥬얼 값.  분위기가 좋아서 데이트 하거나 쉬어가기에 좋은 곳. ',
#   '4점'],
#  ['아키비스트', '커피맛이 진짜 좋아요. 완전 맛있고 일하시는 분들도 친절하십니다. 메뉴에는 안 보이지만 스콘류도 있네요.', '4점'],
#  ['아키비스트', '좋아요', '4점'],
#  ['청수당',
#   '카페 안에 잔잔하게 흐르는 물도 있어서 일본 교토 느낌 나요! 직원분들 친절하시고 사진 찍기 정말 좋은 분위기 좋은 카페예요. 전반적으로 자연 속 느낌있는 카페여서 재방문 할 것 같아요',
#   '5점'],
#  ['청수당', '맛이 이상해오...', '1점'],
#  ['청수당',
#   '카페라떼 주문했는데 기대만큼은 아니었어요 디저트도 양이 좀 적어 아쉬웠구요 가격은 넘 비싸서 재방문은 안할듯요',
#   '3점'],
#  ['청수당',
#   '가격이 진짜..ㅋㅋ 부담되긴 해요.. 맘 먹고 가야하는 카페라고 생각이 되는 부분ㅠ 하지만 분위기는 진짜 말도 안되게 좋고 직원분들도 친절하심! :) 인생샷 건지러 가기 딱 좋은 곳이에요 !',
#   '4점'],
#  ['청수당', '가격은 사악하지만 직원분들의 친절함과 분위기 때문에 재방문 의사 있습니당 수플레 맛있고 음료는 쏘쏘예요', '4점'],
#  ['청수당', '분위기 맛집임 음료는 괜춘 카스테라 가격은 사악함... 퀄리티에 비해 그정도 가격은 진짜 아닌듯', '4점'],
#  ['청수당',
#   '분위기좋은데 너무너무 비쌈.. 맛도 그닥.. 에이드랑 에그...무슨 커피 시켰는데 맛없음.. 굳이 찾아와 돈낭비할 필요가 없었다.. 노래도 없음..',
#   '2점'],
#  ['청수당',
#   '괜히 핫플이 아니였음 가을밤 감성에 아주 딱이다! 마치 일본 중국의 어느 휴양지에 온 느낌 계란 커피도 독특하니 부드럽고 맛남 홍차 녹차라인 음료들도 괜춘 차후 재방문 확정! 취저 탕탕^^',
#   '5점'],
#  ['청수당', '익선동 핫플 분위기 맛집', '4점'],
#  ['청수당', '최고예요', '5점'],
#  ['청수당',
#   '분위기 카페.. 3만원 넘는 케이크는 분위기도 커버하지 못한 맛. 빠바 케이크가 더 맛남.   그래도 인테리어는 지금까지 가본 국내 카페 중 탑3 안에 들어길 정도!   다만 공간이 작아 코로나 시국에 가기에는 다소 무리.  2명 이하로 가는 것을 추천 ',
#   '2점'],
#  ['청수당', '분위기는 좋지만 가격이 너무 사악하다. 사회적 거리두기 나름 신경 써서 괜춘합니다. 계란커피 추천!', '4점'],
#  ['청수당', '사진 찍기에는 참 좋음 하지만 가격은 맛에 비해 사악함', '4점'],
#  ['청수당',
#   'GOOD : 분위기와 인테리어가 정말 좋음. 인스타 사진찍기로 최고. 직원분들 친절함.  BAD : 사람 굉장히 많음. 자리가 조금 부족한 느낌. 기다란 테이블 형식이라 앞사람과 눈이 마주치거나 얘기들이 잘들림.  1. 계란커피 : 특이하고 유명해서 마셔봄. 아메리카노와 달달한 커스터드 크림을 같이 먹는맛. 맛은 애매함.   2. 천혜향 청수 : 괜찮음. ...',
#   '4점'],
#  ['청수당', '차가운 계란커피 정말 맛있었음 크아악', '5점'],
#  ['청수당', '최고예요', '5점'],
#  ['청수당',
#   '음료는 나쁘지않은 정도고, 수플레가 진짜 너무 맛있어요ㅠㅠㅠㅠㅠ 자꾸 생각나는맛ㅠㅠ 인테리어도 예뻐서 사진 찍기에 좋아요!',
#   '5점'],
#  ['청수당', '인테리어 맛집. 음료 디즈트 다 가격 대 있으나 이동네 핫한 카페는 다 그럼.', '4점'],
#  ['청수당', '수플레 가격대비 최악...', '1점'],
#  ['청수당',
#   ' 디저트랑 커피 비주얼은 좋아요! 좌석들도 너무 신기하게 잘 되어있구요. 사람 너무 많아서 복작복작 하지만 자리 잘 잡으면 여유롭게 쉬다 갈 수 있을 것 같아요.  다만, 말차크림라떼를 시켰는데 제 음료가 이상한건지 비린맛이 나서 크림만 먹고 아래는 못마셨어요ㅠㅠ 조개류에서 날것 같은 맛이 왜 음료에서 나는걸까요..진짜..ㅠ그것만 빼면 좋아요..',
#   '2점'],
#  ['청수당',
#   '분위기는 이뻐요 음식은 플레이팅이 이쁘고 맛은 그냥 평범하게 맛있어요 근데 가성비가 너무 떨어져요,, 비싸요 그리고 청결이 별로 안좋아요 테이블을 저희가 닦아야해요.. ',
#   '3점'],
#  ['청수당',
#   '딱 감성카페.  얼마나 오래 운영될지는 모르겠지만 인테리어는 유지관리하기 힘들어 보인다;;  여기 인싸용 드링크는 따로 있었는데 나는 왜 커피를 시켰을까나. 별로였고, 세작은 퍼포먼스 용 드립으로 두번 우려내게 해서 여린 차잎 맛을 망친다. ',
#   '4점'],
#  ['청수당', '일본에 온 감성을 주는 카페 비좁아서 사람이 많으면 불편한것은 단점', '4점'],
#  ['청수당', '트렌디함 제대로^^', '5점'],
#  ['청수당', '분위기깡패 비쥬얼이 다함 배 청수(시큼한 맛 아쉬움) 청결 아쉬움 ', '4점'],
#  ['청수당', '맛과 인테리어, 직원분의 친절함까지 3박자가 완벽. 가격이 못돼서 1점 깎았습니다. ', '4점'],
#  ['청수당', '분위기깡패! 제주감귤음료 천혜향청수 맛있음!  오리지날수플레도 돈아깝지 않고 맛있었음!  재방문의사 있음! ', '5점'],
#  ['청수당', '말차 뭐시기 맛있음', '5점'],
#  ['청수당',
#   '말차랑 홍차 진짜 완전 대박 맛있어요. 분위기도 너무 좋은데, 낮이랑 밤이랑 또 분위기가 달라서 저 같은 경우에는 밤이 더 이쁜데, 지인들은 낮이 더 이쁘다고하더라구요! 연인들끼리나 친구들끼리 서로 사진찍어주고 인생샷 남기기 좋은것같아요!',
#   '5점'],
#  ['청수당',
#   '예쁘긴 예쁜데 아직 시스템이 안잡혀있어서 그런지 줄서있으면 안내해준다그래서 20분 기다렸는데 다른 사람이 먼저 그냥 앉아버리더라구요 눈치게임이었음 혹시 가실 분들은 그냥 자리나면 앉으세요',
#   '1점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점', '불친절-1. 나머지 만족. 커피 베이커리 인테리어', '4점'],
#  ['테라로사 광화문점',
#   '서울에서 이 정도 커피를 만날수 있음에 감사합니다. 강릉 팩토리에 비해 조금 아쉬운데요. 이 부분 채워주셨으면 해서 별 한개 깎아봅니다',
#   '4점'],
#  ['테라로사 광화문점',
#   '커피도 별로고 너무 불친절.. 다른 분들 다 친절한데 유독 한명이 너무 불친절했어요 주문하라고 턱 들고 까딱. 위 아래로 훑어보면서 노려보고.',
#   '1점'],
#  ['테라로사 광화문점', '테라로사 좋아하시는 분들 ㅜㅜ  다른 지점 가세요.. 맛 완전 달라여', '1점'],
#  ['테라로사 광화문점', '커피, 디저트 모두 맛있습니다', '4점'],
#  ['테라로사 광화문점',
#   '공간 넓고 분위기 시원하고 커피 티라미수 짱맛 광화문 갈 때마다 교보에서 책 사가서 몇 시간 동안 앉아 있고 싶은 곳 ',
#   '5점'],
#  ['테라로사 광화문점', '커피알못이라 특별한지는 모르겠음 엄청 넓고 시끄러운데 구경할만해서 재밌었다', '3점'],
#  ['테라로사 광화문점',
#   '커피 원두를 사고 드립용으로 분쇄해 달라고 했는데 에스프레소용으로 갈아놨네요.. 물이 안내려와요. 커피 원두 다 버리게 생겼네요.. 진짜짜증. ‘드립용이면 얼마나 굵게 분쇄해야 하는지 아시죠?’ 이렇게 물어봐야 하나요? ㅠㅠㅠㅠ 후.. 커피 행이 좋으니까 더짜증나네요. 원두살때 참고하세요ㅠ',
#   '2점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점', '일단 넓어서 좋아요 커피두 좋구 공부하기도 조아요 ~~', '5점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점', '알고보니 좀 유명하던데 커피 맛있어요 ~ 커피 좋아하시는 분들 가보세요', '4점'],
#  ['테라로사 광화문점', '커피 진짜 맛있고 좋은데, 소리가 울려서 너무 시끄러워요.', '4점'],
#  ['테라로사 광화문점', '아메리카노 크레마가 장난아니에오 스콘은 그냥그럼', '5점'],
#  ['테라로사 광화문점',
#   '테라로사를 좋아해서 광화문에 있을 때마다 커피 마시러 오는데, 최순실 거라는 아래 댓글 보고 깜놀해서 인터넷을 찾아봤더니 최순실이 자주 왔던 곳이라네요..',
#   '5점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점', '좋아요', '3점'],
#  ['테라로사 광화문점', '무난무난해요. 삼청동 근처 사람이 그래도 적은 곳~ 다른 테라로사보다는 조금 아쉬운 곳이에요', '3점'],
#  ['테라로사 광화문점', '맛도 좋고 분위기도 좋고 편하게 한잔 하고 가기 좋음 !', '5점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점',
#   'Great quiet place for a cup of coffee for a chat, or getting work done. Try the cookies or pastries along with the coffee! ',
#   '4점'],
#  ['테라로사 광화문점', '커피맛있음 직원친절 강릉테라로사를 서울에서 맛볼수있는게 넘행복', '5점'],
#  ['테라로사 광화문점', '사람이 너무 많아요', '4점'],
#  ['테라로사 광화문점',
#   '1.깔끔, 정말 깔끔, 게다가 따뜻. 2.직원분들 매우 친절하고 밝으심.(편안함) 3.제일 중요한거. 커피 맛있음.(아메리카노 연하게강추!!!!) 4.더 중요한거. 빵 맛있음(뱅오쇼콜라 강추)',
#   '5점'],
#  ['테라로사 광화문점',
#   '장점 : 분위기가 좋고 굉장히 넓어요. 베이커리류가 다양해요. 단점 : 좌석이 불편해요. 딱딱한 의자가 대부분이에요.',
#   '4점'],
#  ['테라로사 광화문점', '라떼 시켰는데 맛은 평범해요~!', '4점'],
#  ['테라로사 광화문점',
#   '강릉의 테라로사 커피를 서울에서도 만날 수 있습니다. 광화문 동십자각 아래 더케이트윈타워 B동 1층에 위치하고 있으며, 드립커피 뿐만 아니라 브런치도 함께 즐길 수 있는 곳입니다. 넓은 매장임에도 불구하고 항상 사람이 많은 곳입니다.',
#   '4점'],
#  ['테라로사 광화문점', '시장통의 끝판왕 시끄러워도 너무 시끄러움 ', '1점'],
#  ['테라로사 광화문점', '추억의 장소', '5점'],
#  ['테라로사 광화문점', '빵이랑 커피 맛나요', '5점'],
#  ['테라로사 광화문점', '커피 기름 쩐내 너무 심함 산폐된 커피 맞는듯 ... 단체로 갔다가 단체 배탈났음 ', '1점'],
#  ['테라로사 광화문점',
#   '페루산파블로 5. 벚꽃블랜딩 아이스  6. 치즈 치아바타 3. 체다베이컨쪽파스콘 3.5  매장이큰데 시끄럽긴함 가격도 쎈듯 맛은 보통',
#   '3점'],
#  ['테라로사 광화문점', '매장에서 파스타 냄새가 너무 심해서 커피향이 느껴지지 않네요. 좋아했던 곳인데 너무 아쉽네요', '1점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점',
#   '브런치는 가성비 굿잡 커피는 테라로사 커피 어딜가나 비슷 매장이 조오오오오오오오오오올라 시끄럽다. 대형 매장에 브런치까지 파니까 그럴 수 밖에 없는데 왁자지껄한 분위기가 싫으면 극불호. 책읽으러 가기엔 안좋다. 애인과 브런치 하나 때리고 인사동 고고 하기에 적당. ',
#   '4점'],
#  ['테라로사 광화문점', '매장분위기좋고 커피는 보통', '4점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점', '넓찍하고 음료맛 굳굳. 시장통마냥 겁나 시끄러움. ', '5점'],
#  ['테라로사 광화문점',
#   '커피가 연해도 너무 연해요. 투샷이 들어간다는데 우유양을 줄이려 작은컵에 달래도 안된다시고... 결국 그냥 큰 컵에 양만 줄여  받았는데도 샷을 길게 뽑으시는건지 너무 연하고 묽어요. 라떼마셨어요.',
#   '3점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점',
#   '산폐아니라 썩은커피를 먹는 느낌. 에스프레소 크레마는 전부 전혀없다시피합니다. 커피상태, 바리스타의 실력 전부 최악. 에스프레소 가격은 5천원. 스타벅스가세요',
#   '1점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점',
#   '테라로사는 양평이 갑 하지만 광화문 점은 뭔가 여의도점 보다 더 쾌적한 느낌이 강함. 커피맛이야 유명하고.. 단 가격이 살짝 있으니 이점 참고할 것!! 주차는 건물 지하주차 2시간 무료!!',
#   '4점'],
#  ['테라로사 광화문점', '점심 브런치', '4점'],
#  ['테라로사 광화문점', '가끔씩 책 읽으러 ', '3점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점',
#   '광화문에서도 살짝 외진 곳에 있으면서 매장도 넓고 다른 커피전문점에 비해 조용해서 대화하기 좋다. 맘에 듦.',
#   '3점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점', '모든게 굿~', '5점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점', '브런치  널찍하고 좋다 ㅎㅎ 피로회복에 좋다는 히비스커스에이드 완전 맛있♥', '5점'],
#  ['테라로사 광화문점', '괜찮은 신맛 커피를 찾는다면 여기.', '3점'],
#  ['테라로사 광화문점', '입주사  직원들로 붐빔. 브런치 가성비 좋음', '3점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점', '최고예요', '5점'],
#  ['테라로사 광화문점', '조금 아쉬워요', '2점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점',
#   '브런치 13,000원에 커피는 3000원.  보기보다 양, 맛 괜찮음.  테라로사 넓은 테이블의 분위기도 괜찮음',
#   '4점'],
#  ['테라로사 광화문점', '보통이에요', '3점'],
#  ['테라로사 광화문점', '직장인들 휴가기간이라 기다림없이 먹을수 있었고  가격대비 구성이 알차 재 방문의사 있음.', '4점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점', '매일매일 신선한 재료의 유니크한 메뉴를 맛볼 수 있음에 감사하게 되는 곳', '5점'],
#  ['테라로사 광화문점', '걍 도심속 테라로사. 사람많아서 시름.', '3점'],
#  ['테라로사 광화문점', '유명한만큼 커피 맛도 좋고 베이커리도 맛있어요 !! 분위기도 좋습니다 :) ', '4점'],
#  ['테라로사 광화문점', '좋아요', '4점'],
#  ['테라로사 광화문점', '유명한 강릉테라로사가 광화문에 생김! 커피는 말할것도 없고! 빵 또한 맛있다~!!', '4점'],
#  ['테라로사 광화문점', '런치 13,000원 샐러드 중 3개메뉴 선택. 가격이 좀 있지만 맛있어요.', '4점'],
#  ['테라로사 광화문점', '분위기 좋고 커피 맛도 좋은데 점심 메뉴는 괜찮아요 정도이지 말입니다', '4점'],
#  ['테라로사 광화문점', 'terarosa in Seoul', 0],
#  ['테라로사 광화문점', '온두라스 부에나 비스타 원두 핸드드립, 마리아주 프레르 얼그레이, 홍차잔 레녹스', 0],
#  ['테라로사 광화문점',
#   '평일 점심시간에 테라로사 브런치 메뉴. 1만3천원에 제법 푸짐하고 메뉴도 다양했움. 매일매일 다른 메뉴가 제공되고 여러 종류 메뉴에서 자기가 먹을 메뉴를 고를 수 있다.',
#   0],
#  ['테라로사 광화문점', '', 0],
#  ['테라로사 광화문점', '주말에 한쪽 구석 자리잡고 앉아 잼난 책 읽고싶구나. 향기롭고 강한 커피맛 굿~', 0],
#  ['테라로사 광화문점', '담엔 라이딩 와야지', 0],
#  ['테라로사 광화문점', '파나마 먹어봄. 브라질이 더 맛있었음.', 0],
#  ['테라로사 광화문점', '넓고 사람은 많고.. 커피맛 괜찮고.. 브런치는 soso.. 넓은게 맘에 든다.', 0],
#  ['테라로사 광화문점', 'ㅇㅇ', 0],
#  ['테라로사 광화문점', '맛남', 0],
#  ['테라로사 광화문점', '강릉에서 시작해 서울까지 진출한 커피집 드립커피가 유명한데 나는 왜 라떼가 더 맛있지ㅋ', 0],
#  ['테라로사 광화문점', '시다모 오마초.  과테말라라에스페란자', 0],
#  ['테라로사 광화문점', '광화문에도 테라로사가♥ 커피와 베이커리 맛 그대로', 0],
#  ['테라로사 광화문점', '광화문에 오픈한 강릉의 유명 커피전문점!! 베이커리와 브런치도 수준급', 0],
#  ['테라로사 광화문점', '인테리어가 기가막힌 ...', 0],
#  ['테라로사 광화문점', '청진동 투어중 만난 테라로사', 0],
#  ['테라로사 광화문점', '', 0],
#  ['테라로사 광화문점', '에스프레소 마끼아또♡♡♡', 0],
#  ['테라로사 광화문점',
#   '여기보다 맛있는 커피는 없다... 같은 커피지만 맛은 다르다... 강릉..양평...힘들었는데.. 광화문에 생겨서...넘 햄볶아요',
#   0],
#  ['테라로사 광화문점', '브런치가 깔끔하면서도 맛있음. 장소도 좋음. 가격대가 조금 아쉽긴 함. ', '5점'],
#  ['레이어드', '케익 가격이 좀 비싸지만 ㅜㅜ 얼그레이 케익은 맛있구용 직원 분들이 친절해서 기분 좋았어욤!!', '4점'],
#  ['레이어드', '스콘이 맛있어요', '5점'],
#  ['레이어드', '나쁘지 않았어요', '4점'],
#  ['레이어드',
#   '스콘 종류가 엄청 많아서 골라먹을 수 있는 재미가 있고 시끄러운건 사람들이 그만큼 여기가 좋아서 많이 온다는거니까◡̈ 직원분들 다 친절하셨어요',
#   '4점'],
#  ['레이어드', '스콘맛집 강추', '5점'],
#  ['레이어드', '유럽감성 따라하려고 한듯. 위생별로고 시끄럽고 노키즈존', '2점'],
#  ['레이어드',
#   '- 눈으로만 봐도 좋고 입에 넣으면 더좋은 짱맛있는 스콘 - 이시국이라 테이크아웃 할인 해줌 - 밖에 꺼내놓고 손님들이 직접 집게로 집어가는 형식인데, 살짝 찝찝하긴 함 - 직원분들도 친절하고 넘 맛있음!',
#   '4점'],
#  ['레이어드', '베이커리 맛집', '5점'],
#  ['레이어드', '먹어본 스콘중에  여기  바질스콘이  최고였어요  하루 지나  먹어도  너무  맛있었습니다  ', '5점'],
#  ['레이어드',
#   '최애 케잌 맛집! 스콘이 유명하지만 케잌 추천합니다. 너무 달지 않고 세련되고 다양한 조각케잌들이 예쁘게 진열되어있는 매장 내부는 방문 할때마다 행복해질 정도입니다.  개인적으로 삼각형 모양의 스콘은 왠지 조금 생소하고, 둥근 스콘 만큼의 식감이나 호감이 가지 않는... 스콘의 생명은 촉촉함과 풍부한 버터향인데 둘다 조금 아쉬워요. 그러나 맛있는 케잌들과 ...',
#   '5점'],
#  ...]

# %%
df = pd.DataFrame(searchList)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5283 entries, 0 to 5282
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5283 non-null   object
#  1   1       5283 non-null   object
#  2   2       5283 non-null   object
# dtypes: object(3)
# memory usage: 123.9+ KB

# %%
df.head(10)
# Out:
#           0                                                  1   2
# 0  카페노티드 안국            맛있어요 좀 비싸긴하지만 늦게가면 남은거없음  요즘 코로나라 사람 덜함  4점
# 1  카페노티드 안국                                             밀크 존맛♡  5점
# 2  카페노티드 안국                맛은 있는데 항상 웨이팅이 길고 남은 메뉴가 몇 개 없네요 아쉽  4점
# 3  카페노티드 안국  맛은..평범해요.. 한사람이 도넛 계산 후 도넛을 받을 때까지 그 뒷 사람 주문을 ...  2점
# 4  카페노티드 안국                                                존맛탱  5점
# 5  카페노티드 안국                                                좋아요  4점
# 6  카페노티드 안국                      그냥 무난무난 .. 직원들이 너무 서로 친한듯^^;;  3점
# 7  카페노티드 안국  오늘 기준으로 저는 약 20분 정도 줄 섰구요 은근 기대하고 갔는데 저는 정말 맛있...  5점
# 8  카페노티드 안국  너무 극찬하길래 직접 가서 포장해와서 먹어봤습니다.... 패키지랑 컨셉은 진짜 잘하...  2점
# 9  카페노티드 안국  눈 내리는 날에 가지 마세요. 매장 안에 들어오지 말라고 내쫓깁니다. 인성 쓰레기 ...  1점

# %%
df.to_csv("종로 cafe_review.csv")

# %%
cafe_namelist = cafe_list.drop_duplicates()
cafe_namelist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f4bf57f8af6e> in <module>
# ----> 1 cafe_namelist = cafe_list.drop_duplicates()
#       2 cafe_namelist
#
# NameError: name 'cafe_list' is not defined

# %%
cafe_namelist = pd.DataFrame(cafe_namelist)
cafe_namelist

# %%
cafe_namelist['cafe_name'] = "강남카페 " + cafe_namelist[0]

# %%
cafe_namelist

# %%
cafe_namelist.drop([0], axis=1)

# %%
cafe_namelist.to_csv("cafe_namelist.csv")
